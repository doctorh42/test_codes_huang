# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance, graph_draw
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt

# 读取图和位置信息　グラフと位置情報を読み取る
filename1 = "Germany50"
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance


# 将图转换为个体编码　グラフを個体エンコードに変換する
def graph_to_individual(graph):
    num_vertices = graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual


# 将个体解码为图并计算边权重属性　個体をグラフにデコードし、エッジの重みを計算する
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights


# 计算两条线段是否相交的函数
def is_intersect(p1, p2, q1, q2):
    def ccw(A, B, C):
        return (C[1] - A[1]) * (B[0] - A[0]) > (B[1] - A[1]) * (C[0] - A[0])

    return ccw(p1, q1, q2) != ccw(p2, q1, q2) and ccw(p1, p2, q1) != ccw(p1, p2, q2)


# 定义适应度函数　適応度関数を定義する
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, read_graph.num_vertices())
    num_edges = graph.num_edges()
    if num_edges != 69:  # 边数限制，确保边数为69
        return float('inf'),  # 如果边数不为69，适应度设为无穷大

    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])

    # 计算边交叉的惩罚项
    edge_list = [(e.source(), e.target()) for e in graph.edges()]
    cross_count = 0
    for i in range(len(edge_list)):
        for j in range(i + 1, len(edge_list)):
            e1, e2 = edge_list[i], edge_list[j]
            p1, p2 = read_pos[e1[0]], read_pos[e1[1]]
            q1, q2 = read_pos[e2[0]], read_pos[e2[1]]
            if is_intersect(p1, p2, q1, q2):
                cross_count += 1

    # 将交叉的数量添加到总距离中作为惩罚
    total_distance += cross_count * 1000  # 乘以一个大数以增加惩罚力度

    return total_distance,


# 自定义交叉操作　交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        num_vertices = int(np.sqrt(len(individual)))
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > 69:
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - 69)
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < 69:
            # 添加缺失的边
            missing_edges = random.sample(non_edges, 69 - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2


# 自定义变异操作　変異操作
def mutGraph(ind):
    size = int(np.sqrt(len(ind)))
    edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 1]
    non_edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 0]

    if edges and non_edges:
        # 移除一条边　エッジを削除する
        i, j = random.choice(edges)
        ind[i * size + j] = 0
        ind[j * size + i] = 0

        # 添加一条边　エッジを追加する
        i, j = random.choice(non_edges)
        ind[i * size + j] = 1
        ind[j * size + i] = 1

    return ind,


# 遗传算法设置　遺伝的アルゴリズムの設定
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)


# 初始化个体时确保边数为69　初期個体を初期化する際にエッジ数を69に確保する
def initIndividual():
    num_vertices = read_graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], 69)
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)


toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)


# 主遗传算法流程　メイン遺伝的アルゴリズムフロー
def main():
    pop = toolbox.population(n=300)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(1000):
        pop, _ = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=1, stats=stats, halloffame=hof,
                                     verbose=False)
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)
        print(f"Generation {gen}: Min Fitness {record['min']}")

    return pop, logbook, hof


if __name__ == "__main__":
    pop, logbook, hof = main()
    best_individual = hof[0]
    best_graph, _ = individual_to_graph(best_individual, read_graph.num_vertices())

    # 为每个节点标上对应的序号
    vertex_text = best_graph.new_vertex_property("string")
    for v in best_graph.vertices():
        vertex_text[v] = str(int(v))

    # 绘制最终优化后的图
    graph_draw(best_graph, read_pos, vertex_text=vertex_text, edge_color='blue', output_size=(1000, 1000))

    # 绘制适应度值随迭代次数变化的图表
    min_fitness_values = logbook.select("min")
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(min_fitness_values)), min_fitness_values, marker='o', linestyle='-', color='b')
    plt.title("Fitness Value over Generations")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.grid(True)
    plt.savefig("fitness_over_generations.png")
    plt.show()
# Out:
# nodes:  50 links  69
# Generation 0: Min Fitness 424651.12263778766
# Generation 1: Min Fitness 424651.12263778766
# Generation 2: Min Fitness 405632.9507607474
# Generation 3: Min Fitness 404574.6157891191
# Generation 4: Min Fitness 410713.0251431023
# Generation 5: Min Fitness 388925.4253673662
# Generation 6: Min Fitness 399589.6316424901
# Generation 7: Min Fitness 359619.0732692701
# Generation 8: Min Fitness 359619.0732692701
# Generation 9: Min Fitness 359030.4179837703
# Generation 10: Min Fitness 331534.1921217608
# Generation 11: Min Fitness 331534.1921217608
# Generation 12: Min Fitness 318500.5187145116
# Generation 13: Min Fitness 318500.5187145116
# Generation 14: Min Fitness 302398.0477322813
# Generation 15: Min Fitness 295688.99467426754
# Generation 16: Min Fitness 282439.2622357043
# Generation 17: Min Fitness 274341.25410483207
# Generation 18: Min Fitness 274341.25410483207
# Generation 19: Min Fitness 272217.28780096094
# Generation 20: Min Fitness 261638.36780821768
# Generation 21: Min Fitness 252329.72579269405
# Generation 22: Min Fitness 249321.44115806374
# Generation 23: Min Fitness 235198.29725407448
# Generation 24: Min Fitness 231155.50052494282
# Generation 25: Min Fitness 230141.3383103885
# Generation 26: Min Fitness 229080.25144876316
# Generation 27: Min Fitness 229080.25144876316
# Generation 28: Min Fitness 222335.15735398344
# Generation 29: Min Fitness 215016.2397901661
# Generation 30: Min Fitness 211058.2106266987
# Generation 31: Min Fitness 190994.29461698091
# Generation 32: Min Fitness 184897.27594057075
# Generation 33: Min Fitness 184897.27594057075
# Generation 34: Min Fitness 179099.15920711673
# Generation 35: Min Fitness 174089.32999354214
# Generation 36: Min Fitness 161828.82109933085
# Generation 37: Min Fitness 156900.43395015044
# Generation 38: Min Fitness 156900.43395015044
# Generation 39: Min Fitness 154813.70988509868
# Generation 40: Min Fitness 154813.70988509868
# Generation 41: Min Fitness 148766.33008910355
# Generation 42: Min Fitness 148766.33008910355
# Generation 43: Min Fitness 140770.43292514578
# Generation 44: Min Fitness 140770.43292514578
# Generation 45: Min Fitness 140770.43292514578
# Generation 46: Min Fitness 136698.74869090077
# Generation 47: Min Fitness 136698.74869090077
# Generation 48: Min Fitness 130934.5003788804
# Generation 49: Min Fitness 127875.77268992625
# Generation 50: Min Fitness 124906.01362599795
# Generation 51: Min Fitness 123664.14127451579
# Generation 52: Min Fitness 120654.44037108208
# Generation 53: Min Fitness 111586.03938611562
# Generation 54: Min Fitness 111586.03938611562
# Generation 55: Min Fitness 111586.03938611562
# Generation 56: Min Fitness 111586.03938611562
# Generation 57: Min Fitness 111586.03938611562
# Generation 58: Min Fitness 103571.98044211837
# Generation 59: Min Fitness 103571.98044211837
# Generation 60: Min Fitness 102826.66753304045
# Generation 61: Min Fitness 97538.04108725223
# Generation 62: Min Fitness 94800.440291043
# Generation 63: Min Fitness 94800.440291043
# Generation 64: Min Fitness 91547.02187469877
# Generation 65: Min Fitness 86652.06514347553
# Generation 66: Min Fitness 83535.57963070057
# Generation 67: Min Fitness 82599.52257979201
# Generation 68: Min Fitness 80621.61589478196
# Generation 69: Min Fitness 75592.8298895271
# Generation 70: Min Fitness 75578.27667477498
# Generation 71: Min Fitness 75592.8298895271
# Generation 72: Min Fitness 75592.8298895271
# Generation 73: Min Fitness 73581.36553413342
# Generation 74: Min Fitness 71526.46616595898
# Generation 75: Min Fitness 67471.38026391862
# Generation 76: Min Fitness 67471.38026391862
# Generation 77: Min Fitness 66623.75164589439
# Generation 78: Min Fitness 66622.23507814501
# Generation 79: Min Fitness 62799.50831379628
# Generation 80: Min Fitness 63461.47879826322
# Generation 81: Min Fitness 58571.8870349607
# Generation 82: Min Fitness 58304.56736888029
# Generation 83: Min Fitness 55728.296791337336
# Generation 84: Min Fitness 54615.25807291151
# Generation 85: Min Fitness 54615.25807291151
# Generation 86: Min Fitness 53873.785277618816
# Generation 87: Min Fitness 46764.521890723794
# Generation 88: Min Fitness 46764.521890723794
# Generation 89: Min Fitness 46764.521890723794
# Generation 90: Min Fitness 45752.6908421565
# Generation 91: Min Fitness 46597.436048996555
# Generation 92: Min Fitness 43759.7405743806
# Generation 93: Min Fitness 43445.31829997995
# Generation 94: Min Fitness 43445.31829997995
# Generation 95: Min Fitness 42865.759507406365
# Generation 96: Min Fitness 41419.876095702355
# Generation 97: Min Fitness 40507.537410060555
# Generation 98: Min Fitness 40507.537410060555
# Generation 99: Min Fitness 39758.64937533899
# Generation 100: Min Fitness 38631.847412105504
# Generation 101: Min Fitness 38534.22341482675
# Generation 102: Min Fitness 36542.45990364312
# Generation 103: Min Fitness 35506.653172409846
# Generation 104: Min Fitness 32631.434310892393
# Generation 105: Min Fitness 32631.434310892393
# Generation 106: Min Fitness 32518.001083275773
# Generation 107: Min Fitness 31606.004869942837
# Generation 108: Min Fitness 31606.004869942837
# Generation 109: Min Fitness 28656.221080377156
# Generation 110: Min Fitness 28656.221080377156
# Generation 111: Min Fitness 28656.221080377156
# Generation 112: Min Fitness 28656.221080377156
# Generation 113: Min Fitness 28613.64775121324
# Generation 114: Min Fitness 27676.49226590812
# Generation 115: Min Fitness 27495.821321696632
# Generation 116: Min Fitness 27495.821321696632
# Generation 117: Min Fitness 24717.42414183529
# Generation 118: Min Fitness 25468.442126489754
# Generation 119: Min Fitness 24753.78209700128
# Generation 120: Min Fitness 24753.78209700128
# Generation 121: Min Fitness 24580.54602883622
# Generation 122: Min Fitness 24392.07358178398
# Generation 123: Min Fitness 23768.617469275396
# Generation 124: Min Fitness 22536.934728786342
# Generation 125: Min Fitness 22536.934728786342
# Generation 126: Min Fitness 22536.934728786342
# Generation 127: Min Fitness 21491.59798259353
# Generation 128: Min Fitness 20423.352143831282
# Generation 129: Min Fitness 20423.352143831282
# Generation 130: Min Fitness 19778.18097889149
# Generation 131: Min Fitness 19040.718668126614
# Generation 132: Min Fitness 19040.718668126614
# Generation 133: Min Fitness 19040.718668126614
# Generation 134: Min Fitness 18059.91055036427
# Generation 135: Min Fitness 17359.453598089975
# Generation 136: Min Fitness 16957.47198122185
# Generation 137: Min Fitness 15922.350087872252
# Generation 138: Min Fitness 15922.350087872252
# Generation 139: Min Fitness 14864.498401576571
# Generation 140: Min Fitness 14864.498401576571
# Generation 141: Min Fitness 14864.498401576571
# Generation 142: Min Fitness 14864.498401576571
# Generation 143: Min Fitness 13961.81412396403
# Generation 144: Min Fitness 13510.9855675994
# Generation 145: Min Fitness 13097.816029383703
# Generation 146: Min Fitness 13097.816029383703
# Generation 147: Min Fitness 11559.17021113867
# Generation 148: Min Fitness 11559.17021113867
# Generation 149: Min Fitness 11543.388184388863
# Generation 150: Min Fitness 11559.17021113867
# Generation 151: Min Fitness 11505.651971741161
# Generation 152: Min Fitness 11505.651971741161
# Generation 153: Min Fitness 11505.651971741161
# Generation 154: Min Fitness 11398.204531814934
# Generation 155: Min Fitness 10541.340717864374
# Generation 156: Min Fitness 9622.45451753991
# Generation 157: Min Fitness 10450.606220285481
# Generation 158: Min Fitness 10419.409551879004
# Generation 159: Min Fitness 10419.409551879004
# Generation 160: Min Fitness 9435.587627091365
# Generation 161: Min Fitness 9418.758778880749
# Generation 162: Min Fitness 9408.965250345616
# Generation 163: Min Fitness 8496.544069969073
# Generation 164: Min Fitness 8496.544069969073
# Generation 165: Min Fitness 8340.289769453939
# Generation 166: Min Fitness 8340.289769453939
# Generation 167: Min Fitness 8340.289769453939
# Generation 168: Min Fitness 7467.220223005735
# Generation 169: Min Fitness 7467.220223005735
# Generation 170: Min Fitness 7467.220223005735
# Generation 171: Min Fitness 7467.220223005735
# Generation 172: Min Fitness 7317.882775081996
# Generation 173: Min Fitness 6450.869882342592
# Generation 174: Min Fitness 6357.472841533953
# Generation 175: Min Fitness 6357.472841533953
# Generation 176: Min Fitness 6342.638022335575
# Generation 177: Min Fitness 6342.638022335575
# Generation 178: Min Fitness 6334.844611133385
# Generation 179: Min Fitness 6297.519042275624
# Generation 180: Min Fitness 6297.519042275624
# Generation 181: Min Fitness 5435.3088371999675
# Generation 182: Min Fitness 5319.023306404241
# Generation 183: Min Fitness 5319.023306404241
# Generation 184: Min Fitness 5319.023306404241
# Generation 185: Min Fitness 4561.94422993833
# Generation 186: Min Fitness 5308.663818527779
# Generation 187: Min Fitness 4443.449042065522
# Generation 188: Min Fitness 4399.692605169805
# Generation 189: Min Fitness 4399.692605169805
# Generation 190: Min Fitness 4314.944903096442
# Generation 191: Min Fitness 4284.034394603272
# Generation 192: Min Fitness 4284.034394603272
# Generation 193: Min Fitness 4272.41608893147
# Generation 194: Min Fitness 4272.41608893147
# Generation 195: Min Fitness 3268.3891757385804
# Generation 196: Min Fitness 3268.3891757385804
# Generation 197: Min Fitness 3268.3891757385804
# Generation 198: Min Fitness 3268.3891757385804
# Generation 199: Min Fitness 3262.3374938777433
# Generation 200: Min Fitness 2343.447020694091
# Generation 201: Min Fitness 2343.447020694091
# Generation 202: Min Fitness 2319.8906552358058
# Generation 203: Min Fitness 2319.8906552358058
# Generation 204: Min Fitness 2319.8906552358058
# Generation 205: Min Fitness 2319.8906552358058
# Generation 206: Min Fitness 2319.8906552358058
# Generation 207: Min Fitness 2319.8906552358058
# Generation 208: Min Fitness 2319.8906552358058
# Generation 209: Min Fitness 2317.3478692092212
# Generation 210: Min Fitness 2317.3478692092212
# Generation 211: Min Fitness 2292.1133150853475
# Generation 212: Min Fitness 2292.1133150853475
# Generation 213: Min Fitness 2223.9359726892953
# Generation 214: Min Fitness 2223.9359726892953
# Generation 215: Min Fitness 2231.732966288564
# Generation 216: Min Fitness 2231.732966288564
# Generation 217: Min Fitness 2231.732966288564
# Generation 218: Min Fitness 2199.4135111895134
# Generation 219: Min Fitness 2192.516890781386
# Generation 220: Min Fitness 2182.496192084968
# Generation 221: Min Fitness 2182.496192084968
# Generation 222: Min Fitness 2172.250110625642
# Generation 223: Min Fitness 2164.8760589136427
# Generation 224: Min Fitness 2164.8760589136427
# Generation 225: Min Fitness 2164.8760589136427
# Generation 226: Min Fitness 2147.5446228114006
# Generation 227: Min Fitness 2139.3268428206625
# Generation 228: Min Fitness 2139.3268428206625
# Generation 229: Min Fitness 2128.8553746141897
# Generation 230: Min Fitness 2128.8553746141897
# Generation 231: Min Fitness 2128.8553746141897
# Generation 232: Min Fitness 2126.6056419270462
# Generation 233: Min Fitness 2126.6056419270462
# Generation 234: Min Fitness 2126.6056419270462
# Generation 235: Min Fitness 2087.909732007799
# Generation 236: Min Fitness 2087.909732007799
# Generation 237: Min Fitness 2074.359683860399
# Generation 238: Min Fitness 2074.359683860399
# Generation 239: Min Fitness 2074.359683860399
# Generation 240: Min Fitness 2072.650282803026
# Generation 241: Min Fitness 2056.2607894951134
# Generation 242: Min Fitness 2056.2607894951134
# Generation 243: Min Fitness 2048.503678882056
# Generation 244: Min Fitness 2048.503678882056
# Generation 245: Min Fitness 2048.503678882056
# Generation 246: Min Fitness 2048.503678882056
# Generation 247: Min Fitness 2048.503678882056
# Generation 248: Min Fitness 2048.503678882056
# Generation 249: Min Fitness 2032.3616011427755
# Generation 250: Min Fitness 2030.3155778343817
# Generation 251: Min Fitness 2030.3155778343817
# Generation 252: Min Fitness 2030.3155778343817
# Generation 253: Min Fitness 2027.461256591886
# Generation 254: Min Fitness 2027.461256591886
# Generation 255: Min Fitness 2027.461256591886
# Generation 256: Min Fitness 2027.461256591886
# Generation 257: Min Fitness 2027.461256591886
# Generation 258: Min Fitness 2027.461256591886
# Generation 259: Min Fitness 2006.1700309382406
# Generation 260: Min Fitness 1996.3099645512532
# Generation 261: Min Fitness 1996.3099645512532
# Generation 262: Min Fitness 1996.3099645512532
# Generation 263: Min Fitness 1994.9100363933399
# Generation 264: Min Fitness 1994.9100363933399
# Generation 265: Min Fitness 1994.9100363933399
# Generation 266: Min Fitness 1994.9100363933399
# Generation 267: Min Fitness 1994.9100363933399
# Generation 268: Min Fitness 1966.7745942618226
# Generation 269: Min Fitness 1985.0191210388898
# Generation 270: Min Fitness 1985.0191210388898
# Generation 271: Min Fitness 1985.0191210388898
# Generation 272: Min Fitness 1985.0191210388898
# Generation 273: Min Fitness 1978.2250081233042
# Generation 274: Min Fitness 1978.2250081233042
# Generation 275: Min Fitness 1978.2250081233042
# Generation 276: Min Fitness 1967.5000200998772
# Generation 277: Min Fitness 1967.5000200998772
# Generation 278: Min Fitness 1956.5064596309912
# Generation 279: Min Fitness 1961.8098113334627
# Generation 280: Min Fitness 1956.2581371464457
# Generation 281: Min Fitness 1955.8677083739462
# Generation 282: Min Fitness 1939.5233486061334
# Generation 283: Min Fitness 1936.47460369126
# Generation 284: Min Fitness 1932.2622276528573
# Generation 285: Min Fitness 1932.2622276528573
# Generation 286: Min Fitness 1932.2622276528573
# Generation 287: Min Fitness 1936.47460369126
# Generation 288: Min Fitness 1932.2622276528573
# Generation 289: Min Fitness 1921.7909628760358
# Generation 290: Min Fitness 1921.7909628760358
# Generation 291: Min Fitness 1921.7909628760358
# Generation 292: Min Fitness 1921.7909628760358
# Generation 293: Min Fitness 1921.7909628760358
# Generation 294: Min Fitness 1921.7909628760358
# Generation 295: Min Fitness 1920.090563004625
# Generation 296: Min Fitness 1920.090563004625
# Generation 297: Min Fitness 1920.090563004625
# Generation 298: Min Fitness 1920.090563004625
# Generation 299: Min Fitness 1920.090563004625
# Generation 300: Min Fitness 1920.090563004625
# Generation 301: Min Fitness 1907.9696512709834
# Generation 302: Min Fitness 1907.9696512709834
# Generation 303: Min Fitness 1903.9506675415796
# Generation 304: Min Fitness 1903.9506675415796
# Generation 305: Min Fitness 1903.9506675415796
# Generation 306: Min Fitness 1903.9506675415796
# Generation 307: Min Fitness 1903.9506675415796
# Generation 308: Min Fitness 1887.3752487579868
# Generation 309: Min Fitness 1887.3752487579868
# Generation 310: Min Fitness 1887.3752487579868
# Generation 311: Min Fitness 1887.3752487579868
# Generation 312: Min Fitness 1887.3752487579868
# Generation 313: Min Fitness 1877.6969909021475
# Generation 314: Min Fitness 1877.6969909021475
# Generation 315: Min Fitness 1877.6969909021475
# Generation 316: Min Fitness 1877.0259058058086
# Generation 317: Min Fitness 1877.0259058058086
# Generation 318: Min Fitness 1870.2392421686195
# Generation 319: Min Fitness 1870.2392421686195
# Generation 320: Min Fitness 1870.2392421686195
# Generation 321: Min Fitness 1870.2392421686195
# Generation 322: Min Fitness 1870.2392421686195
# Generation 323: Min Fitness 1870.2392421686195
# Generation 324: Min Fitness 1863.510482158729
# Generation 325: Min Fitness 1863.510482158729
# Generation 326: Min Fitness 1863.510482158729
# Generation 327: Min Fitness 1863.510482158729
# Generation 328: Min Fitness 1861.6268776252505
# Generation 329: Min Fitness 1861.6268776252505
# Generation 330: Min Fitness 1859.0873912989496
# Generation 331: Min Fitness 1859.0873912989496
# Generation 332: Min Fitness 1859.0873912989496
# Generation 333: Min Fitness 1859.0873912989496
# Generation 334: Min Fitness 1859.0873912989496
# Generation 335: Min Fitness 1859.0873912989496
# Generation 336: Min Fitness 1852.6530697927928
# Generation 337: Min Fitness 1849.302428616406
# Generation 338: Min Fitness 1839.712525322644
# Generation 339: Min Fitness 1839.712525322644
# Generation 340: Min Fitness 1839.712525322644
# Generation 341: Min Fitness 1838.2936126728682
# Generation 342: Min Fitness 1835.367824324117
# Generation 343: Min Fitness 1835.1052807830883
# Generation 344: Min Fitness 1821.5913264119938
# Generation 345: Min Fitness 1821.5913264119938
# Generation 346: Min Fitness 1821.5913264119938
# Generation 347: Min Fitness 1821.5913264119938
# Generation 348: Min Fitness 1818.0162690559796
# Generation 349: Min Fitness 1818.0162690559796
# Generation 350: Min Fitness 1818.0162690559796
# Generation 351: Min Fitness 1818.0162690559796
# Generation 352: Min Fitness 1818.0162690559796
# Generation 353: Min Fitness 1809.819777859338
# Generation 354: Min Fitness 1809.819777859338
# Generation 355: Min Fitness 1809.819777859338
# Generation 356: Min Fitness 1803.9776521637355
# Generation 357: Min Fitness 1803.9776521637355
# Generation 358: Min Fitness 1803.9776521637355
# Generation 359: Min Fitness 1765.5732858846516
# Generation 360: Min Fitness 1765.5732858846516
# Generation 361: Min Fitness 1765.5732858846516
# Generation 362: Min Fitness 1765.5732858846516
# Generation 363: Min Fitness 1760.5525839072532
# Generation 364: Min Fitness 1760.5525839072532
# Generation 365: Min Fitness 1754.5556619216177
# Generation 366: Min Fitness 1755.520607240788
# Generation 367: Min Fitness 1748.7795183848393
# Generation 368: Min Fitness 1748.7795183848393
# Generation 369: Min Fitness 1748.7795183848393
# Generation 370: Min Fitness 1748.7795183848393
# Generation 371: Min Fitness 1741.2095142620467
# Generation 372: Min Fitness 1737.4482844549357
# Generation 373: Min Fitness 1735.2421108276958
# Generation 374: Min Fitness 1735.2421108276958
# Generation 375: Min Fitness 1735.2421108276958
# Generation 376: Min Fitness 1732.4478011349702
# Generation 377: Min Fitness 1729.3378666225765
# Generation 378: Min Fitness 1729.3378666225765
# Generation 379: Min Fitness 1714.9215807036094
# Generation 380: Min Fitness 1714.9215807036094
# Generation 381: Min Fitness 1714.9215807036094
# Generation 382: Min Fitness 1714.9215807036094
# Generation 383: Min Fitness 1714.0517938159796
# Generation 384: Min Fitness 1694.249285379689
# Generation 385: Min Fitness 1694.249285379689
# Generation 386: Min Fitness 1694.249285379689
# Generation 387: Min Fitness 1694.249285379689
# Generation 388: Min Fitness 1694.249285379689
# Generation 389: Min Fitness 1694.249285379689
# Generation 390: Min Fitness 1694.249285379689
# Generation 391: Min Fitness 1685.5331972773745
# Generation 392: Min Fitness 1685.5331972773745
# Generation 393: Min Fitness 1685.5331972773745
# Generation 394: Min Fitness 1685.5331972773745
# Generation 395: Min Fitness 1685.5331972773745
# Generation 396: Min Fitness 1685.5331972773745
# Generation 397: Min Fitness 1682.5140635305374
# Generation 398: Min Fitness 1682.1399811988585
# Generation 399: Min Fitness 1681.2694605183356
# Generation 400: Min Fitness 1682.1399811988585
# Generation 401: Min Fitness 1653.946253472252
# Generation 402: Min Fitness 1653.946253472252
# Generation 403: Min Fitness 1650.0255399965463
# Generation 404: Min Fitness 1650.0255399965463
# Generation 405: Min Fitness 1650.0255399965463
# Generation 406: Min Fitness 1650.0255399965463
# Generation 407: Min Fitness 1650.0255399965463
# Generation 408: Min Fitness 1650.0255399965463
# Generation 409: Min Fitness 1650.0255399965463
# Generation 410: Min Fitness 1650.0255399965463
# Generation 411: Min Fitness 1646.6070239462304
# Generation 412: Min Fitness 1646.6070239462304
# Generation 413: Min Fitness 1646.6070239462304
# Generation 414: Min Fitness 1646.6070239462304
# Generation 415: Min Fitness 1646.6070239462304
# Generation 416: Min Fitness 1646.6070239462304
# Generation 417: Min Fitness 1643.3846060566912
# Generation 418: Min Fitness 1640.7320959231652
# Generation 419: Min Fitness 1631.6904764804938
# Generation 420: Min Fitness 1623.8732797540897
# Generation 421: Min Fitness 1621.5248426080636
# Generation 422: Min Fitness 1621.5248426080636
# Generation 423: Min Fitness 1621.5248426080636
# Generation 424: Min Fitness 1621.5248426080636
# Generation 425: Min Fitness 1618.0764030866533
# Generation 426: Min Fitness 1615.5709008631873
# Generation 427: Min Fitness 1615.3994094287143
# Generation 428: Min Fitness 1615.3994094287143
# Generation 429: Min Fitness 1615.3994094287143
# Generation 430: Min Fitness 1615.2010788320324
# Generation 431: Min Fitness 1615.3994094287143
# Generation 432: Min Fitness 1615.2010788320324
# Generation 433: Min Fitness 1615.2010788320324
# Generation 434: Min Fitness 1615.2010788320324
# Generation 435: Min Fitness 1615.2010788320324
# Generation 436: Min Fitness 1614.333554843152
# Generation 437: Min Fitness 1614.333554843152
# Generation 438: Min Fitness 1613.5518968910274
# Generation 439: Min Fitness 1595.0881927313012
# Generation 440: Min Fitness 1595.0881927313012
# Generation 441: Min Fitness 1595.0881927313012
# Generation 442: Min Fitness 1595.0881927313012
# Generation 443: Min Fitness 1578.6437326593286
# Generation 444: Min Fitness 1578.6437326593286
# Generation 445: Min Fitness 1578.6437326593286
# Generation 446: Min Fitness 1578.6437326593286
# Generation 447: Min Fitness 1578.6437326593286
# Generation 448: Min Fitness 1578.6437326593286
# Generation 449: Min Fitness 1578.6437326593286
# Generation 450: Min Fitness 1573.9623615224289
# Generation 451: Min Fitness 1573.9623615224289
# Generation 452: Min Fitness 1573.9623615224289
# Generation 453: Min Fitness 1573.9623615224289
# Generation 454: Min Fitness 1573.9623615224289
# Generation 455: Min Fitness 1568.6772758259895
# Generation 456: Min Fitness 1568.6772758259895
# Generation 457: Min Fitness 1568.6772758259895
# Generation 458: Min Fitness 1568.6772758259895
# Generation 459: Min Fitness 1568.6772758259895
# Generation 460: Min Fitness 1563.9959046890895
# Generation 461: Min Fitness 1562.9702627251218
# Generation 462: Min Fitness 1562.9702627251218
# Generation 463: Min Fitness 1563.9959046890895
# Generation 464: Min Fitness 1563.9959046890895
# Generation 465: Min Fitness 1563.9959046890895
# Generation 466: Min Fitness 1563.9959046890895
# Generation 467: Min Fitness 1563.9959046890895
# Generation 468: Min Fitness 1563.9959046890895
# Generation 469: Min Fitness 1560.883035359871
# Generation 470: Min Fitness 1560.883035359871
# Generation 471: Min Fitness 1560.883035359871
# Generation 472: Min Fitness 1560.883035359871
# Generation 473: Min Fitness 1560.883035359871
# Generation 474: Min Fitness 1560.883035359871
# Generation 475: Min Fitness 1560.883035359871
# Generation 476: Min Fitness 1560.883035359871
# Generation 477: Min Fitness 1560.883035359871
# Generation 478: Min Fitness 1560.883035359871
# Generation 479: Min Fitness 1560.883035359871
# Generation 480: Min Fitness 1560.883035359871
# Generation 481: Min Fitness 1560.883035359871
# Generation 482: Min Fitness 1560.883035359871
# Generation 483: Min Fitness 1560.883035359871
# Generation 484: Min Fitness 1560.883035359871
# Generation 485: Min Fitness 1560.883035359871
# Generation 486: Min Fitness 1560.883035359871
# Generation 487: Min Fitness 1560.883035359871
# Generation 488: Min Fitness 1560.883035359871
# Generation 489: Min Fitness 1560.883035359871
# Generation 490: Min Fitness 1558.8316184170085
# Generation 491: Min Fitness 1558.8316184170085
# Generation 492: Min Fitness 1558.8316184170085
# Generation 493: Min Fitness 1558.8316184170085
# Generation 494: Min Fitness 1558.8316184170085
# Generation 495: Min Fitness 1556.5280526474332
# Generation 496: Min Fitness 1556.5280526474332
# Generation 497: Min Fitness 1556.5280526474332
# Generation 498: Min Fitness 1556.5280526474332
# Generation 499: Min Fitness 1556.5280526474332
# Generation 500: Min Fitness 1556.5280526474332
# Generation 501: Min Fitness 1556.5280526474332
# Generation 502: Min Fitness 1556.5280526474332
# Generation 503: Min Fitness 1556.5280526474332
# Generation 504: Min Fitness 1556.5280526474332
# Generation 505: Min Fitness 1556.5280526474332
# Generation 506: Min Fitness 1556.5280526474332
# Generation 507: Min Fitness 1556.5280526474332
# Generation 508: Min Fitness 1556.5280526474332
# Generation 509: Min Fitness 1556.5280526474332
# Generation 510: Min Fitness 1556.5280526474332
# Generation 511: Min Fitness 1556.5280526474332
# Generation 512: Min Fitness 1556.5280526474332
# Generation 513: Min Fitness 1543.183737872539
# Generation 514: Min Fitness 1543.183737872539
# Generation 515: Min Fitness 1537.323997429907
# Generation 516: Min Fitness 1543.183737872539
# Generation 517: Min Fitness 1541.4258033504507
# Generation 518: Min Fitness 1540.8667392540308
# Generation 519: Min Fitness 1540.8667392540308
# Generation 520: Min Fitness 1540.8667392540308
# Generation 521: Min Fitness 1537.323997429907
# Generation 522: Min Fitness 1537.323997429907
# Generation 523: Min Fitness 1537.323997429907
# Generation 524: Min Fitness 1537.323997429907
# Generation 525: Min Fitness 1537.323997429907
# Generation 526: Min Fitness 1537.323997429907
# Generation 527: Min Fitness 1537.323997429907
# Generation 528: Min Fitness 1537.323997429907
# Generation 529: Min Fitness 1537.323997429907
# Generation 530: Min Fitness 1537.323997429907
# Generation 531: Min Fitness 1537.323997429907
# Generation 532: Min Fitness 1537.323997429907
# Generation 533: Min Fitness 1537.323997429907
# Generation 534: Min Fitness 1537.323997429907
# Generation 535: Min Fitness 1537.323997429907
# Generation 536: Min Fitness 1537.323997429907
# Generation 537: Min Fitness 1537.323997429907
# Generation 538: Min Fitness 1537.323997429907
# Generation 539: Min Fitness 1537.323997429907
# Generation 540: Min Fitness 1537.323997429907
# Generation 541: Min Fitness 1537.323997429907
# Generation 542: Min Fitness 1537.323997429907
# Generation 543: Min Fitness 1537.323997429907
# Generation 544: Min Fitness 1537.323997429907
# Generation 545: Min Fitness 1537.323997429907
# Generation 546: Min Fitness 1537.323997429907
# Generation 547: Min Fitness 1537.323997429907
# Generation 548: Min Fitness 1537.323997429907
# Generation 549: Min Fitness 1537.323997429907
# Generation 550: Min Fitness 1537.323997429907
# Generation 551: Min Fitness 1537.323997429907
# Generation 552: Min Fitness 1537.323997429907
# Generation 553: Min Fitness 1537.323997429907
# Generation 554: Min Fitness 1537.323997429907
# Generation 555: Min Fitness 1537.323997429907
# Generation 556: Min Fitness 1537.323997429907
# Generation 557: Min Fitness 1537.323997429907
# Generation 558: Min Fitness 1537.323997429907
# Generation 559: Min Fitness 1537.323997429907
# Generation 560: Min Fitness 1536.198094687187
# Generation 561: Min Fitness 1536.198094687187
# Generation 562: Min Fitness 1536.198094687187
# Generation 563: Min Fitness 1534.6905533066938
# Generation 564: Min Fitness 1536.198094687187
# Generation 565: Min Fitness 1536.198094687187
# Generation 566: Min Fitness 1531.6061326856166
# Generation 567: Min Fitness 1531.6061326856166
# Generation 568: Min Fitness 1533.9202394118033
# Generation 569: Min Fitness 1533.9202394118033
# Generation 570: Min Fitness 1533.9202394118033
# Generation 571: Min Fitness 1533.9202394118033
# Generation 572: Min Fitness 1533.9202394118033
# Generation 573: Min Fitness 1533.9202394118033
# Generation 574: Min Fitness 1533.9202394118033
# Generation 575: Min Fitness 1530.5343210016981
# Generation 576: Min Fitness 1530.5343210016981
# Generation 577: Min Fitness 1530.5343210016981
# Generation 578: Min Fitness 1530.5343210016981
# Generation 579: Min Fitness 1530.5343210016981
# Generation 580: Min Fitness 1529.0230875604152
# Generation 581: Min Fitness 1529.0230875604152
# Generation 582: Min Fitness 1530.5343210016981
# Generation 583: Min Fitness 1530.5343210016981
# Generation 584: Min Fitness 1530.5343210016981
# Generation 585: Min Fitness 1530.5343210016981
# Generation 586: Min Fitness 1530.5343210016981
# Generation 587: Min Fitness 1530.5343210016981
# Generation 588: Min Fitness 1530.5343210016981
# Generation 589: Min Fitness 1530.5343210016981
# Generation 590: Min Fitness 1530.5343210016981
# Generation 591: Min Fitness 1530.5343210016981
# Generation 592: Min Fitness 1530.5343210016981
# Generation 593: Min Fitness 1530.5343210016981
# Generation 594: Min Fitness 1530.5343210016981
# Generation 595: Min Fitness 1530.5343210016981
# Generation 596: Min Fitness 1530.5343210016981
# Generation 597: Min Fitness 1530.5343210016981
# Generation 598: Min Fitness 1530.5343210016981
# Generation 599: Min Fitness 1530.5343210016981
# Generation 600: Min Fitness 1530.5343210016981
# Generation 601: Min Fitness 1530.5343210016981
# Generation 602: Min Fitness 1530.5343210016981
# Generation 603: Min Fitness 1530.5343210016981
# Generation 604: Min Fitness 1530.5343210016981
# Generation 605: Min Fitness 1530.5343210016981
# Generation 606: Min Fitness 1530.5343210016981
# Generation 607: Min Fitness 1530.5343210016981
# Generation 608: Min Fitness 1528.9601436182234
# Generation 609: Min Fitness 1528.9601436182234
# Generation 610: Min Fitness 1528.9601436182234
# Generation 611: Min Fitness 1528.9601436182234
# Generation 612: Min Fitness 1528.9601436182234
# Generation 613: Min Fitness 1525.5449655276027
# Generation 614: Min Fitness 1527.3305133711738
# Generation 615: Min Fitness 1527.3305133711738
# Generation 616: Min Fitness 1527.3305133711738
# Generation 617: Min Fitness 1527.3305133711738
# Generation 618: Min Fitness 1527.3305133711738
# Generation 619: Min Fitness 1527.3305133711738
# Generation 620: Min Fitness 1527.3305133711738
# Generation 621: Min Fitness 1527.3305133711738
# Generation 622: Min Fitness 1527.3305133711738
# Generation 623: Min Fitness 1527.3305133711738
# Generation 624: Min Fitness 1527.3305133711738
# Generation 625: Min Fitness 1527.3305133711738
# Generation 626: Min Fitness 1527.3305133711738
# Generation 627: Min Fitness 1527.3305133711738
# Generation 628: Min Fitness 1527.3305133711738
# Generation 629: Min Fitness 1527.3305133711738
# Generation 630: Min Fitness 1527.3305133711738
# Generation 631: Min Fitness 1527.3305133711738
# Generation 632: Min Fitness 1527.3305133711738
# Generation 633: Min Fitness 1527.3305133711738
# Generation 634: Min Fitness 1527.3305133711738
# Generation 635: Min Fitness 1527.3305133711738
# Generation 636: Min Fitness 1527.3305133711738
# Generation 637: Min Fitness 1527.3305133711738
# Generation 638: Min Fitness 1527.3305133711738
# Generation 639: Min Fitness 1527.3305133711738
# Generation 640: Min Fitness 1527.3305133711738
# Generation 641: Min Fitness 1527.3305133711738
# Generation 642: Min Fitness 1527.3305133711738
# Generation 643: Min Fitness 1527.3305133711738
# Generation 644: Min Fitness 1527.3305133711738
# Generation 645: Min Fitness 1527.3305133711738
# Generation 646: Min Fitness 1527.3305133711738
# Generation 647: Min Fitness 1527.3305133711738
# Generation 648: Min Fitness 1527.3305133711738
# Generation 649: Min Fitness 1527.3305133711738
# Generation 650: Min Fitness 1527.3305133711738
# Generation 651: Min Fitness 1527.3305133711738
# Generation 652: Min Fitness 1527.3305133711738
# Generation 653: Min Fitness 1527.3305133711738
# Generation 654: Min Fitness 1527.3305133711738
# Generation 655: Min Fitness 1527.3305133711738
# Generation 656: Min Fitness 1527.3305133711738
# Generation 657: Min Fitness 1527.3305133711738
# Generation 658: Min Fitness 1527.3305133711738
# Generation 659: Min Fitness 1527.3305133711738
# Generation 660: Min Fitness 1527.3305133711738
# Generation 661: Min Fitness 1527.3305133711738
# Generation 662: Min Fitness 1527.3305133711738
# Generation 663: Min Fitness 1527.3305133711738
# Generation 664: Min Fitness 1527.3305133711738
# Generation 665: Min Fitness 1527.3305133711738
# Generation 666: Min Fitness 1527.3305133711738
# Generation 667: Min Fitness 1522.8920890739143
# Generation 668: Min Fitness 1522.6455018994989
# Generation 669: Min Fitness 1522.6455018994989
# Generation 670: Min Fitness 1522.6455018994989
# Generation 671: Min Fitness 1522.6455018994989
# Generation 672: Min Fitness 1522.6455018994989
# Generation 673: Min Fitness 1522.6455018994989
# Generation 674: Min Fitness 1522.6455018994989
# Generation 675: Min Fitness 1522.6455018994989
# Generation 676: Min Fitness 1522.6455018994989
# Generation 677: Min Fitness 1522.6455018994989
# Generation 678: Min Fitness 1522.6455018994989
# Generation 679: Min Fitness 1513.1775985930988
# Generation 680: Min Fitness 1513.1775985930988
# Generation 681: Min Fitness 1513.1775985930988
# Generation 682: Min Fitness 1513.1775985930988
# Generation 683: Min Fitness 1513.1775985930988
# Generation 684: Min Fitness 1513.1775985930988
# Generation 685: Min Fitness 1513.1775985930988
# Generation 686: Min Fitness 1513.1775985930988
# Generation 687: Min Fitness 1513.1775985930988
# Generation 688: Min Fitness 1513.1775985930988
# Generation 689: Min Fitness 1513.1775985930988
# Generation 690: Min Fitness 1513.1775985930988
# Generation 691: Min Fitness 1513.1775985930988
# Generation 692: Min Fitness 1513.1775985930988
# Generation 693: Min Fitness 1513.1775985930988
# Generation 694: Min Fitness 1513.1775985930988
# Generation 695: Min Fitness 1513.1775985930988
# Generation 696: Min Fitness 1513.1775985930988
# Generation 697: Min Fitness 1513.1775985930988
# Generation 698: Min Fitness 1513.1775985930988
# Generation 699: Min Fitness 1513.1775985930988
# Generation 700: Min Fitness 1513.1775985930988
# Generation 701: Min Fitness 1513.1775985930988
# Generation 702: Min Fitness 1513.1775985930988
# Generation 703: Min Fitness 1513.1775985930988
# Generation 704: Min Fitness 1513.1775985930988
# Generation 705: Min Fitness 1513.1775985930988
# Generation 706: Min Fitness 1513.1775985930988
# Generation 707: Min Fitness 1513.1775985930988
# Generation 708: Min Fitness 1513.1775985930988
# Generation 709: Min Fitness 1513.1775985930988
# Generation 710: Min Fitness 1513.1775985930988
# Generation 711: Min Fitness 1513.1775985930988
# Generation 712: Min Fitness 1513.1775985930988
# Generation 713: Min Fitness 1513.1775985930988
# Generation 714: Min Fitness 1513.1775985930988
# Generation 715: Min Fitness 1513.1775985930988
# Generation 716: Min Fitness 1513.1775985930988
# Generation 717: Min Fitness 1513.1775985930988
# Generation 718: Min Fitness 1513.1775985930988
# Generation 719: Min Fitness 1513.1775985930988
# Generation 720: Min Fitness 1513.1775985930988
# Generation 721: Min Fitness 1513.1775985930988
# Generation 722: Min Fitness 1513.1775985930988
# Generation 723: Min Fitness 1513.1775985930988
# Generation 724: Min Fitness 1513.1775985930988
# Generation 725: Min Fitness 1513.1775985930988
# Generation 726: Min Fitness 1513.1775985930988
# Generation 727: Min Fitness 1513.1775985930988
# Generation 728: Min Fitness 1513.1775985930988
# Generation 729: Min Fitness 1513.1775985930988
# Generation 730: Min Fitness 1513.1775985930988
# Generation 731: Min Fitness 1513.1775985930988
# Generation 732: Min Fitness 1513.1775985930988
# Generation 733: Min Fitness 1513.1775985930988
# Generation 734: Min Fitness 1513.1775985930988
# Generation 735: Min Fitness 1513.1775985930988
# Generation 736: Min Fitness 1513.1775985930988
# Generation 737: Min Fitness 1513.1775985930988
# Generation 738: Min Fitness 1513.1775985930988
# Generation 739: Min Fitness 1513.1775985930988
# Generation 740: Min Fitness 1513.1775985930988
# Generation 741: Min Fitness 1510.7287344195092
# Generation 742: Min Fitness 1510.7287344195092
# Generation 743: Min Fitness 1510.7287344195092
# Generation 744: Min Fitness 1510.7287344195092
# Generation 745: Min Fitness 1510.7287344195092
# Generation 746: Min Fitness 1510.7287344195092
# Generation 747: Min Fitness 1510.7287344195092
# Generation 748: Min Fitness 1510.7287344195092
# Generation 749: Min Fitness 1510.7287344195092
# Generation 750: Min Fitness 1508.8490054656168
# Generation 751: Min Fitness 1508.8490054656168
# Generation 752: Min Fitness 1508.8490054656168
# Generation 753: Min Fitness 1510.7287344195092
# Generation 754: Min Fitness 1510.7287344195092
# Generation 755: Min Fitness 1510.7287344195092
# Generation 756: Min Fitness 1510.7287344195092
# Generation 757: Min Fitness 1510.470286136976
# Generation 758: Min Fitness 1510.470286136976
# Generation 759: Min Fitness 1510.470286136976
# Generation 760: Min Fitness 1510.470286136976
# Generation 761: Min Fitness 1510.470286136976
# Generation 762: Min Fitness 1510.0701822581755
# Generation 763: Min Fitness 1510.0701822581755
# Generation 764: Min Fitness 1510.0701822581755
# Generation 765: Min Fitness 1510.0701822581755
# Generation 766: Min Fitness 1510.0701822581755
# Generation 767: Min Fitness 1508.9188718239825
# Generation 768: Min Fitness 1510.0701822581755
# Generation 769: Min Fitness 1510.0701822581755
# Generation 770: Min Fitness 1510.0701822581755
# Generation 771: Min Fitness 1510.0701822581755
# Generation 772: Min Fitness 1510.0701822581755
# Generation 773: Min Fitness 1510.0701822581755
# Generation 774: Min Fitness 1510.0701822581755
# Generation 775: Min Fitness 1510.0701822581755
# Generation 776: Min Fitness 1510.0701822581755
# Generation 777: Min Fitness 1510.0701822581755
# Generation 778: Min Fitness 1510.0701822581755
# Generation 779: Min Fitness 1510.0701822581755
# Generation 780: Min Fitness 1510.0701822581755
# Generation 781: Min Fitness 1510.0701822581755
# Generation 782: Min Fitness 1510.0701822581755
# Generation 783: Min Fitness 1510.0701822581755
# Generation 784: Min Fitness 1510.0701822581755
# Generation 785: Min Fitness 1510.0701822581755
# Generation 786: Min Fitness 1510.0701822581755
# Generation 787: Min Fitness 1510.0701822581755
# Generation 788: Min Fitness 1510.0701822581755
# Generation 789: Min Fitness 1510.0701822581755
# Generation 790: Min Fitness 1510.0701822581755
# Generation 791: Min Fitness 1510.0701822581755
# Generation 792: Min Fitness 1510.0701822581755
# Generation 793: Min Fitness 1510.0701822581755
# Generation 794: Min Fitness 1510.0701822581755
# Generation 795: Min Fitness 1510.0701822581755
# Generation 796: Min Fitness 1510.0701822581755
# Generation 797: Min Fitness 1510.0701822581755
# Generation 798: Min Fitness 1510.0701822581755
# Generation 799: Min Fitness 1510.0701822581755
# Generation 800: Min Fitness 1510.0701822581755
# Generation 801: Min Fitness 1510.0701822581755
# Generation 802: Min Fitness 1510.0701822581755
# Generation 803: Min Fitness 1510.0701822581755
# Generation 804: Min Fitness 1510.0701822581755
# Generation 805: Min Fitness 1510.0701822581755
# Generation 806: Min Fitness 1510.0701822581755
# Generation 807: Min Fitness 1510.0701822581755
# Generation 808: Min Fitness 1510.0701822581755
# Generation 809: Min Fitness 1510.0701822581755
# Generation 810: Min Fitness 1510.0701822581755
# Generation 811: Min Fitness 1508.2586596918065
# Generation 812: Min Fitness 1508.2586596918065
# Generation 813: Min Fitness 1508.2586596918065
# Generation 814: Min Fitness 1508.2586596918065
# Generation 815: Min Fitness 1508.2586596918065
# Generation 816: Min Fitness 1508.2586596918065
# Generation 817: Min Fitness 1507.632140603304
# Generation 818: Min Fitness 1506.6879975942234
# Generation 819: Min Fitness 1506.6879975942234
# Generation 820: Min Fitness 1505.6644978767476
# Generation 821: Min Fitness 1505.6644978767476
# Generation 822: Min Fitness 1505.6644978767476
# Generation 823: Min Fitness 1505.6644978767476
# Generation 824: Min Fitness 1504.3617113622195
# Generation 825: Min Fitness 1495.114336345366
# Generation 826: Min Fitness 1505.6644978767476
# Generation 827: Min Fitness 1505.3012462369272
# Generation 828: Min Fitness 1505.3012462369272
# Generation 829: Min Fitness 1505.3012462369272
# Generation 830: Min Fitness 1505.3012462369272
# Generation 831: Min Fitness 1505.3012462369272
# Generation 832: Min Fitness 1505.3012462369272
# Generation 833: Min Fitness 1505.3012462369272
# Generation 834: Min Fitness 1505.3012462369272
# Generation 835: Min Fitness 1505.3012462369272
# Generation 836: Min Fitness 1505.3012462369272
# Generation 837: Min Fitness 1505.3012462369272
# Generation 838: Min Fitness 1505.3012462369272
# Generation 839: Min Fitness 1505.3012462369272
# Generation 840: Min Fitness 1505.3012462369272
# Generation 841: Min Fitness 1505.3012462369272
# Generation 842: Min Fitness 1505.3012462369272
# Generation 843: Min Fitness 1505.3012462369272
# Generation 844: Min Fitness 1505.3012462369272
# Generation 845: Min Fitness 1505.3012462369272
# Generation 846: Min Fitness 1505.3012462369272
# Generation 847: Min Fitness 1505.3012462369272
# Generation 848: Min Fitness 1505.3012462369272
# Generation 849: Min Fitness 1504.1499358027345
# Generation 850: Min Fitness 1505.3012462369272
# Generation 851: Min Fitness 1505.3012462369272
# Generation 852: Min Fitness 1505.3012462369272
# Generation 853: Min Fitness 1505.3012462369272
# Generation 854: Min Fitness 1505.3012462369272
# Generation 855: Min Fitness 1505.3012462369272
# Generation 856: Min Fitness 1505.3012462369272
# Generation 857: Min Fitness 1505.3012462369272
# Generation 858: Min Fitness 1505.3012462369272
# Generation 859: Min Fitness 1505.3012462369272
# Generation 860: Min Fitness 1505.3012462369272
# Generation 861: Min Fitness 1505.3012462369272
# Generation 862: Min Fitness 1505.3012462369272
# Generation 863: Min Fitness 1505.3012462369272
# Generation 864: Min Fitness 1505.3012462369272
# Generation 865: Min Fitness 1505.3012462369272
# Generation 866: Min Fitness 1505.3012462369272
# Generation 867: Min Fitness 1505.3012462369272
# Generation 868: Min Fitness 1505.3012462369272
# Generation 869: Min Fitness 1505.3012462369272
# Generation 870: Min Fitness 1505.3012462369272
# Generation 871: Min Fitness 1505.3012462369272
# Generation 872: Min Fitness 1505.3012462369272
# Generation 873: Min Fitness 1505.3012462369272
# Generation 874: Min Fitness 1505.3012462369272
# Generation 875: Min Fitness 1505.3012462369272
# Generation 876: Min Fitness 1505.3012462369272
# Generation 877: Min Fitness 1505.3012462369272
# Generation 878: Min Fitness 1505.3012462369272
# Generation 879: Min Fitness 1505.3012462369272
# Generation 880: Min Fitness 1505.3012462369272
# Generation 881: Min Fitness 1505.3012462369272
# Generation 882: Min Fitness 1505.3012462369272
# Generation 883: Min Fitness 1505.3012462369272
# Generation 884: Min Fitness 1505.3012462369272
# Generation 885: Min Fitness 1505.3012462369272
# Generation 886: Min Fitness 1505.3012462369272
# Generation 887: Min Fitness 1505.3012462369272
# Generation 888: Min Fitness 1505.3012462369272
# Generation 889: Min Fitness 1505.3012462369272
# Generation 890: Min Fitness 1505.3012462369272
# Generation 891: Min Fitness 1505.3012462369272
# Generation 892: Min Fitness 1505.3012462369272
# Generation 893: Min Fitness 1505.3012462369272
# Generation 894: Min Fitness 1505.3012462369272
# Generation 895: Min Fitness 1505.3012462369272
# Generation 896: Min Fitness 1505.3012462369272
# Generation 897: Min Fitness 1505.3012462369272
# Generation 898: Min Fitness 1505.3012462369272
# Generation 899: Min Fitness 1505.3012462369272
# Generation 900: Min Fitness 1505.3012462369272
# Generation 901: Min Fitness 1505.3012462369272
# Generation 902: Min Fitness 1505.3012462369272
# Generation 903: Min Fitness 1505.3012462369272
# Generation 904: Min Fitness 1505.3012462369272
# Generation 905: Min Fitness 1505.3012462369272
# Generation 906: Min Fitness 1503.5415588725837
# Generation 907: Min Fitness 1505.3012462369272
# Generation 908: Min Fitness 1505.3012462369272
# Generation 909: Min Fitness 1505.3012462369272
# Generation 910: Min Fitness 1504.8606579455359
# Generation 911: Min Fitness 1504.8606579455359
# Generation 912: Min Fitness 1504.8606579455359
# Generation 913: Min Fitness 1504.8606579455359
# Generation 914: Min Fitness 1504.8606579455359
# Generation 915: Min Fitness 1504.8606579455359
# Generation 916: Min Fitness 1504.1022333567432
# Generation 917: Min Fitness 1504.1022333567432
# Generation 918: Min Fitness 1504.1022333567432
# Generation 919: Min Fitness 1502.0164157042532
# Generation 920: Min Fitness 1502.0164157042532
# Generation 921: Min Fitness 1502.0164157042532
# Generation 922: Min Fitness 1502.0164157042532
# Generation 923: Min Fitness 1502.0164157042532
# Generation 924: Min Fitness 1502.0164157042532
# Generation 925: Min Fitness 1502.0164157042532
# Generation 926: Min Fitness 1501.1997484263782
# Generation 927: Min Fitness 1501.1997484263782
# Generation 928: Min Fitness 1501.1997484263782
# Generation 929: Min Fitness 1501.1997484263782
# Generation 930: Min Fitness 1501.1997484263782
# Generation 931: Min Fitness 1501.1997484263782
# Generation 932: Min Fitness 1501.1997484263782
# Generation 933: Min Fitness 1501.1997484263782
# Generation 934: Min Fitness 1501.1997484263782
# Generation 935: Min Fitness 1500.879656144715
# Generation 936: Min Fitness 1500.879656144715
# Generation 937: Min Fitness 1500.879656144715
# Generation 938: Min Fitness 1500.879656144715
# Generation 939: Min Fitness 1500.879656144715
# Generation 940: Min Fitness 1499.8902243417413
# Generation 941: Min Fitness 1499.8902243417413
# Generation 942: Min Fitness 1499.8902243417413
# Generation 943: Min Fitness 1499.8902243417413
# Generation 944: Min Fitness 1499.1707379622176
# Generation 945: Min Fitness 1499.1707379622176
# Generation 946: Min Fitness 1499.1707379622176
# Generation 947: Min Fitness 1499.1707379622176
# Generation 948: Min Fitness 1499.1707379622176
# Generation 949: Min Fitness 1499.1707379622176
# Generation 950: Min Fitness 1499.1707379622176
# Generation 951: Min Fitness 1499.1707379622176
# Generation 952: Min Fitness 1498.7575048576052
# Generation 953: Min Fitness 1498.7575048576052
# Generation 954: Min Fitness 1498.7575048576052
# Generation 955: Min Fitness 1498.666094226267
# Generation 956: Min Fitness 1498.666094226267
# Generation 957: Min Fitness 1498.1895599136803
# Generation 958: Min Fitness 1498.1895599136803
# Generation 959: Min Fitness 1498.1895599136803
# Generation 960: Min Fitness 1498.1895599136803
# Generation 961: Min Fitness 1498.1895599136803
# Generation 962: Min Fitness 1498.1895599136803
# Generation 963: Min Fitness 1498.1895599136803
# Generation 964: Min Fitness 1498.1895599136803
# Generation 965: Min Fitness 1497.5640333450485
# Generation 966: Min Fitness 1498.1895599136803
# Generation 967: Min Fitness 1498.1895599136803
# Generation 968: Min Fitness 1498.1895599136803
# Generation 969: Min Fitness 1498.1895599136803
# Generation 970: Min Fitness 1498.1895599136803
# Generation 971: Min Fitness 1498.1895599136803
# Generation 972: Min Fitness 1498.1895599136803
# Generation 973: Min Fitness 1498.1895599136803
# Generation 974: Min Fitness 1498.1895599136803
# Generation 975: Min Fitness 1498.1895599136803
# Generation 976: Min Fitness 1498.1895599136803
# Generation 977: Min Fitness 1498.1895599136803
# Generation 978: Min Fitness 1498.1895599136803
# Generation 979: Min Fitness 1498.1895599136803
# Generation 980: Min Fitness 1498.1895599136803
# Generation 981: Min Fitness 1498.1895599136803
# Generation 982: Min Fitness 1498.1895599136803
# Generation 983: Min Fitness 1498.1895599136803
# Generation 984: Min Fitness 1498.1895599136803
# Generation 985: Min Fitness 1498.1895599136803
# Generation 986: Min Fitness 1498.1895599136803
# Generation 987: Min Fitness 1498.1895599136803
# Generation 988: Min Fitness 1498.1895599136803
# Generation 989: Min Fitness 1498.1895599136803
# Generation 990: Min Fitness 1498.1895599136803
# Generation 991: Min Fitness 1498.1895599136803
# Generation 992: Min Fitness 1498.1895599136803
# Generation 993: Min Fitness 1498.1895599136803
# Generation 994: Min Fitness 1498.1895599136803
# Generation 995: Min Fitness 1498.1895599136803
# Generation 996: Min Fitness 1498.1895599136803
# Generation 997: Min Fitness 1498.1895599136803
# Generation 998: Min Fitness 1498.1895599136803
# Generation 999: Min Fitness 1498.1895599136803

# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance, graph_draw
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt
from multiprocessing import Pool

# 读取图和位置信息　グラフと位置情報を読み取る
filename1 = "Germany50"
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance


# 将图转换为个体编码　グラフを個体エンコードに変換する
def graph_to_individual(graph):
    num_vertices = graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual


# 将个体解码为图并计算边权重属性　個体をグラフにデコードし、エッジの重みを計算する
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights


# 计算两条线段是否相交的函数
def is_intersect(p1, p2, q1, q2):
    def ccw(A, B, C):
        return (C[1] - A[1]) * (B[0] - A[0]) > (B[1] - A[1]) * (C[0] - A[0])

    return ccw(p1, q1, q2) != ccw(p2, q1, q2) and ccw(p1, p2, q1) != ccw(p1, p2, q2)


# 定义适应度函数　適応度関数を定義する
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, read_graph.num_vertices())
    num_edges = graph.num_edges()
    if num_edges != 69:  # 边数限制，确保边数为69
        return float('inf'),  # 如果边数不为69，适应度设为无穷大

    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])

    # 计算边交叉的惩罚项
    edge_list = [(e.source(), e.target()) for e in graph.edges()]
    cross_count = 0
    for i in range(len(edge_list)):
        for j in range(i + 1, len(edge_list)):
            e1, e2 = edge_list[i], edge_list[j]
            p1, p2 = read_pos[e1[0]], read_pos[e1[1]]
            q1, q2 = read_pos[e2[0]], read_pos[e2[1]]
            if is_intersect(p1, p2, q1, q2):
                cross_count += 1

    # 将交叉的数量添加到总距离中作为惩罚
    total_distance += cross_count * 1000  # 乘以一个大数以增加惩罚力度

    return total_distance,


# 自定义交叉操作　交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        num_vertices = int(np.sqrt(len(individual)))
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > 69:
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - 69)
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < 69:
            # 添加缺失的边
            missing_edges = random.sample(non_edges, 69 - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2


# 自定义变异操作　変異操作
def mutGraph(ind):
    size = int(np.sqrt(len(ind)))
    edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 1]
    non_edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 0]

    if edges and non_edges:
        # 移除一条边　エッジを削除する
        i, j = random.choice(edges)
        ind[i * size + j] = 0
        ind[j * size + i] = 0

        # 添加一条边　エッジを追加する
        i, j = random.choice(non_edges)
        ind[i * size + j] = 1
        ind[j * size + i] = 1

    return ind,


# 遗传算法设置　遺伝的アルゴリズムの設定
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)


# 初始化个体时确保边数为69　初期個体を初期化する際にエッジ数を69に確保する
def initIndividual():
    num_vertices = read_graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], 69)
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)


toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)


# 主遗传算法流程　メイン遺伝的アルゴリズムフロー
def main():
    pool = Pool()
    toolbox.register("map", pool.map)

    pop = toolbox.population(n=300)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(1000):
        pop, _ = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=1, stats=stats, halloffame=hof,
                                     verbose=False)
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)
        print(f"Generation {gen}: Min Fitness {record['min']}")

    pool.close()
    pool.join()

    return pop, logbook, hof


if __name__ == "__main__":
    pop, logbook, hof = main()
    best_individual = hof[0]
    best_graph, _ = individual_to_graph(best_individual, read_graph.num_vertices())

    # 为每个节点标上对应的序号
    vertex_text = best_graph.new_vertex_property("string")
    for v in best_graph.vertices():
        vertex_text[v] = str(int(v))

    # 绘制最终优化后的图
    graph_draw(best_graph, read_pos, vertex_text=vertex_text, edge_color='blue', output_size=(1000, 1000))

    # 绘制适应度值随迭代次数变化的图表
    min_fitness_values = logbook.select("min")
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(min_fitness_values)), min_fitness_values, marker='o', linestyle='-', color='b')
    plt.title("Fitness Value over Generations")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.grid(True)
    plt.savefig("fitness_over_generations.png")
    plt.show()
# Out:
# nodes:  50 links  69
# Generation 0: Min Fitness 440556.0281053509
# Generation 1: Min Fitness 427235.5870256676
# Generation 2: Min Fitness 427204.3256772567
# Generation 3: Min Fitness 407923.76083682245
# Generation 4: Min Fitness 398738.1930312254
# Generation 5: Min Fitness 323400.5954780998
# Generation 6: Min Fitness 311469.8058674552
# Generation 7: Min Fitness 311469.8058674552
# Generation 8: Min Fitness 297280.0440287009
# Generation 9: Min Fitness 297280.0440287009
# Generation 10: Min Fitness 293483.9330380309
# Generation 11: Min Fitness 287109.78893341543
# Generation 12: Min Fitness 282422.6000674141
# Generation 13: Min Fitness 279279.59369654255
# Generation 14: Min Fitness 279279.59369654255
# Generation 15: Min Fitness 266445.2569181859
# Generation 16: Min Fitness 259516.180726537
# Generation 17: Min Fitness 246175.73176232874
# Generation 18: Min Fitness 232167.83953766734
# Generation 19: Min Fitness 225248.61656302624
# Generation 20: Min Fitness 225248.61656302624
# Generation 21: Min Fitness 215069.5173350645
# Generation 22: Min Fitness 213701.6226831664
# Generation 23: Min Fitness 211035.0053276529
# Generation 24: Min Fitness 204600.1270420235
# Generation 25: Min Fitness 201244.38567340808
# Generation 26: Min Fitness 193101.1800278129
# Generation 27: Min Fitness 185095.93365165617
# Generation 28: Min Fitness 174054.9800244639
# Generation 29: Min Fitness 174054.9800244639
# Generation 30: Min Fitness 173088.35433972283
# Generation 31: Min Fitness 166007.0428648769
# Generation 32: Min Fitness 161855.3848410827
# Generation 33: Min Fitness 160986.3643886192
# Generation 34: Min Fitness 155781.20385574707
# Generation 35: Min Fitness 153682.607861359
# Generation 36: Min Fitness 147748.58560332033
# Generation 37: Min Fitness 146240.8965195613
# Generation 38: Min Fitness 145725.7191212541
# Generation 39: Min Fitness 140825.1463557863
# Generation 40: Min Fitness 137734.07068004625
# Generation 41: Min Fitness 136942.7046528819
# Generation 42: Min Fitness 134671.39731120673
# Generation 43: Min Fitness 121860.41254182276
# Generation 44: Min Fitness 118647.33834707784
# Generation 45: Min Fitness 118867.49951594257
# Generation 46: Min Fitness 118867.49951594257
# Generation 47: Min Fitness 117818.36288749646
# Generation 48: Min Fitness 115668.48271396317
# Generation 49: Min Fitness 112848.96481416035
# Generation 50: Min Fitness 108885.81209266886
# Generation 51: Min Fitness 106467.54432649014
# Generation 52: Min Fitness 99779.87703196489
# Generation 53: Min Fitness 99779.87703196489
# Generation 54: Min Fitness 97718.92143912539
# Generation 55: Min Fitness 97805.22320402447
# Generation 56: Min Fitness 92549.25672722324
# Generation 57: Min Fitness 92549.25672722324
# Generation 58: Min Fitness 92549.25672722324
# Generation 59: Min Fitness 92641.40815543802
# Generation 60: Min Fitness 86567.31931832453
# Generation 61: Min Fitness 86567.31931832453
# Generation 62: Min Fitness 86567.31931832453
# Generation 63: Min Fitness 84613.63782218109
# Generation 64: Min Fitness 82873.9486209815
# Generation 65: Min Fitness 82675.26710719777
# Generation 66: Min Fitness 78947.83356207154
# Generation 67: Min Fitness 76788.02285206501
# Generation 68: Min Fitness 74679.83148504028
# Generation 69: Min Fitness 69613.49972320381
# Generation 70: Min Fitness 68708.35767044238
# Generation 71: Min Fitness 68708.35767044238
# Generation 72: Min Fitness 67570.18157167175
# Generation 73: Min Fitness 65664.9229470163
# Generation 74: Min Fitness 63736.46584629921
# Generation 75: Min Fitness 65597.22953779704
# Generation 76: Min Fitness 65569.26323175314
# Generation 77: Min Fitness 62769.23226133822
# Generation 78: Min Fitness 61665.92408158111
# Generation 79: Min Fitness 62755.041563471554
# Generation 80: Min Fitness 60498.6533206327
# Generation 81: Min Fitness 57444.03124389302
# Generation 82: Min Fitness 55497.808186399874
# Generation 83: Min Fitness 53645.716448051026
# Generation 84: Min Fitness 53645.716448051026
# Generation 85: Min Fitness 53456.21705773466
# Generation 86: Min Fitness 49704.20864577534
# Generation 87: Min Fitness 48827.54137538532
# Generation 88: Min Fitness 47828.86927212657
# Generation 89: Min Fitness 46700.43673505229
# Generation 90: Min Fitness 44735.656132513956
# Generation 91: Min Fitness 44391.198965722935
# Generation 92: Min Fitness 44617.97675481883
# Generation 93: Min Fitness 43603.18771967016
# Generation 94: Min Fitness 41726.27355876772
# Generation 95: Min Fitness 42422.358637080404
# Generation 96: Min Fitness 39746.5543290339
# Generation 97: Min Fitness 41760.49089514773
# Generation 98: Min Fitness 40530.021327209375
# Generation 99: Min Fitness 38702.388414384506
# Generation 100: Min Fitness 33470.04393645232
# Generation 101: Min Fitness 33487.34868708259
# Generation 102: Min Fitness 33487.34868708259
# Generation 103: Min Fitness 33462.371967333034
# Generation 104: Min Fitness 32480.53057019877
# Generation 105: Min Fitness 32480.53057019877
# Generation 106: Min Fitness 32480.53057019877
# Generation 107: Min Fitness 32480.53057019877
# Generation 108: Min Fitness 32433.722243589556
# Generation 109: Min Fitness 31463.152146239194
# Generation 110: Min Fitness 30593.302608153914
# Generation 111: Min Fitness 30525.655461780294
# Generation 112: Min Fitness 29456.399330534463
# Generation 113: Min Fitness 29456.399330534463
# Generation 114: Min Fitness 28473.46308540352
# Generation 115: Min Fitness 28505.67647496523
# Generation 116: Min Fitness 28548.919579266643
# Generation 117: Min Fitness 27561.297156823053
# Generation 118: Min Fitness 27621.074947559995
# Generation 119: Min Fitness 27401.4984342654
# Generation 120: Min Fitness 25608.856160764743
# Generation 121: Min Fitness 26471.874650373626
# Generation 122: Min Fitness 26471.874650373626
# Generation 123: Min Fitness 25470.26885317907
# Generation 124: Min Fitness 24543.50795055174
# Generation 125: Min Fitness 24435.339263611088
# Generation 126: Min Fitness 23569.470582313596
# Generation 127: Min Fitness 21584.32681672286
# Generation 128: Min Fitness 21584.32681672286
# Generation 129: Min Fitness 21584.32681672286
# Generation 130: Min Fitness 21584.32681672286
# Generation 131: Min Fitness 21584.32681672286
# Generation 132: Min Fitness 21539.08701012372
# Generation 133: Min Fitness 20559.8707153156
# Generation 134: Min Fitness 20505.19532573073
# Generation 135: Min Fitness 20469.017557366933
# Generation 136: Min Fitness 18527.340552808022
# Generation 137: Min Fitness 18549.783543793128
# Generation 138: Min Fitness 18549.783543793128
# Generation 139: Min Fitness 18549.783543793128
# Generation 140: Min Fitness 18505.89922921409
# Generation 141: Min Fitness 17641.31757394795
# Generation 142: Min Fitness 16529.76153657
# Generation 143: Min Fitness 16521.48612124016
# Generation 144: Min Fitness 16445.289608135005
# Generation 145: Min Fitness 15509.48367976514
# Generation 146: Min Fitness 15573.0951113156
# Generation 147: Min Fitness 15573.0951113156
# Generation 148: Min Fitness 14595.788506078148
# Generation 149: Min Fitness 14544.080857802299
# Generation 150: Min Fitness 14534.224659209638
# Generation 151: Min Fitness 14534.224659209638
# Generation 152: Min Fitness 13556.910698958642
# Generation 153: Min Fitness 12651.943313886002
# Generation 154: Min Fitness 12624.148322309522
# Generation 155: Min Fitness 12624.148322309522
# Generation 156: Min Fitness 11651.14274490654
# Generation 157: Min Fitness 11610.442049353522
# Generation 158: Min Fitness 10654.52248257557
# Generation 159: Min Fitness 10654.52248257557
# Generation 160: Min Fitness 10643.894125125746
# Generation 161: Min Fitness 10608.893323278131
# Generation 162: Min Fitness 9699.08087630117
# Generation 163: Min Fitness 8692.215886361337
# Generation 164: Min Fitness 8692.215886361337
# Generation 165: Min Fitness 8636.82927222321
# Generation 166: Min Fitness 8636.82927222321
# Generation 167: Min Fitness 8636.82927222321
# Generation 168: Min Fitness 7669.515831804261
# Generation 169: Min Fitness 7669.515831804261
# Generation 170: Min Fitness 7628.5414004396125
# Generation 171: Min Fitness 6738.219564542196
# Generation 172: Min Fitness 6496.725896509697
# Generation 173: Min Fitness 6496.725896509697
# Generation 174: Min Fitness 6496.725896509697
# Generation 175: Min Fitness 6496.725896509697
# Generation 176: Min Fitness 5567.41845056395
# Generation 177: Min Fitness 5567.41845056395
# Generation 178: Min Fitness 5534.44831765352
# Generation 179: Min Fitness 5518.737807218777
# Generation 180: Min Fitness 5502.236520188537
# Generation 181: Min Fitness 5502.236520188537
# Generation 182: Min Fitness 4591.45352451022
# Generation 183: Min Fitness 4483.428919611098
# Generation 184: Min Fitness 4483.428919611098
# Generation 185: Min Fitness 4483.428919611098
# Generation 186: Min Fitness 4483.428919611098
# Generation 187: Min Fitness 3554.6811900563107
# Generation 188: Min Fitness 3554.6811900563107
# Generation 189: Min Fitness 3486.2458450212575
# Generation 190: Min Fitness 3486.2458450212575
# Generation 191: Min Fitness 3486.2458450212575
# Generation 192: Min Fitness 2581.544716950496
# Generation 193: Min Fitness 3466.820548228107
# Generation 194: Min Fitness 3466.820548228107
# Generation 195: Min Fitness 2556.9664588982796
# Generation 196: Min Fitness 2556.9664588982796
# Generation 197: Min Fitness 2556.9664588982796
# Generation 198: Min Fitness 3406.4262222345305
# Generation 199: Min Fitness 3406.4262222345305
# Generation 200: Min Fitness 3400.818668871685
# Generation 201: Min Fitness 2481.4657268414285
# Generation 202: Min Fitness 2481.4657268414285
# Generation 203: Min Fitness 2467.580082760684
# Generation 204: Min Fitness 2467.580082760684
# Generation 205: Min Fitness 2467.580082760684
# Generation 206: Min Fitness 2467.580082760684
# Generation 207: Min Fitness 2467.580082760684
# Generation 208: Min Fitness 2467.580082760684
# Generation 209: Min Fitness 2467.580082760684
# Generation 210: Min Fitness 2467.580082760684
# Generation 211: Min Fitness 2467.580082760684
# Generation 212: Min Fitness 2467.580082760684
# Generation 213: Min Fitness 2467.580082760684
# Generation 214: Min Fitness 2414.8002771531346
# Generation 215: Min Fitness 2414.8002771531346
# Generation 216: Min Fitness 2401.404790122101
# Generation 217: Min Fitness 2401.404790122101
# Generation 218: Min Fitness 2401.404790122101
# Generation 219: Min Fitness 2390.851856288049
# Generation 220: Min Fitness 2390.450491421003
# Generation 221: Min Fitness 2336.1631514830033
# Generation 222: Min Fitness 2336.1631514830033
# Generation 223: Min Fitness 2336.1631514830033
# Generation 224: Min Fitness 2336.1631514830033
# Generation 225: Min Fitness 2336.1631514830033
# Generation 226: Min Fitness 2325.6102176489508
# Generation 227: Min Fitness 2325.2088527819046
# Generation 228: Min Fitness 2325.2088527819046
# Generation 229: Min Fitness 2325.2088527819046
# Generation 230: Min Fitness 2325.2088527819046
# Generation 231: Min Fitness 2325.2088527819046
# Generation 232: Min Fitness 2325.2088527819046
# Generation 233: Min Fitness 2325.2088527819046
# Generation 234: Min Fitness 2325.2088527819046
# Generation 235: Min Fitness 2322.942501728417
# Generation 236: Min Fitness 2319.8917019604646
# Generation 237: Min Fitness 2290.850726310489
# Generation 238: Min Fitness 2290.850726310489
# Generation 239: Min Fitness 2290.850726310489
# Generation 240: Min Fitness 2290.850726310489
# Generation 241: Min Fitness 2290.850726310489
# Generation 242: Min Fitness 2268.859196339313
# Generation 243: Min Fitness 2266.466967866576
# Generation 244: Min Fitness 2255.3309104573086
# Generation 245: Min Fitness 2255.3309104573086
# Generation 246: Min Fitness 2255.3309104573086
# Generation 247: Min Fitness 2238.835935655928
# Generation 248: Min Fitness 2216.407444632583
# Generation 249: Min Fitness 2216.407444632583
# Generation 250: Min Fitness 2209.6674445711988
# Generation 251: Min Fitness 2209.6674445711988
# Generation 252: Min Fitness 2209.6674445711988
# Generation 253: Min Fitness 2183.8932403056187
# Generation 254: Min Fitness 2183.8932403056187
# Generation 255: Min Fitness 2168.8021912203712
# Generation 256: Min Fitness 2161.0273230333746
# Generation 257: Min Fitness 2157.098665552205
# Generation 258: Min Fitness 2155.527565882681
# Generation 259: Min Fitness 2155.527565882681
# Generation 260: Min Fitness 2153.389461363224
# Generation 261: Min Fitness 2143.084200087871
# Generation 262: Min Fitness 2145.883605206708
# Generation 263: Min Fitness 2142.806724419942
# Generation 264: Min Fitness 2142.806724419942
# Generation 265: Min Fitness 2138.0626894311117
# Generation 266: Min Fitness 2137.1368746851967
# Generation 267: Min Fitness 2137.1368746851967
# Generation 268: Min Fitness 2132.751472574818
# Generation 269: Min Fitness 2132.751472574818
# Generation 270: Min Fitness 2075.256290103111
# Generation 271: Min Fitness 2104.443544174067
# Generation 272: Min Fitness 2104.443544174067
# Generation 273: Min Fitness 2104.443544174067
# Generation 274: Min Fitness 2104.443544174067
# Generation 275: Min Fitness 2104.443544174067
# Generation 276: Min Fitness 2080.0486327492517
# Generation 277: Min Fitness 2025.2031086513025
# Generation 278: Min Fitness 2025.2031086513025
# Generation 279: Min Fitness 2025.2031086513025
# Generation 280: Min Fitness 2025.2031086513025
# Generation 281: Min Fitness 2025.2031086513025
# Generation 282: Min Fitness 2018.0548234711996
# Generation 283: Min Fitness 2013.2639108811431
# Generation 284: Min Fitness 2010.2283736088366
# Generation 285: Min Fitness 2010.2283736088366
# Generation 286: Min Fitness 2010.2283736088366
# Generation 287: Min Fitness 2003.3091503921446
# Generation 288: Min Fitness 2004.2672516774992
# Generation 289: Min Fitness 2001.6965676187847
# Generation 290: Min Fitness 2001.6965676187847
# Generation 291: Min Fitness 1980.2463762714065
# Generation 292: Min Fitness 1959.9466497242604
# Generation 293: Min Fitness 1956.5710350322893
# Generation 294: Min Fitness 1959.9466497242604
# Generation 295: Min Fitness 1956.163276193357
# Generation 296: Min Fitness 1953.580721735189
# Generation 297: Min Fitness 1953.580721735189
# Generation 298: Min Fitness 1946.3372465391406
# Generation 299: Min Fitness 1945.2149420018545
# Generation 300: Min Fitness 1937.7471529384263
# Generation 301: Min Fitness 1937.7471529384263
# Generation 302: Min Fitness 1937.7471529384263
# Generation 303: Min Fitness 1935.4679449404243
# Generation 304: Min Fitness 1937.7471529384263
# Generation 305: Min Fitness 1928.6029592987422
# Generation 306: Min Fitness 1925.0884314254254
# Generation 307: Min Fitness 1923.7803500393097
# Generation 308: Min Fitness 1920.6438795169292
# Generation 309: Min Fitness 1920.5024308466936
# Generation 310: Min Fitness 1916.7583680938933
# Generation 311: Min Fitness 1915.6078096541523
# Generation 312: Min Fitness 1916.7583680938933
# Generation 313: Min Fitness 1916.5030069337304
# Generation 314: Min Fitness 1911.608385741189
# Generation 315: Min Fitness 1911.608385741189
# Generation 316: Min Fitness 1823.316978979447
# Generation 317: Min Fitness 1823.316978979447
# Generation 318: Min Fitness 1815.137144584849
# Generation 319: Min Fitness 1815.137144584849
# Generation 320: Min Fitness 1811.40594730957
# Generation 321: Min Fitness 1807.8851248670078
# Generation 322: Min Fitness 1807.8851248670078
# Generation 323: Min Fitness 1807.6080422291402
# Generation 324: Min Fitness 1807.6080422291402
# Generation 325: Min Fitness 1807.6080422291402
# Generation 326: Min Fitness 1807.6080422291402
# Generation 327: Min Fitness 1803.2953414426484
# Generation 328: Min Fitness 1803.2953414426484
# Generation 329: Min Fitness 1773.9415330775437
# Generation 330: Min Fitness 1773.9415330775437
# Generation 331: Min Fitness 1773.9415330775437
# Generation 332: Min Fitness 1773.9415330775437
# Generation 333: Min Fitness 1773.9415330775437
# Generation 334: Min Fitness 1766.6862963732665
# Generation 335: Min Fitness 1766.6862963732665
# Generation 336: Min Fitness 1766.6862963732665
# Generation 337: Min Fitness 1766.6862963732665
# Generation 338: Min Fitness 1749.1273095396477
# Generation 339: Min Fitness 1749.1273095396477
# Generation 340: Min Fitness 1749.1273095396477
# Generation 341: Min Fitness 1744.133804237192
# Generation 342: Min Fitness 1739.2982814639884
# Generation 343: Min Fitness 1729.8018871890667
# Generation 344: Min Fitness 1729.8018871890667
# Generation 345: Min Fitness 1729.8018871890667
# Generation 346: Min Fitness 1729.8018871890667
# Generation 347: Min Fitness 1729.8018871890667
# Generation 348: Min Fitness 1729.8018871890667
# Generation 349: Min Fitness 1725.4527068259633
# Generation 350: Min Fitness 1725.4527068259633
# Generation 351: Min Fitness 1725.4527068259633
# Generation 352: Min Fitness 1722.9309488281303
# Generation 353: Min Fitness 1713.9601353635876
# Generation 354: Min Fitness 1713.9601353635876
# Generation 355: Min Fitness 1713.9601353635876
# Generation 356: Min Fitness 1710.541153377852
# Generation 357: Min Fitness 1710.541153377852
# Generation 358: Min Fitness 1710.541153377852
# Generation 359: Min Fitness 1710.50522283785
# Generation 360: Min Fitness 1710.50522283785
# Generation 361: Min Fitness 1710.50522283785
# Generation 362: Min Fitness 1710.50522283785
# Generation 363: Min Fitness 1703.2758932791635
# Generation 364: Min Fitness 1703.1100589698565
# Generation 365: Min Fitness 1703.1100589698565
# Generation 366: Min Fitness 1691.3496007605022
# Generation 367: Min Fitness 1685.4027761774946
# Generation 368: Min Fitness 1685.4027761774946
# Generation 369: Min Fitness 1685.4027761774946
# Generation 370: Min Fitness 1685.4027761774946
# Generation 371: Min Fitness 1685.0939099342083
# Generation 372: Min Fitness 1684.1006114751674
# Generation 373: Min Fitness 1673.8977648394743
# Generation 374: Min Fitness 1673.8977648394743
# Generation 375: Min Fitness 1673.8977648394743
# Generation 376: Min Fitness 1673.8977648394743
# Generation 377: Min Fitness 1670.1699292546718
# Generation 378: Min Fitness 1670.1699292546718
# Generation 379: Min Fitness 1670.1699292546718
# Generation 380: Min Fitness 1670.1699292546718
# Generation 381: Min Fitness 1670.1699292546718
# Generation 382: Min Fitness 1669.0286863114966
# Generation 383: Min Fitness 1664.3197871486445
# Generation 384: Min Fitness 1664.386432652393
# Generation 385: Min Fitness 1664.386432652393
# Generation 386: Min Fitness 1664.386432652393
# Generation 387: Min Fitness 1664.386432652393
# Generation 388: Min Fitness 1664.386432652393
# Generation 389: Min Fitness 1661.6131738813174
# Generation 390: Min Fitness 1661.6131738813174
# Generation 391: Min Fitness 1661.6131738813174
# Generation 392: Min Fitness 1661.6131738813174
# Generation 393: Min Fitness 1661.6131738813174
# Generation 394: Min Fitness 1661.6131738813174
# Generation 395: Min Fitness 1660.6818733873706
# Generation 396: Min Fitness 1660.6818733873706
# Generation 397: Min Fitness 1660.6818733873706
# Generation 398: Min Fitness 1660.6818733873706
# Generation 399: Min Fitness 1660.6818733873706
# Generation 400: Min Fitness 1660.6818733873706
# Generation 401: Min Fitness 1660.6818733873706
# Generation 402: Min Fitness 1660.6818733873706
# Generation 403: Min Fitness 1638.0543962413005
# Generation 404: Min Fitness 1638.0543962413005
# Generation 405: Min Fitness 1638.0543962413005
# Generation 406: Min Fitness 1638.0543962413005
# Generation 407: Min Fitness 1637.1958643061305
# Generation 408: Min Fitness 1633.402054982576
# Generation 409: Min Fitness 1633.402054982576
# Generation 410: Min Fitness 1628.8488117926634
# Generation 411: Min Fitness 1628.8488117926634
# Generation 412: Min Fitness 1628.5467632492628
# Generation 413: Min Fitness 1628.5467632492628
# Generation 414: Min Fitness 1627.7189622265728
# Generation 415: Min Fitness 1627.7189622265728
# Generation 416: Min Fitness 1627.7189622265728
# Generation 417: Min Fitness 1627.7189622265728
# Generation 418: Min Fitness 1627.7189622265728
# Generation 419: Min Fitness 1622.7275379623832
# Generation 420: Min Fitness 1620.548975626001
# Generation 421: Min Fitness 1620.411685875445
# Generation 422: Min Fitness 1620.411685875445
# Generation 423: Min Fitness 1620.411685875445
# Generation 424: Min Fitness 1619.4294874258276
# Generation 425: Min Fitness 1619.4294874258276
# Generation 426: Min Fitness 1619.4294874258276
# Generation 427: Min Fitness 1607.7532266421406
# Generation 428: Min Fitness 1615.1480930863192
# Generation 429: Min Fitness 1615.1480930863192
# Generation 430: Min Fitness 1615.1480930863192
# Generation 431: Min Fitness 1615.1480930863192
# Generation 432: Min Fitness 1615.1480930863192
# Generation 433: Min Fitness 1615.1480930863192
# Generation 434: Min Fitness 1615.1480930863192
# Generation 435: Min Fitness 1615.1480930863192
# Generation 436: Min Fitness 1615.1480930863192
# Generation 437: Min Fitness 1615.1480930863192
# Generation 438: Min Fitness 1615.1480930863192
# Generation 439: Min Fitness 1615.1480930863192
# Generation 440: Min Fitness 1615.0616565173425
# Generation 441: Min Fitness 1615.0616565173425
# Generation 442: Min Fitness 1615.0616565173425
# Generation 443: Min Fitness 1615.0616565173425
# Generation 444: Min Fitness 1615.0616565173425
# Generation 445: Min Fitness 1615.0616565173425
# Generation 446: Min Fitness 1615.0616565173425
# Generation 447: Min Fitness 1615.0616565173425
# Generation 448: Min Fitness 1615.0616565173425
# Generation 449: Min Fitness 1615.0616565173425
# Generation 450: Min Fitness 1615.0616565173425
# Generation 451: Min Fitness 1615.0616565173425
# Generation 452: Min Fitness 1615.0616565173425
# Generation 453: Min Fitness 1615.0616565173425
# Generation 454: Min Fitness 1615.0616565173425
# Generation 455: Min Fitness 1615.0616565173425
# Generation 456: Min Fitness 1615.0616565173425
# Generation 457: Min Fitness 1615.0616565173425
# Generation 458: Min Fitness 1615.0616565173425
# Generation 459: Min Fitness 1615.0616565173425
# Generation 460: Min Fitness 1615.0616565173425
# Generation 461: Min Fitness 1612.8453517058742
# Generation 462: Min Fitness 1612.8453517058742
# Generation 463: Min Fitness 1612.8453517058742
# Generation 464: Min Fitness 1612.8453517058742
# Generation 465: Min Fitness 1611.3941635994313
# Generation 466: Min Fitness 1611.3941635994313
# Generation 467: Min Fitness 1611.3941635994313
# Generation 468: Min Fitness 1611.3941635994313
# Generation 469: Min Fitness 1611.3941635994313
# Generation 470: Min Fitness 1611.3941635994313
# Generation 471: Min Fitness 1611.3941635994313
# Generation 472: Min Fitness 1610.9863857749328
# Generation 473: Min Fitness 1610.9863857749328
# Generation 474: Min Fitness 1610.9863857749328
# Generation 475: Min Fitness 1610.9863857749328
# Generation 476: Min Fitness 1610.9863857749328
# Generation 477: Min Fitness 1610.9863857749328
# Generation 478: Min Fitness 1594.0486647321293
# Generation 479: Min Fitness 1594.0486647321293
# Generation 480: Min Fitness 1594.0486647321293
# Generation 481: Min Fitness 1594.0486647321293
# Generation 482: Min Fitness 1594.0486647321293
# Generation 483: Min Fitness 1594.0486647321293
# Generation 484: Min Fitness 1594.0486647321293
# Generation 485: Min Fitness 1594.0486647321293
# Generation 486: Min Fitness 1594.0486647321293
# Generation 487: Min Fitness 1591.8007805204984
# Generation 488: Min Fitness 1591.8007805204984
# Generation 489: Min Fitness 1591.8007805204984
# Generation 490: Min Fitness 1587.1185234385098
# Generation 491: Min Fitness 1591.8007805204984
# Generation 492: Min Fitness 1584.3111488209024
# Generation 493: Min Fitness 1584.3111488209024
# Generation 494: Min Fitness 1584.3111488209024
# Generation 495: Min Fitness 1584.3111488209024
# Generation 496: Min Fitness 1584.3111488209024
# Generation 497: Min Fitness 1584.3111488209024
# Generation 498: Min Fitness 1584.3111488209024
# Generation 499: Min Fitness 1584.3111488209024
# Generation 500: Min Fitness 1582.8641009175278
# Generation 501: Min Fitness 1582.8641009175278
# Generation 502: Min Fitness 1582.253546329304
# Generation 503: Min Fitness 1582.253546329304
# Generation 504: Min Fitness 1582.253546329304
# Generation 505: Min Fitness 1582.253546329304
# Generation 506: Min Fitness 1575.086816344523
# Generation 507: Min Fitness 1575.086816344523
# Generation 508: Min Fitness 1575.086816344523
# Generation 509: Min Fitness 1575.086816344523
# Generation 510: Min Fitness 1574.2978427989456
# Generation 511: Min Fitness 1574.0735060400225
# Generation 512: Min Fitness 1574.0735060400225
# Generation 513: Min Fitness 1574.0735060400225
# Generation 514: Min Fitness 1573.22104321466
# Generation 515: Min Fitness 1573.22104321466
# Generation 516: Min Fitness 1573.22104321466
# Generation 517: Min Fitness 1571.5722663094793
# Generation 518: Min Fitness 1571.5722663094793
# Generation 519: Min Fitness 1571.5722663094793
# Generation 520: Min Fitness 1571.5722663094793
# Generation 521: Min Fitness 1571.5722663094793
# Generation 522: Min Fitness 1571.5722663094793
# Generation 523: Min Fitness 1566.7682492712702
# Generation 524: Min Fitness 1566.7682492712702
# Generation 525: Min Fitness 1566.7682492712702
# Generation 526: Min Fitness 1566.7682492712702
# Generation 527: Min Fitness 1566.7682492712702
# Generation 528: Min Fitness 1566.7682492712702
# Generation 529: Min Fitness 1566.7682492712702
# Generation 530: Min Fitness 1564.1795186829104
# Generation 531: Min Fitness 1564.1795186829104
# Generation 532: Min Fitness 1564.1795186829104
# Generation 533: Min Fitness 1564.1795186829104
# Generation 534: Min Fitness 1564.1795186829104
# Generation 535: Min Fitness 1564.1795186829104
# Generation 536: Min Fitness 1564.1795186829104
# Generation 537: Min Fitness 1564.1795186829104
# Generation 538: Min Fitness 1564.1795186829104
# Generation 539: Min Fitness 1564.1795186829104
# Generation 540: Min Fitness 1564.1795186829104
# Generation 541: Min Fitness 1564.1795186829104
# Generation 542: Min Fitness 1564.1795186829104
# Generation 543: Min Fitness 1564.1795186829104
# Generation 544: Min Fitness 1562.4581601571517
# Generation 545: Min Fitness 1562.4581601571517
# Generation 546: Min Fitness 1562.4581601571517
# Generation 547: Min Fitness 1562.4581601571517
# Generation 548: Min Fitness 1562.4581601571517
# Generation 549: Min Fitness 1562.4581601571517
# Generation 550: Min Fitness 1562.4581601571517
# Generation 551: Min Fitness 1562.4581601571517
# Generation 552: Min Fitness 1562.4581601571517
# Generation 553: Min Fitness 1562.4581601571517
# Generation 554: Min Fitness 1556.441703233295
# Generation 555: Min Fitness 1556.441703233295
# Generation 556: Min Fitness 1556.441703233295
# Generation 557: Min Fitness 1556.441703233295
# Generation 558: Min Fitness 1556.441703233295
# Generation 559: Min Fitness 1556.441703233295
# Generation 560: Min Fitness 1556.441703233295
# Generation 561: Min Fitness 1556.441703233295
# Generation 562: Min Fitness 1556.441703233295
# Generation 563: Min Fitness 1556.441703233295
# Generation 564: Min Fitness 1556.441703233295
# Generation 565: Min Fitness 1556.441703233295
# Generation 566: Min Fitness 1556.441703233295
# Generation 567: Min Fitness 1556.441703233295
# Generation 568: Min Fitness 1556.441703233295
# Generation 569: Min Fitness 1556.441703233295
# Generation 570: Min Fitness 1556.441703233295
# Generation 571: Min Fitness 1556.441703233295
# Generation 572: Min Fitness 1556.441703233295
# Generation 573: Min Fitness 1556.441703233295
# Generation 574: Min Fitness 1556.441703233295
# Generation 575: Min Fitness 1556.441703233295
# Generation 576: Min Fitness 1556.441703233295
# Generation 577: Min Fitness 1556.441703233295
# Generation 578: Min Fitness 1556.441703233295
# Generation 579: Min Fitness 1556.441703233295
# Generation 580: Min Fitness 1556.441703233295
# Generation 581: Min Fitness 1556.441703233295
# Generation 582: Min Fitness 1556.441703233295
# Generation 583: Min Fitness 1556.441703233295
# Generation 584: Min Fitness 1556.441703233295
# Generation 585: Min Fitness 1556.441703233295
# Generation 586: Min Fitness 1556.441703233295
# Generation 587: Min Fitness 1556.441703233295
# Generation 588: Min Fitness 1556.441703233295
# Generation 589: Min Fitness 1556.441703233295
# Generation 590: Min Fitness 1556.441703233295
# Generation 591: Min Fitness 1556.441703233295
# Generation 592: Min Fitness 1555.6997352811823
# Generation 593: Min Fitness 1555.6997352811823
# Generation 594: Min Fitness 1555.6997352811823
# Generation 595: Min Fitness 1555.6997352811823
# Generation 596: Min Fitness 1555.6997352811823
# Generation 597: Min Fitness 1555.6997352811823
# Generation 598: Min Fitness 1555.6997352811823
# Generation 599: Min Fitness 1555.6997352811823
# Generation 600: Min Fitness 1555.6997352811823
# Generation 601: Min Fitness 1555.6997352811823
# Generation 602: Min Fitness 1553.4538125169668
# Generation 603: Min Fitness 1545.4979178978701
# Generation 604: Min Fitness 1553.4538125169668
# Generation 605: Min Fitness 1553.4538125169668
# Generation 606: Min Fitness 1553.4538125169668
# Generation 607: Min Fitness 1553.4538125169668
# Generation 608: Min Fitness 1553.4538125169668
# Generation 609: Min Fitness 1552.1764123730168
# Generation 610: Min Fitness 1552.1764123730168
# Generation 611: Min Fitness 1552.1764123730168
# Generation 612: Min Fitness 1553.0657875676152
# Generation 613: Min Fitness 1553.0657875676152
# Generation 614: Min Fitness 1553.0657875676152
# Generation 615: Min Fitness 1553.0657875676152
# Generation 616: Min Fitness 1549.4027942080847
# Generation 617: Min Fitness 1549.4027942080847
# Generation 618: Min Fitness 1549.4027942080847
# Generation 619: Min Fitness 1549.4027942080847
# Generation 620: Min Fitness 1549.4027942080847
# Generation 621: Min Fitness 1549.4027942080847
# Generation 622: Min Fitness 1549.4027942080847
# Generation 623: Min Fitness 1549.4027942080847
# Generation 624: Min Fitness 1549.3806330728858
# Generation 625: Min Fitness 1549.3806330728858
# Generation 626: Min Fitness 1549.3806330728858
# Generation 627: Min Fitness 1549.3806330728858
# Generation 628: Min Fitness 1549.3806330728858
# Generation 629: Min Fitness 1549.3806330728858
# Generation 630: Min Fitness 1549.3806330728858
# Generation 631: Min Fitness 1543.085823451987
# Generation 632: Min Fitness 1543.085823451987
# Generation 633: Min Fitness 1543.085823451987
# Generation 634: Min Fitness 1543.085823451987
# Generation 635: Min Fitness 1543.085823451987
# Generation 636: Min Fitness 1543.085823451987
# Generation 637: Min Fitness 1538.998106356713
# Generation 638: Min Fitness 1538.998106356713
# Generation 639: Min Fitness 1538.998106356713
# Generation 640: Min Fitness 1538.998106356713
# Generation 641: Min Fitness 1538.998106356713
# Generation 642: Min Fitness 1538.998106356713
# Generation 643: Min Fitness 1538.998106356713
# Generation 644: Min Fitness 1538.998106356713
# Generation 645: Min Fitness 1538.998106356713
# Generation 646: Min Fitness 1538.998106356713
# Generation 647: Min Fitness 1538.998106356713
# Generation 648: Min Fitness 1538.998106356713
# Generation 649: Min Fitness 1538.998106356713
# Generation 650: Min Fitness 1538.998106356713
# Generation 651: Min Fitness 1538.998106356713
# Generation 652: Min Fitness 1538.998106356713
# Generation 653: Min Fitness 1538.998106356713
# Generation 654: Min Fitness 1538.998106356713
# Generation 655: Min Fitness 1538.998106356713
# Generation 656: Min Fitness 1538.998106356713
# Generation 657: Min Fitness 1538.998106356713
# Generation 658: Min Fitness 1538.998106356713
# Generation 659: Min Fitness 1538.998106356713
# Generation 660: Min Fitness 1538.998106356713
# Generation 661: Min Fitness 1538.998106356713
# Generation 662: Min Fitness 1538.998106356713
# Generation 663: Min Fitness 1538.998106356713
# Generation 664: Min Fitness 1538.998106356713
# Generation 665: Min Fitness 1538.998106356713
# Generation 666: Min Fitness 1538.998106356713
# Generation 667: Min Fitness 1538.998106356713
# Generation 668: Min Fitness 1538.998106356713
# Generation 669: Min Fitness 1538.998106356713
# Generation 670: Min Fitness 1538.998106356713
# Generation 671: Min Fitness 1538.998106356713
# Generation 672: Min Fitness 1538.998106356713
# Generation 673: Min Fitness 1538.998106356713
# Generation 674: Min Fitness 1538.998106356713
# Generation 675: Min Fitness 1538.998106356713
# Generation 676: Min Fitness 1538.998106356713
# Generation 677: Min Fitness 1538.998106356713
# Generation 678: Min Fitness 1538.998106356713
# Generation 679: Min Fitness 1538.998106356713
# Generation 680: Min Fitness 1538.998106356713
# Generation 681: Min Fitness 1538.998106356713
# Generation 682: Min Fitness 1538.998106356713
# Generation 683: Min Fitness 1538.998106356713
# Generation 684: Min Fitness 1538.998106356713
# Generation 685: Min Fitness 1538.998106356713
# Generation 686: Min Fitness 1538.998106356713
# Generation 687: Min Fitness 1538.998106356713
# Generation 688: Min Fitness 1538.998106356713
# Generation 689: Min Fitness 1538.998106356713
# Generation 690: Min Fitness 1538.998106356713
# Generation 691: Min Fitness 1538.998106356713
# Generation 692: Min Fitness 1538.998106356713
# Generation 693: Min Fitness 1538.998106356713
# Generation 694: Min Fitness 1538.998106356713
# Generation 695: Min Fitness 1538.998106356713
# Generation 696: Min Fitness 1538.998106356713
# Generation 697: Min Fitness 1538.998106356713
# Generation 698: Min Fitness 1538.998106356713
# Generation 699: Min Fitness 1538.998106356713
# Generation 700: Min Fitness 1538.998106356713
# Generation 701: Min Fitness 1538.998106356713
# Generation 702: Min Fitness 1538.998106356713
# Generation 703: Min Fitness 1538.998106356713
# Generation 704: Min Fitness 1538.998106356713
# Generation 705: Min Fitness 1538.998106356713
# Generation 706: Min Fitness 1538.998106356713
# Generation 707: Min Fitness 1538.998106356713
# Generation 708: Min Fitness 1538.998106356713
# Generation 709: Min Fitness 1538.998106356713
# Generation 710: Min Fitness 1538.998106356713
# Generation 711: Min Fitness 1538.998106356713
# Generation 712: Min Fitness 1538.998106356713
# Generation 713: Min Fitness 1538.998106356713
# Generation 714: Min Fitness 1538.998106356713
# Generation 715: Min Fitness 1538.998106356713
# Generation 716: Min Fitness 1538.998106356713
# Generation 717: Min Fitness 1538.998106356713
# Generation 718: Min Fitness 1538.998106356713
# Generation 719: Min Fitness 1538.998106356713
# Generation 720: Min Fitness 1538.998106356713
# Generation 721: Min Fitness 1538.998106356713
# Generation 722: Min Fitness 1538.998106356713
# Generation 723: Min Fitness 1538.998106356713
# Generation 724: Min Fitness 1538.998106356713
# Generation 725: Min Fitness 1538.998106356713
# Generation 726: Min Fitness 1538.998106356713
# Generation 727: Min Fitness 1538.998106356713
# Generation 728: Min Fitness 1538.998106356713
# Generation 729: Min Fitness 1531.718238105117
# Generation 730: Min Fitness 1531.718238105117
# Generation 731: Min Fitness 1531.718238105117
# Generation 732: Min Fitness 1531.718238105117
# Generation 733: Min Fitness 1531.718238105117
# Generation 734: Min Fitness 1531.718238105117
# Generation 735: Min Fitness 1531.718238105117
# Generation 736: Min Fitness 1531.718238105117
# Generation 737: Min Fitness 1531.718238105117
# Generation 738: Min Fitness 1531.718238105117
# Generation 739: Min Fitness 1531.718238105117
# Generation 740: Min Fitness 1531.718238105117
# Generation 741: Min Fitness 1531.718238105117
# Generation 742: Min Fitness 1531.718238105117
# Generation 743: Min Fitness 1531.718238105117
# Generation 744: Min Fitness 1531.718238105117
# Generation 745: Min Fitness 1531.718238105117
# Generation 746: Min Fitness 1531.718238105117
# Generation 747: Min Fitness 1531.718238105117
# Generation 748: Min Fitness 1531.718238105117
# Generation 749: Min Fitness 1531.718238105117
# Generation 750: Min Fitness 1531.718238105117
# Generation 751: Min Fitness 1531.718238105117
# Generation 752: Min Fitness 1531.718238105117
# Generation 753: Min Fitness 1531.718238105117
# Generation 754: Min Fitness 1531.718238105117
# Generation 755: Min Fitness 1531.718238105117
# Generation 756: Min Fitness 1531.718238105117
# Generation 757: Min Fitness 1531.718238105117
# Generation 758: Min Fitness 1531.718238105117
# Generation 759: Min Fitness 1531.718238105117
# Generation 760: Min Fitness 1531.718238105117
# Generation 761: Min Fitness 1531.718238105117
# Generation 762: Min Fitness 1531.718238105117
# Generation 763: Min Fitness 1531.718238105117
# Generation 764: Min Fitness 1531.718238105117
# Generation 765: Min Fitness 1531.718238105117
# Generation 766: Min Fitness 1531.718238105117
# Generation 767: Min Fitness 1531.718238105117
# Generation 768: Min Fitness 1531.718238105117
# Generation 769: Min Fitness 1531.718238105117
# Generation 770: Min Fitness 1531.718238105117
# Generation 771: Min Fitness 1531.718238105117
# Generation 772: Min Fitness 1531.718238105117
# Generation 773: Min Fitness 1531.718238105117
# Generation 774: Min Fitness 1531.718238105117
# Generation 775: Min Fitness 1531.718238105117
# Generation 776: Min Fitness 1531.718238105117
# Generation 777: Min Fitness 1531.718238105117
# Generation 778: Min Fitness 1531.718238105117
# Generation 779: Min Fitness 1531.718238105117
# Generation 780: Min Fitness 1531.718238105117
# Generation 781: Min Fitness 1531.718238105117
# Generation 782: Min Fitness 1531.718238105117
# Generation 783: Min Fitness 1531.718238105117
# Generation 784: Min Fitness 1531.718238105117
# Generation 785: Min Fitness 1531.718238105117
# Generation 786: Min Fitness 1531.718238105117
# Generation 787: Min Fitness 1528.4791829519445
# Generation 788: Min Fitness 1528.4791829519445
# Generation 789: Min Fitness 1528.4791829519445
# Generation 790: Min Fitness 1528.4791829519445
# Generation 791: Min Fitness 1528.4791829519445
# Generation 792: Min Fitness 1528.4791829519445
# Generation 793: Min Fitness 1528.4791829519445
# Generation 794: Min Fitness 1528.4791829519445
# Generation 795: Min Fitness 1528.4791829519445
# Generation 796: Min Fitness 1528.4791829519445
# Generation 797: Min Fitness 1528.4791829519445
# Generation 798: Min Fitness 1528.4791829519445
# Generation 799: Min Fitness 1528.4791829519445
# Generation 800: Min Fitness 1528.4791829519445
# Generation 801: Min Fitness 1528.4791829519445
# Generation 802: Min Fitness 1528.4791829519445
# Generation 803: Min Fitness 1528.4791829519445
# Generation 804: Min Fitness 1528.4791829519445
# Generation 805: Min Fitness 1528.4791829519445
# Generation 806: Min Fitness 1528.4791829519445
# Generation 807: Min Fitness 1528.4791829519445
# Generation 808: Min Fitness 1528.4791829519445
# Generation 809: Min Fitness 1528.4791829519445
# Generation 810: Min Fitness 1528.4791829519445
# Generation 811: Min Fitness 1528.4791829519445
# Generation 812: Min Fitness 1528.4791829519445
# Generation 813: Min Fitness 1528.4791829519445
# Generation 814: Min Fitness 1528.4791829519445
# Generation 815: Min Fitness 1528.4791829519445
# Generation 816: Min Fitness 1528.4791829519445
# Generation 817: Min Fitness 1528.4791829519445
# Generation 818: Min Fitness 1528.4791829519445
# Generation 819: Min Fitness 1528.4791829519445
# Generation 820: Min Fitness 1528.4791829519445
# Generation 821: Min Fitness 1528.4791829519445
# Generation 822: Min Fitness 1528.4791829519445
# Generation 823: Min Fitness 1528.4791829519445
# Generation 824: Min Fitness 1528.4791829519445
# Generation 825: Min Fitness 1528.4791829519445
# Generation 826: Min Fitness 1528.4791829519445
# Generation 827: Min Fitness 1528.4791829519445
# Generation 828: Min Fitness 1528.4791829519445
# Generation 829: Min Fitness 1528.4791829519445
# Generation 830: Min Fitness 1528.4791829519445
# Generation 831: Min Fitness 1528.4791829519445
# Generation 832: Min Fitness 1528.4791829519445
# Generation 833: Min Fitness 1528.4791829519445
# Generation 834: Min Fitness 1528.4791829519445
# Generation 835: Min Fitness 1528.4791829519445
# Generation 836: Min Fitness 1528.4791829519445
# Generation 837: Min Fitness 1528.4791829519445
# Generation 838: Min Fitness 1528.4791829519445
# Generation 839: Min Fitness 1528.4791829519445
# Generation 840: Min Fitness 1528.4791829519445
# Generation 841: Min Fitness 1528.4791829519445
# Generation 842: Min Fitness 1528.4791829519445
# Generation 843: Min Fitness 1528.4791829519445
# Generation 844: Min Fitness 1527.7508984530336
# Generation 845: Min Fitness 1527.7508984530336
# Generation 846: Min Fitness 1527.7508984530336
# Generation 847: Min Fitness 1527.7508984530336
# Generation 848: Min Fitness 1527.7508984530336
# Generation 849: Min Fitness 1527.7027140825448
# Generation 850: Min Fitness 1527.7027140825448
# Generation 851: Min Fitness 1527.7027140825448
# Generation 852: Min Fitness 1527.7027140825448
# Generation 853: Min Fitness 1527.7027140825448
# Generation 854: Min Fitness 1527.7027140825448
# Generation 855: Min Fitness 1527.7027140825448
# Generation 856: Min Fitness 1520.8983822819241
# Generation 857: Min Fitness 1520.8983822819241
# Generation 858: Min Fitness 1520.8983822819241
# Generation 859: Min Fitness 1520.8983822819241
# Generation 860: Min Fitness 1520.8983822819241
# Generation 861: Min Fitness 1520.8983822819241
# Generation 862: Min Fitness 1520.8983822819241
# Generation 863: Min Fitness 1520.8983822819241
# Generation 864: Min Fitness 1520.8983822819241
# Generation 865: Min Fitness 1520.8983822819241
# Generation 866: Min Fitness 1520.8983822819241
# Generation 867: Min Fitness 1520.8983822819241
# Generation 868: Min Fitness 1520.8983822819241
# Generation 869: Min Fitness 1520.8983822819241
# Generation 870: Min Fitness 1520.8983822819241
# Generation 871: Min Fitness 1520.8983822819241
# Generation 872: Min Fitness 1520.8983822819241
# Generation 873: Min Fitness 1520.8983822819241
# Generation 874: Min Fitness 1520.8983822819241
# Generation 875: Min Fitness 1520.8983822819241
# Generation 876: Min Fitness 1520.8983822819241
# Generation 877: Min Fitness 1520.8983822819241
# Generation 878: Min Fitness 1520.8983822819241
# Generation 879: Min Fitness 1520.8983822819241
# Generation 880: Min Fitness 1520.1747942954294
# Generation 881: Min Fitness 1520.1747942954294
# Generation 882: Min Fitness 1520.1747942954294
# Generation 883: Min Fitness 1520.1747942954294
# Generation 884: Min Fitness 1520.1747942954294
# Generation 885: Min Fitness 1520.1747942954294
# Generation 886: Min Fitness 1520.1622705302227
# Generation 887: Min Fitness 1520.1622705302227
# Generation 888: Min Fitness 1520.1622705302227
# Generation 889: Min Fitness 1520.1622705302227
# Generation 890: Min Fitness 1520.1622705302227
# Generation 891: Min Fitness 1520.1622705302227
# Generation 892: Min Fitness 1520.1622705302227
# Generation 893: Min Fitness 1520.1622705302227
# Generation 894: Min Fitness 1520.1622705302227
# Generation 895: Min Fitness 1520.1622705302227
# Generation 896: Min Fitness 1520.1622705302227
# Generation 897: Min Fitness 1520.1622705302227
# Generation 898: Min Fitness 1520.1622705302227
# Generation 899: Min Fitness 1520.1622705302227
# Generation 900: Min Fitness 1520.1622705302227
# Generation 901: Min Fitness 1520.1622705302227
# Generation 902: Min Fitness 1520.1622705302227
# Generation 903: Min Fitness 1520.1622705302227
# Generation 904: Min Fitness 1520.1622705302227
# Generation 905: Min Fitness 1520.1622705302227
# Generation 906: Min Fitness 1520.1622705302227
# Generation 907: Min Fitness 1520.1622705302227
# Generation 908: Min Fitness 1519.2296327934564
# Generation 909: Min Fitness 1519.2296327934564
# Generation 910: Min Fitness 1519.2296327934564
# Generation 911: Min Fitness 1519.2296327934564
# Generation 912: Min Fitness 1519.2296327934564
# Generation 913: Min Fitness 1519.2296327934564
# Generation 914: Min Fitness 1518.9527422306383
# Generation 915: Min Fitness 1518.9527422306383
# Generation 916: Min Fitness 1518.9527422306383
# Generation 917: Min Fitness 1518.9527422306383
# Generation 918: Min Fitness 1518.7550223691474
# Generation 919: Min Fitness 1518.7400577261317
# Generation 920: Min Fitness 1517.5629673912724
# Generation 921: Min Fitness 1517.5629673912724
# Generation 922: Min Fitness 1517.5629673912724
# Generation 923: Min Fitness 1517.5629673912724
# Generation 924: Min Fitness 1517.5629673912724
# Generation 925: Min Fitness 1517.5629673912724
# Generation 926: Min Fitness 1517.5629673912724
# Generation 927: Min Fitness 1517.5629673912724
# Generation 928: Min Fitness 1517.5629673912724
# Generation 929: Min Fitness 1517.5629673912724
# Generation 930: Min Fitness 1517.5629673912724
# Generation 931: Min Fitness 1517.5629673912724
# Generation 932: Min Fitness 1517.5629673912724
# Generation 933: Min Fitness 1517.5629673912724
# Generation 934: Min Fitness 1517.5629673912724
# Generation 935: Min Fitness 1517.5629673912724
# Generation 936: Min Fitness 1517.5629673912724
# Generation 937: Min Fitness 1517.5629673912724
# Generation 938: Min Fitness 1517.5629673912724
# Generation 939: Min Fitness 1517.5629673912724
# Generation 940: Min Fitness 1517.5629673912724
# Generation 941: Min Fitness 1517.5629673912724
# Generation 942: Min Fitness 1517.5629673912724
# Generation 943: Min Fitness 1517.5629673912724
# Generation 944: Min Fitness 1517.5629673912724
# Generation 945: Min Fitness 1517.5629673912724
# Generation 946: Min Fitness 1517.5629673912724
# Generation 947: Min Fitness 1517.5629673912724
# Generation 948: Min Fitness 1517.5629673912724
# Generation 949: Min Fitness 1517.5629673912724
# Generation 950: Min Fitness 1517.5629673912724
# Generation 951: Min Fitness 1517.5629673912724
# Generation 952: Min Fitness 1517.5629673912724
# Generation 953: Min Fitness 1517.5629673912724
# Generation 954: Min Fitness 1517.5629673912724
# Generation 955: Min Fitness 1517.5629673912724
# Generation 956: Min Fitness 1517.5629673912724
# Generation 957: Min Fitness 1517.5629673912724
# Generation 958: Min Fitness 1517.5629673912724
# Generation 959: Min Fitness 1517.5629673912724
# Generation 960: Min Fitness 1516.8147051284095
# Generation 961: Min Fitness 1516.8147051284095
# Generation 962: Min Fitness 1516.8147051284095
# Generation 963: Min Fitness 1516.8147051284095
# Generation 964: Min Fitness 1516.8147051284095
# Generation 965: Min Fitness 1516.8147051284095
# Generation 966: Min Fitness 1516.8147051284095
# Generation 967: Min Fitness 1516.8147051284095
# Generation 968: Min Fitness 1516.8147051284095
# Generation 969: Min Fitness 1516.8147051284095
# Generation 970: Min Fitness 1516.8147051284095
# Generation 971: Min Fitness 1516.8147051284095
# Generation 972: Min Fitness 1516.8147051284095
# Generation 973: Min Fitness 1516.8147051284095
# Generation 974: Min Fitness 1516.8147051284095
# Generation 975: Min Fitness 1516.8147051284095
# Generation 976: Min Fitness 1516.8147051284095
# Generation 977: Min Fitness 1516.8147051284095
# Generation 978: Min Fitness 1516.8147051284095
# Generation 979: Min Fitness 1516.8147051284095
# Generation 980: Min Fitness 1516.8147051284095
# Generation 981: Min Fitness 1516.8147051284095
# Generation 982: Min Fitness 1516.8147051284095
# Generation 983: Min Fitness 1516.8147051284095
# Generation 984: Min Fitness 1516.8147051284095
# Generation 985: Min Fitness 1516.8147051284095
# Generation 986: Min Fitness 1516.8147051284095
# Generation 987: Min Fitness 1516.8147051284095
# Generation 988: Min Fitness 1516.8147051284095
# Generation 989: Min Fitness 1516.8147051284095
# Generation 990: Min Fitness 1516.8147051284095
# Generation 991: Min Fitness 1516.8147051284095
# Generation 992: Min Fitness 1516.8147051284095
# Generation 993: Min Fitness 1516.8147051284095
# Generation 994: Min Fitness 1516.8147051284095
# Generation 995: Min Fitness 1516.8147051284095
# Generation 996: Min Fitness 1516.8147051284095
# Generation 997: Min Fitness 1516.8147051284095
# Generation 998: Min Fitness 1516.8147051284095
# Generation 999: Min Fitness 1516.8147051284095

# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance, graph_draw
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt
from scoop import futures

# 读取图和位置信息　グラフと位置情報を読み取る
filename1 = "Germany50"
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

num_vertices = read_graph.num_vertices()
num_edges = read_graph.num_edges()

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance


# 将图转换为个体编码　グラフを個体エンコードに変換する
def graph_to_individual(graph):
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual


# 将个体解码为图并计算边权重属性　個体をグラフにデコードし、エッジの重みを計算する
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights


# 计算两条线段是否相交的函数
def is_intersect(p1, p2, q1, q2):
    def ccw(A, B, C):
        return (C[1] - A[1]) * (B[0] - A[0]) > (B[1] - A[1]) * (C[0] - A[0])

    return ccw(p1, q1, q2) != ccw(p2, q1, q2) and ccw(p1, p2, q1) != ccw(p1, p2, q2)


# 定义适应度函数　適応度関数を定義する
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, num_vertices)
    num_edges = graph.num_edges()
    if num_edges != read_graph.num_edges():  # 动态边数限制，确保边数与原图相同
        return float('inf'),  # 如果边数不相同，适应度设为无穷大

    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])

    # 计算边交叉的惩罚项
    edge_list = [(e.source(), e.target()) for e in graph.edges()]
    cross_count = 0
    for i in range(len(edge_list)):
        for j in range(i + 1, len(edge_list)):
            e1, e2 = edge_list[i], edge_list[j]
            p1, p2 = read_pos[e1[0]], read_pos[e1[1]]
            q1, q2 = read_pos[e2[0]], read_pos[e2[1]]
            if is_intersect(p1, p2, q1, q2):
                cross_count += 1

    # 将交叉的数量添加到总距离中作为惩罚
    total_distance += cross_count * 1000  # 乘以一个大数以增加惩罚力度

    return total_distance,


# 自定义交叉操作　交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > read_graph.num_edges():
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - read_graph.num_edges())
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < read_graph.num_edges():
            # 添加缺失的边
            missing_edges = random.sample(non_edges, read_graph.num_edges() - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2


# 自定义变异操作　変異操作
def mutGraph(ind):
    edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if ind[i * num_vertices + j] == 1]
    non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if ind[i * num_vertices + j] == 0]

    if edges and non_edges:
        # 移除一条边　エッジを削除する
        i, j = random.choice(edges)
        ind[i * num_vertices + j] = 0
        ind[j * num_vertices + i] = 0

        # 添加一条边　エッジを追加する
        i, j = random.choice(non_edges)
        ind[i * num_vertices + j] = 1
        ind[j * num_vertices + i] = 1

    return ind,


# 遗传算法设置　遺伝的アルゴリズムの設定
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)

# 初始化个体时确保边数与原图相同　初期個体を初期化する際にエッジ数を原図と同じに確保する
def initIndividual():
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], read_graph.num_edges())
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)

toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)

# 使用scoop进行并行计算
toolbox.register("map", futures.map)

# 主遗传算法流程　メイン遺伝的アルゴリズムフロー
def main():
    pop = toolbox.population(n=300)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(100):
        pop, _ = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=1, stats=stats, halloffame=hof, verbose=False)
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)
        print(f"Generation {gen}: Min Fitness {record['min']}")

    return pop, logbook, hof


if __name__ == "__main__":
    pop, logbook, hof = main()
    best_individual = hof[0]
    best_graph, _ = individual_to_graph(best_individual, num_vertices)

    # 为每个节点标上对应的序号
    vertex_text = best_graph.new_vertex_property("string")
    for v in best_graph.vertices():
        vertex_text[v] = str(int(v))

    # 绘制最终优化后的图
    graph_draw(best_graph, read_pos, vertex_text=vertex_text, edge_color='blue', output_size=(1000, 1000))

    # 绘制适应度值随迭代次数变化的图表
    min_fitness_values = logbook.select("min")
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(min_fitness_values)), min_fitness_values, marker='o', linestyle='-', color='b')
    plt.title("Fitness Value over Generations")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.grid(True)
    plt.savefig("fitness_over_generations.png")
    plt.show()
# Out:
# nodes:  50 links  69
# /home/huanghanjun/anaconda3/envs/graph-tool/lib/python3.12/site-packages/scoop/fallbacks.py:38: RuntimeWarning: SCOOP was not started properly.
# Be sure to start your program with the '-m scoop' parameter. You can find further information in the documentation.
# Your map call has been replaced by the builtin serial Python map().
#   warnings.warn(
# /home/huanghanjun/anaconda3/envs/graph-tool/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Generation 0: Min Fitness 448769.0314718864
# Generation 1: Min Fitness 448769.0314718864
# Generation 2: Min Fitness 425772.1189311496
# Generation 3: Min Fitness 406565.2835911069
# Generation 4: Min Fitness 398183.76982077403
# Generation 5: Min Fitness 377178.4455742571
# Generation 6: Min Fitness 372299.4543342225
# Generation 7: Min Fitness 364909.3361921231
# Generation 8: Min Fitness 342645.9511662416
# Generation 9: Min Fitness 342645.9511662416
# Generation 10: Min Fitness 338234.5189654399
# Generation 11: Min Fitness 326373.628157264
# Generation 12: Min Fitness 309850.78488175716
# Generation 13: Min Fitness 307725.0449361438
# Generation 14: Min Fitness 288725.7725993913
# Generation 15: Min Fitness 253558.73293288107
# Generation 16: Min Fitness 246479.62452754015
# Generation 17: Min Fitness 243447.73985081402
# Generation 18: Min Fitness 238547.17508220067
# Generation 19: Min Fitness 225258.12031000343
# Generation 20: Min Fitness 225258.12031000343
# Generation 21: Min Fitness 208125.03381939448
# Generation 22: Min Fitness 206488.93430404706
# Generation 23: Min Fitness 206488.93430404706
# Generation 24: Min Fitness 201380.86108402716
# Generation 25: Min Fitness 195144.72059972686
# Generation 26: Min Fitness 193533.78626919177
# Generation 27: Min Fitness 183458.20131440667
# Generation 28: Min Fitness 183458.20131440667
# Generation 29: Min Fitness 179481.221285198
# Generation 30: Min Fitness 176556.06025068377
# Generation 31: Min Fitness 167498.2805188816
# Generation 32: Min Fitness 171464.15299261388
# Generation 33: Min Fitness 164367.1468242425
# Generation 34: Min Fitness 161527.04495012222
# Generation 35: Min Fitness 159581.1085167233
# Generation 36: Min Fitness 152683.33201092947
# Generation 37: Min Fitness 150113.77358166556
# Generation 38: Min Fitness 147285.57600687924
# Generation 39: Min Fitness 139292.44327450215
# Generation 40: Min Fitness 134967.9573267788
# Generation 41: Min Fitness 131109.42723297168
# Generation 42: Min Fitness 131109.42723297168
# Generation 43: Min Fitness 126278.95462725786
# Generation 44: Min Fitness 126278.95462725786
# Generation 45: Min Fitness 124114.22701984999
# Generation 46: Min Fitness 120902.64586685282
# Generation 47: Min Fitness 118202.50431653483
# Generation 48: Min Fitness 113053.67698565152
# Generation 49: Min Fitness 110047.00163364233
# Generation 50: Min Fitness 110047.00163364233
# Generation 51: Min Fitness 108050.34478837681
# Generation 52: Min Fitness 106990.09704751566
# Generation 53: Min Fitness 101227.95218362653
# Generation 54: Min Fitness 101227.95218362653
# Generation 55: Min Fitness 94934.70337234513
# Generation 56: Min Fitness 94934.70337234513
# Generation 57: Min Fitness 93902.8519360915
# Generation 58: Min Fitness 94934.70337234513
# Generation 59: Min Fitness 92945.3884574896
# Generation 60: Min Fitness 90803.93066633282
# Generation 61: Min Fitness 90803.93066633282
# Generation 62: Min Fitness 90084.78588014623
# Generation 63: Min Fitness 85753.24621961503
# Generation 64: Min Fitness 85621.60210141083
# Generation 65: Min Fitness 79846.75852908021
# Generation 66: Min Fitness 79846.75852908021
# Generation 67: Min Fitness 79846.75852908021
# Generation 68: Min Fitness 76804.23376673805
# Generation 69: Min Fitness 69125.45110026993
# Generation 70: Min Fitness 67960.5377764624
# Generation 71: Min Fitness 67960.5377764624
# Generation 72: Min Fitness 69125.45110026993
# Generation 73: Min Fitness 68865.34173856923
# Generation 74: Min Fitness 68133.87367379059
# Generation 75: Min Fitness 61724.14497534891
# Generation 76: Min Fitness 61724.14497534891
# Generation 77: Min Fitness 61724.14497534891
# Generation 78: Min Fitness 60184.40088806316
# Generation 79: Min Fitness 56643.22625163047
# Generation 80: Min Fitness 56643.22625163047
# Generation 81: Min Fitness 56643.22625163047
# Generation 82: Min Fitness 55743.73310426164
# Generation 83: Min Fitness 53933.955558333095
# Generation 84: Min Fitness 51773.06916800994
# Generation 85: Min Fitness 48881.31177427093
# Generation 86: Min Fitness 51549.12927913235
# Generation 87: Min Fitness 48907.879738448
# Generation 88: Min Fitness 47804.19269176
# Generation 89: Min Fitness 46694.22838610503
# Generation 90: Min Fitness 42799.06598954581
# Generation 91: Min Fitness 42799.06598954581
# Generation 92: Min Fitness 42799.06598954581
# Generation 93: Min Fitness 41187.28572861965
# Generation 94: Min Fitness 40613.403129597165
# Generation 95: Min Fitness 40613.403129597165
# Generation 96: Min Fitness 40613.403129597165
# Generation 97: Min Fitness 40532.02664627144
# Generation 98: Min Fitness 39563.479348979236
# Generation 99: Min Fitness 39563.479348979236
