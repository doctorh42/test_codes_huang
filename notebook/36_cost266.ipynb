# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance, graph_draw
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor, as_completed
from fractions import Fraction
from tqdm.notebook import tqdm
import pickle  # 用于保存和读取文件
import os

# 读取图和位置信息
filename1 = "cost266"  # 更改为你的文件名
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
num_edges = read_graph.num_edges()
print("nodes: ", read_graph.num_vertices(), "links ", num_edges)

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance

# 将图转换为个体编码
def graph_to_individual(graph):
    num_vertices = graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual

# 将个体解码为图并计算边权重属性
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights

# 定义适应度函数
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, read_graph.num_vertices())
    num_edges = graph.num_edges()
    if num_edges != read_graph.num_edges():  # 边数限制，确保边数为文件中边的数量
        return float('inf'),  # 如果边数不为文件中边的数量，适应度设为无穷大
    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])
    return total_distance,

# 自定义交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        num_vertices = int(np.sqrt(len(individual)))
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > num_edges:
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - num_edges)
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < num_edges:
            # 添加缺失的边
            missing_edges = random.sample(non_edges, num_edges - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2

# 自定义变异操作
def mutGraph(ind):
    size = int(np.sqrt(len(ind)))
    edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 1]
    non_edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 0]

    if edges and non_edges:
        # 移除一条边
        i, j = random.choice(edges)
        ind[i * size + j] = 0
        ind[j * size + i] = 0

        # 添加一条边
        i, j = random.choice(non_edges)
        ind[i * size + j] = 1
        ind[j * size + i] = 1

    return ind,

# 遗传算法设置
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)

# 初始化个体时确保边数为文件中的边数量
def initIndividual():
    num_vertices = read_graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], num_edges)
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)

toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)

# 保存初始种群
def save_population(population, filename):
    with open(filename, 'wb') as f:
        pickle.dump(population, f)

# 读取初始种群
def load_population(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 主遗传算法流程
def main(population_size, selection_ratio, mutpb, initial_population, pbar):
    num_selected = int(population_size * selection_ratio)
    num_offspring = population_size - num_selected
    num_generations = 10  # 设定总迭代次数
    cxpb = 0.5  # 交叉概率

    # 使用固定的初始种群
    pop = initial_population[:]
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(num_generations):
        # 选择操作
        selected = toolbox.select(pop, num_selected)

        # 生成新的个体
        offspring = algorithms.varAnd(selected, toolbox, cxpb, mutpb)
        offspring = offspring[:num_offspring]

        # 组合父代和新生成的个体，形成新的种群
        pop[:] = selected + offspring

        # 评估新的种群
        fitnesses = list(map(toolbox.evaluate, pop))
        for ind, fit in zip(pop, fitnesses):
            ind.fitness.values = fit

        # 记录和输出每一代的最优适应度值
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)

        # 更新进度条
        pbar.update(1)

        # 更新Hall of Fame
        hof.update(pop)

    # 返回最终的最优结果
    return logbook, hof[0].fitness.values[0]

# 配置参数
population_sizes = [75, 150, 300]
selection_ratios = [1 / 3, 1 / 2, 2 / 3, 3 / 4]
mutation_probs = [0.075, 0.15, 0.3]

# 初始化进度条
progress_bars = {
    pop_size: tqdm(total=12 * 10, desc=f'Population={pop_size}', position=i, leave=True)
    for i, pop_size in enumerate(population_sizes)
}

# 用于存储所有图表的最小和最大适应度值，用于后续统一设置y轴范围
all_min_values = []
all_max_values = []
initial_fitness_values = {}  # 用于存储初始适应度值
final_results = {}  # 用于存储每种情况下的最终最优结果

# 逐个运行每个种群大小的12种情况
for population_size in population_sizes:
    population_filename = f"./output_TPE/initial_population_{filename1}_{population_size}.pkl"

    # 检查是否已有保存的初始种群文件
    if os.path.exists(population_filename):
        initial_population = load_population(population_filename)
    else:
        # 生成并保存初始种群
        initial_population = toolbox.population(n=population_size)
        save_population(initial_population, population_filename)

    # 评估初始种群的适应度
    fitnesses = list(map(toolbox.evaluate, initial_population))
    initial_fitness = min(fitnesses)[0]  # 记录最小适应度
    initial_fitness_values[population_size] = initial_fitness

    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_params = {
            executor.submit(main, population_size, selection_ratio, mutpb, initial_population,
                            progress_bars[population_size]): (
                selection_ratio, mutpb)
            for selection_ratio in selection_ratios
            for mutpb in mutation_probs
        }

        logbooks = {}
        labels = {}

        for future in as_completed(future_to_params):
            selection_ratio, mutpb = future_to_params[future]
            try:
                logbook, final_fitness = future.result()  # 获取最终的最优适应度值
                logbooks[(selection_ratio, mutpb)] = logbook
                ratio_fraction = Fraction(selection_ratio).limit_denominator()
                labels[(selection_ratio, mutpb)] = f'Select={ratio_fraction}, Mutate={mutpb * 100}%'

                # 更新最小和最大适应度值
                min_fitness_values = logbook.select("min")
                if np.isfinite(min(min_fitness_values)):
                    all_min_values.append(min(min_fitness_values))
                if np.isfinite(max(min_fitness_values)):
                    all_max_values.append(max(min_fitness_values))

                # 保存最终的最优结果
                final_results[(population_size, selection_ratio, mutpb)] = final_fitness

            except Exception as ex:
                print(
                    f'Error with population_size={population_size}, selection_ratio={selection_ratio}, mutpb={mutpb}: {ex}')

# 确定统一的y轴范围
if all_min_values and all_max_values:
    y_min = min(all_min_values)
    y_max = max(all_max_values)
else:
    y_min, y_max = 0, 1  # 默认值，避免出现空图

# 重新绘制图表，确保y轴范围一致，并添加初始适应度值作为x=0点
for population_size in population_sizes:
    plt.figure(figsize=(14, 10))
    for (selection_ratio, mutpb), logbook in logbooks.items():
        min_fitness_values = logbook.select("min")
        generations = list(range(1, len(min_fitness_values) + 1))
        fitness_values = [initial_fitness_values[population_size]] + min_fitness_values  # 添加初始适应度值
        generations = [0] + generations  # x轴从0开始

        plt.plot(generations, fitness_values, label=labels[(selection_ratio, mutpb)])

    plt.title(f"Fitness Value over Generations (Population Size = {population_size})")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.legend()
    plt.grid(True)

    # 设置统一的y轴范围
    plt.ylim(y_min, y_max)

    # 保存图表
    plt.savefig(f"./output_TPE/{filename1}_fitness_over_generations_population_{population_size}.png")
    plt.show()

# 完成后关闭所有进度条
for pbar in progress_bars.values():
    pbar.close()

# 打印36种情况下的最终最优结果
print("Final optimal fitness values for each combination:")
for key, value in final_results.items():
    pop_size, select_ratio, mutate_prob = key
    print(f"Population Size: {pop_size}, Selection Ratio: {select_ratio}, Mutation Probability: {mutate_prob * 100}% - Final Fitness: {value}")
# Out:
# nodes:  37 links  46
# /home/huang/anaconda3/envs/gt/lib/python3.12/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/huang/anaconda3/envs/gt/lib/python3.12/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Population=75:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=150:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=300:   0%|          | 0/120 [00:00<?, ?it/s]
# Final optimal fitness values for each combination:
# Population Size: 75, Selection Ratio: 0.3333333333333333, Mutation Probability: 7.5% - Final Fitness: 2436.9134756844123
# Population Size: 75, Selection Ratio: 0.3333333333333333, Mutation Probability: 15.0% - Final Fitness: 2035.0345672377384
# Population Size: 75, Selection Ratio: 0.3333333333333333, Mutation Probability: 30.0% - Final Fitness: 1907.484938740416
# Population Size: 75, Selection Ratio: 0.5, Mutation Probability: 7.5% - Final Fitness: 1977.476658577601
# Population Size: 75, Selection Ratio: 0.5, Mutation Probability: 30.0% - Final Fitness: 1893.4654141431183
# Population Size: 75, Selection Ratio: 0.5, Mutation Probability: 15.0% - Final Fitness: 1832.9349486901708
# Population Size: 75, Selection Ratio: 0.6666666666666666, Mutation Probability: 7.5% - Final Fitness: 1835.2233416109893
# Population Size: 75, Selection Ratio: 0.6666666666666666, Mutation Probability: 15.0% - Final Fitness: 1894.379550781689
# Population Size: 75, Selection Ratio: 0.6666666666666666, Mutation Probability: 30.0% - Final Fitness: 1844.493805467458
# Population Size: 75, Selection Ratio: 0.75, Mutation Probability: 15.0% - Final Fitness: 1923.2575868047709
# Population Size: 75, Selection Ratio: 0.75, Mutation Probability: 7.5% - Final Fitness: 1970.1892537167378
# Population Size: 75, Selection Ratio: 0.75, Mutation Probability: 30.0% - Final Fitness: 1870.4174195567784
# Population Size: 150, Selection Ratio: 0.3333333333333333, Mutation Probability: 7.5% - Final Fitness: 2033.8858867586875
# Population Size: 150, Selection Ratio: 0.3333333333333333, Mutation Probability: 15.0% - Final Fitness: 2129.5533318976645
# Population Size: 150, Selection Ratio: 0.3333333333333333, Mutation Probability: 30.0% - Final Fitness: 1855.6224718159306
# Population Size: 150, Selection Ratio: 0.5, Mutation Probability: 7.5% - Final Fitness: 1997.5449634943118
# Population Size: 150, Selection Ratio: 0.6666666666666666, Mutation Probability: 7.5% - Final Fitness: 1965.3548057918042
# Population Size: 150, Selection Ratio: 0.5, Mutation Probability: 30.0% - Final Fitness: 1784.3742838880285
# Population Size: 150, Selection Ratio: 0.5, Mutation Probability: 15.0% - Final Fitness: 1905.9198692914176
# Population Size: 150, Selection Ratio: 0.6666666666666666, Mutation Probability: 15.0% - Final Fitness: 1823.127835151864
# Population Size: 150, Selection Ratio: 0.75, Mutation Probability: 7.5% - Final Fitness: 1900.487150809516
# Population Size: 150, Selection Ratio: 0.6666666666666666, Mutation Probability: 30.0% - Final Fitness: 1896.3703327819635
# Population Size: 150, Selection Ratio: 0.75, Mutation Probability: 15.0% - Final Fitness: 1757.181175543643
# Population Size: 150, Selection Ratio: 0.75, Mutation Probability: 30.0% - Final Fitness: 1826.9195859222004
# Population Size: 300, Selection Ratio: 0.3333333333333333, Mutation Probability: 7.5% - Final Fitness: 2098.3206579518337
# Population Size: 300, Selection Ratio: 0.3333333333333333, Mutation Probability: 30.0% - Final Fitness: 1836.0531475367366
# Population Size: 300, Selection Ratio: 0.3333333333333333, Mutation Probability: 15.0% - Final Fitness: 1872.4431919768986
# Population Size: 300, Selection Ratio: 0.5, Mutation Probability: 7.5% - Final Fitness: 1826.0112661151966
# Population Size: 300, Selection Ratio: 0.5, Mutation Probability: 30.0% - Final Fitness: 1857.411873600694
# Population Size: 300, Selection Ratio: 0.5, Mutation Probability: 15.0% - Final Fitness: 1672.6180678271007
# Population Size: 300, Selection Ratio: 0.6666666666666666, Mutation Probability: 7.5% - Final Fitness: 2202.12393720665
# Population Size: 300, Selection Ratio: 0.6666666666666666, Mutation Probability: 15.0% - Final Fitness: 1964.8540090353533
# Population Size: 300, Selection Ratio: 0.6666666666666666, Mutation Probability: 30.0% - Final Fitness: 1763.7395311905868
# Population Size: 300, Selection Ratio: 0.75, Mutation Probability: 15.0% - Final Fitness: 2075.616435919006
# Population Size: 300, Selection Ratio: 0.75, Mutation Probability: 7.5% - Final Fitness: 1869.1001185014507
# Population Size: 300, Selection Ratio: 0.75, Mutation Probability: 30.0% - Final Fitness: 1813.7923199016127

# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor, as_completed
from fractions import Fraction
from tqdm.notebook import tqdm
import pickle  # 用于保存和读取文件
import os

# 读取图和位置信息
filename1 = "cost266"  # 更改为你的文件名
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
num_edges = read_graph.num_edges()
print("nodes: ", read_graph.num_vertices(), "links ", num_edges)

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance

# 将图转换为个体编码
def graph_to_individual(graph):
    num_vertices = graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual

# 将个体解码为图并计算边权重属性
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights

# 定义适应度函数
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, read_graph.num_vertices())
    num_edges = graph.num_edges()
    if num_edges != read_graph.num_edges():  # 边数限制，确保边数为文件中边的数量
        return float('inf'),  # 如果边数不为文件中边的数量，适应度设为无穷大
    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])
    return total_distance,

# 自定义交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        num_vertices = int(np.sqrt(len(individual)))
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > num_edges:
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - num_edges)
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < num_edges:
            # 添加缺失的边
            missing_edges = random.sample(non_edges, num_edges - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2

# 自定义变异操作
def mutGraph(ind):
    size = int(np.sqrt(len(ind)))
    edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 1]
    non_edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 0]

    if edges and non_edges:
        # 移除一条边
        i, j = random.choice(edges)
        ind[i * size + j] = 0
        ind[j * size + i] = 0

        # 添加一条边
        i, j = random.choice(non_edges)
        ind[i * size + j] = 1
        ind[j * size + i] = 1

    return ind,

# 遗传算法设置
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)

# 初始化个体时确保边数为文件中的边数量
def initIndividual():
    num_vertices = read_graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], num_edges)
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)

toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)

# 保存初始种群
def save_population(population, filename):
    with open(filename, 'wb') as f:
        pickle.dump(population, f)

# 读取初始种群
def load_population(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 主遗传算法流程
def main(population_size, selection_ratio, mutpb, initial_population, pbar):
    num_selected = int(population_size * selection_ratio)
    num_offspring = population_size - num_selected
    num_generations = 10  # 设定总迭代次数
    cxpb = 0.5  # 交叉概率

    # 使用固定的初始种群
    pop = initial_population[:]
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(num_generations):
        # 选择操作
        selected = toolbox.select(pop, num_selected)

        # 生成新的个体
        offspring = algorithms.varAnd(selected, toolbox, cxpb, mutpb)
        offspring = offspring[:num_offspring]

        # 组合父代和新生成的个体，形成新的种群
        pop[:] = selected + offspring

        # 评估新的种群
        fitnesses = list(map(toolbox.evaluate, pop))
        for ind, fit in zip(pop, fitnesses):
            ind.fitness.values = fit

        # 记录和输出每一代的最优适应度值
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)

        # 更新进度条
        pbar.update(1)

        # 更新Hall of Fame
        hof.update(pop)

    # 返回最终的最优结果
    return logbook, hof[0].fitness.values[0]

# 配置参数
population_sizes = [75, 150, 300]
selection_ratios = [1 / 3, 1 / 2, 2 / 3, 3 / 4]
mutation_probs = [0.075, 0.15, 0.3]

# 初始化进度条
progress_bars = {
    pop_size: tqdm(total=12 * 10, desc=f'Population={pop_size}', position=i, leave=True)
    for i, pop_size in enumerate(population_sizes)
}

# 用于存储所有图表的最小和最大适应度值，用于后续统一设置y轴范围
all_min_values = []
all_max_values = []
initial_fitness_values = {}  # 用于存储初始适应度值
final_results = {}  # 用于存储每种情况下的最终最优结果

# 逐个运行每个种群大小的12种情况
for population_size in population_sizes:
    population_filename = f"./output_TPE/initial_population_{filename1}_{population_size}.pkl"

    # 检查是否已有保存的初始种群文件
    if os.path.exists(population_filename):
        initial_population = load_population(population_filename)
    else:
        # 生成并保存初始种群
        initial_population = toolbox.population(n=population_size)
        save_population(initial_population, population_filename)

    # 评估初始种群的适应度
    fitnesses = list(map(toolbox.evaluate, initial_population))
    initial_fitness = min(fitnesses)[0]  # 记录最小适应度
    initial_fitness_values[population_size] = initial_fitness

    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_params = {
            executor.submit(main, population_size, selection_ratio, mutpb, initial_population,
                            progress_bars[population_size]): (
                selection_ratio, mutpb)
            for selection_ratio in selection_ratios
            for mutpb in mutation_probs
        }

        logbooks = []
        labels = []

        for future in as_completed(future_to_params):
            selection_ratio, mutpb = future_to_params[future]
            try:
                logbook, final_fitness = future.result()  # 获取最终的最优适应度值
                logbooks.append((selection_ratio, mutpb, logbook))
                ratio_fraction = Fraction(selection_ratio).limit_denominator()
                labels.append(f'Select={ratio_fraction}, Mutate={mutpb * 100}%')

                # 更新最小和最大适应度值
                min_fitness_values = logbook.select("min")
                if np.isfinite(min(min_fitness_values)):
                    all_min_values.append(min(min_fitness_values))
                if np.isfinite(max(min_fitness_values)):
                    all_max_values.append(max(min_fitness_values))

                # 保存最终的最优结果
                final_results[(population_size, selection_ratio, mutpb)] = final_fitness

            except Exception as ex:
                print(
                    f'Error with population_size={population_size}, selection_ratio={selection_ratio}, mutpb={mutpb}: {ex}')

# 确定统一的y轴范围
y_min = 0  # 设置y轴的最小值为0
y_max = max(all_max_values) if all_max_values else 1  # 如果存在有效最大值，使用它，否则默认为1

# 重新绘制图表，确保y轴范围一致，并添加初始适应度值作为x=0点
for population_size in population_sizes:
    plt.figure(figsize=(14, 10))
    for (selection_ratio, mutpb, logbook) in logbooks:
        min_fitness_values = logbook.select("min")
        generations = list(range(1, len(min_fitness_values) + 1))
        fitness_values = [initial_fitness_values[population_size]] + min_fitness_values  # 添加初始适应度值
        generations = [0] + generations  # x轴从0开始

        plt.plot(generations, fitness_values, label=f'Select={Fraction(selection_ratio).limit_denominator()}, Mutate={mutpb * 100}%')

    plt.title(f"Fitness Value over Generations (Population Size = {population_size})")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.legend()
    plt.grid(True)

    # 设置统一的y轴范围，y轴最小值为0
    plt.ylim(y_min, y_max)

    # 保存图表
    plt.savefig(f"./output_TPE/{filename1}_fitness_over_generations_population_{population_size}.png")
    plt.show()

# 完成后关闭所有进度条
for pbar in progress_bars.values():
    pbar.close()

# 打印36种情况下的最终最优结果
print("Final optimal fitness values for each combination:")
for key, value in final_results.items():
    pop_size, select_ratio, mutate_prob = key
    print(f"Population Size: {pop_size}, Selection Ratio: {select_ratio}, Mutation Probability: {mutate_prob * 100}% - Final Fitness: {value}")
# Out:
# nodes:  37 links  46
# /home/huang/anaconda3/envs/gt/lib/python3.12/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/huang/anaconda3/envs/gt/lib/python3.12/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Population=75:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=150:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=300:   0%|          | 0/120 [00:00<?, ?it/s]
# Final optimal fitness values for each combination:
# Population Size: 75, Selection Ratio: 0.3333333333333333, Mutation Probability: 7.5% - Final Fitness: 1801.3098812679937
# Population Size: 75, Selection Ratio: 0.3333333333333333, Mutation Probability: 15.0% - Final Fitness: inf
# Population Size: 75, Selection Ratio: 0.3333333333333333, Mutation Probability: 30.0% - Final Fitness: 2116.500227108525
# Population Size: 75, Selection Ratio: 0.5, Mutation Probability: 7.5% - Final Fitness: 1832.4840833480532
# Population Size: 75, Selection Ratio: 0.5, Mutation Probability: 30.0% - Final Fitness: 1963.4625240663095
# Population Size: 75, Selection Ratio: 0.5, Mutation Probability: 15.0% - Final Fitness: 1616.3567963894538
# Population Size: 75, Selection Ratio: 0.6666666666666666, Mutation Probability: 7.5% - Final Fitness: 1917.1328425890536
# Population Size: 75, Selection Ratio: 0.6666666666666666, Mutation Probability: 15.0% - Final Fitness: 1911.0659145465743
# Population Size: 75, Selection Ratio: 0.6666666666666666, Mutation Probability: 30.0% - Final Fitness: 1817.184401261043
# Population Size: 75, Selection Ratio: 0.75, Mutation Probability: 7.5% - Final Fitness: 1988.58092153925
# Population Size: 75, Selection Ratio: 0.75, Mutation Probability: 15.0% - Final Fitness: 1944.548682952829
# Population Size: 75, Selection Ratio: 0.75, Mutation Probability: 30.0% - Final Fitness: 1921.8129872490504
# Population Size: 150, Selection Ratio: 0.3333333333333333, Mutation Probability: 15.0% - Final Fitness: 1763.953788597974
# Population Size: 150, Selection Ratio: 0.3333333333333333, Mutation Probability: 30.0% - Final Fitness: 2099.592101243553
# Population Size: 150, Selection Ratio: 0.3333333333333333, Mutation Probability: 7.5% - Final Fitness: 1956.8933650021554
# Population Size: 150, Selection Ratio: 0.5, Mutation Probability: 7.5% - Final Fitness: 1921.198098050405
# Population Size: 150, Selection Ratio: 0.5, Mutation Probability: 15.0% - Final Fitness: 1814.4160705149332
# Population Size: 150, Selection Ratio: 0.5, Mutation Probability: 30.0% - Final Fitness: 1856.1157236443232
# Population Size: 150, Selection Ratio: 0.6666666666666666, Mutation Probability: 7.5% - Final Fitness: 1929.4814698946236
# Population Size: 150, Selection Ratio: 0.6666666666666666, Mutation Probability: 15.0% - Final Fitness: 1963.9926099757697
# Population Size: 150, Selection Ratio: 0.6666666666666666, Mutation Probability: 30.0% - Final Fitness: 1949.156640299157
# Population Size: 150, Selection Ratio: 0.75, Mutation Probability: 7.5% - Final Fitness: 1987.1500537998647
# Population Size: 150, Selection Ratio: 0.75, Mutation Probability: 15.0% - Final Fitness: 2015.1352621496899
# Population Size: 150, Selection Ratio: 0.75, Mutation Probability: 30.0% - Final Fitness: 1776.8361288471742
# Population Size: 300, Selection Ratio: 0.3333333333333333, Mutation Probability: 15.0% - Final Fitness: 1676.2300533132968
# Population Size: 300, Selection Ratio: 0.3333333333333333, Mutation Probability: 30.0% - Final Fitness: 1858.2766438607694
# Population Size: 300, Selection Ratio: 0.3333333333333333, Mutation Probability: 7.5% - Final Fitness: 1720.306576162538
# Population Size: 300, Selection Ratio: 0.5, Mutation Probability: 7.5% - Final Fitness: 1751.664892748669
# Population Size: 300, Selection Ratio: 0.5, Mutation Probability: 30.0% - Final Fitness: 2006.6767464547002
# Population Size: 300, Selection Ratio: 0.6666666666666666, Mutation Probability: 7.5% - Final Fitness: 1808.9891732644096
# Population Size: 300, Selection Ratio: 0.5, Mutation Probability: 15.0% - Final Fitness: 1847.2617159119482
# Population Size: 300, Selection Ratio: 0.6666666666666666, Mutation Probability: 15.0% - Final Fitness: 1931.5114985615485
# Population Size: 300, Selection Ratio: 0.6666666666666666, Mutation Probability: 30.0% - Final Fitness: 1670.7989985158233
# Population Size: 300, Selection Ratio: 0.75, Mutation Probability: 15.0% - Final Fitness: 1930.3652289788538
# Population Size: 300, Selection Ratio: 0.75, Mutation Probability: 7.5% - Final Fitness: 1651.663563685126
# Population Size: 300, Selection Ratio: 0.75, Mutation Probability: 30.0% - Final Fitness: 1919.660947328108

# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor, as_completed
from fractions import Fraction
from tqdm.notebook import tqdm
import pickle
import os

# 读取图和位置信息
filename1 = "cost266"  # 更改为你的文件名
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
num_edges = read_graph.num_edges()
print("nodes: ", read_graph.num_vertices(), "links ", num_edges)

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance

# 将图转换为个体编码
def graph_to_individual(graph):
    num_vertices = graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual

# 将个体解码为图并计算边权重属性
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights

# 定义适应度函数
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, read_graph.num_vertices())
    num_edges = graph.num_edges()
    if num_edges != read_graph.num_edges():  # 边数限制，确保边数为文件中边的数量
        return float('inf'),  # 如果边数不为文件中边的数量，适应度设为无穷大
    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])
    return total_distance,

# 自定义交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        num_vertices = int(np.sqrt(len(individual)))
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > num_edges:
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - num_edges)
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < num_edges:
            # 添加缺失的边
            missing_edges = random.sample(non_edges, num_edges - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2

# 自定义变异操作
def mutGraph(ind):
    size = int(np.sqrt(len(ind)))
    edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 1]
    non_edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 0]

    if edges and non_edges:
        # 移除一条边
        i, j = random.choice(edges)
        ind[i * size + j] = 0
        ind[j * size + i] = 0

        # 添加一条边
        i, j = random.choice(non_edges)
        ind[i * size + j] = 1
        ind[j * size + i] = 1

    return ind,

# 遗传算法设置
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)

# 初始化个体时确保边数为文件中的边数量
def initIndividual():
    num_vertices = read_graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], num_edges)
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)

toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)

# 保存初始种群
def save_population(population, filename):
    with open(filename, 'wb') as f:
        pickle.dump(population, f)

# 读取初始种群
def load_population(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 保存遗传算法的迭代过程数据
def save_logbook(logbook, filename):
    with open(filename, 'wb') as f:
        pickle.dump(logbook, f)

# 主遗传算法流程
def main(population_size, selection_ratio, mutpb, initial_population, pbar, logbook_filename):
    num_selected = int(population_size * selection_ratio)
    num_offspring = population_size - num_selected
    num_generations = 10  # 设定总迭代次数
    cxpb = 0.5  # 交叉概率

    # 使用固定的初始种群
    pop = initial_population[:]
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(num_generations):
        # 选择操作
        selected = toolbox.select(pop, num_selected)

        # 生成新的个体
        offspring = algorithms.varAnd(selected, toolbox, cxpb, mutpb)
        offspring = offspring[:num_offspring]

        # 组合父代和新生成的个体，形成新的种群
        pop[:] = selected + offspring

        # 评估新的种群
        fitnesses = list(map(toolbox.evaluate, pop))
        for ind, fit in zip(pop, fitnesses):
            ind.fitness.values = fit

        # 记录和输出每一代的最优适应度值
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)

        # 更新进度条
        pbar.update(1)

        # 更新Hall of Fame
        hof.update(pop)

    # 保存logbook到文件
    save_logbook(logbook, logbook_filename)

    return logbook, hof[0].fitness.values[0]

# 配置参数
population_sizes = [75, 150, 300]
selection_ratios = [1 / 3, 1 / 2, 2 / 3, 3 / 4]
mutation_probs = [0.075, 0.15, 0.3]

# 初始化进度条
progress_bars = {
    pop_size: tqdm(total=12 * 10, desc=f'Population={pop_size}', position=i, leave=True)
    for i, pop_size in enumerate(population_sizes)
}

# 逐个运行每个种群大小的12种情况，并保存过程数据
for population_size in population_sizes:
    population_filename = f"./output_36/initial_population_{filename1}_{population_size}.pkl"
    logbook_filenames = []

    # 检查是否已有保存的初始种群文件
    if os.path.exists(population_filename):
        initial_population = load_population(population_filename)
    else:
        # 生成并保存初始种群
        initial_population = toolbox.population(n=population_size)
        save_population(initial_population, population_filename)

    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_params = {
            executor.submit(main, population_size, selection_ratio, mutpb, initial_population,
                            progress_bars[population_size], 
                            f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")): (
                selection_ratio, mutpb)
            for selection_ratio in selection_ratios
            for mutpb in mutation_probs
        }

        for future in as_completed(future_to_params):
            selection_ratio, mutpb = future_to_params[future]
            logbook_filename = f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")
            logbook_filenames.append(logbook_filename)
            try:
                _, final_fitness = future.result()
                print(f'Completed: Pop={population_size}, Select={selection_ratio}, Mutate={mutpb} - Fitness={final_fitness}')
            except Exception as ex:
                print(f'Error with Pop={population_size}, Select={selection_ratio}, Mutate={mutpb}: {ex}')

# 完成后关闭所有进度条
for pbar in progress_bars.values():
    pbar.close()

# 读取并绘制图像
def load_logbook(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 确定统一的y轴范围
def determine_y_limits(logbook_filenames):
    all_min_values = []
    all_max_values = []
    for filename in logbook_filenames:
        logbook = load_logbook(filename)
        min_fitness_values = logbook.select("min")
        if np.isfinite(min(min_fitness_values)):
            all_min_values.append(min(min_fitness_values))
        if np.isfinite(max(min_fitness_values)):
            all_max_values.append(max(min_fitness_values))
    y_min = 0
    y_max = max(all_max_values) if all_max_values else 1
    return y_min, y_max

# 绘制图像
def plot_fitness_over_generations(logbook_filenames, population_size, y_min, y_max):
    plt.figure(figsize=(14, 10))
    for filename in logbook_filenames:
        logbook = load_logbook(filename)
        min_fitness_values = logbook.select("min")
        generations = list(range(len(min_fitness_values)))

        # 获取选择率和变异率的信息来作为标签
        select_info = filename.split("_sel")[1].split("_mut")[0]
        mutate_info = filename.split("_mut")[1].split(".pkl")[0]

        plt.plot(generations, min_fitness_values, label=f'Select={select_info}, Mutate={mutate_info}%')

    plt.title(f"Fitness Value over Generations (Population Size = {population_size})")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.legend()
    plt.grid(True)

    # 设置统一的y轴范围
    plt.ylim(y_min, y_max)

    # 保存图表
    plt.savefig(f"./output_36/fitness_over_generations_population_{population_size}.png")
    plt.show()

# 读取保存的logbook文件并生成图像
for population_size in population_sizes:
    logbook_filenames = [
        f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")
        for selection_ratio in selection_ratios
        for mutpb in mutation_probs
    ]
    y_min, y_max = determine_y_limits(logbook_filenames)
    plot_fitness_over_generations(logbook_filenames, population_size, y_min, y_max)
# Out:
# nodes:  37 links  46
# Population=75:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=150:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=300:   0%|          | 0/120 [00:00<?, ?it/s]
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.3 - Fitness=2235.4601413449604
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.075 - Fitness=2137.4515596379388
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.15 - Fitness=2308.0649215307476
# Completed: Pop=75, Select=0.5, Mutate=0.075 - Fitness=2341.9196369353267
# Completed: Pop=75, Select=0.5, Mutate=0.15 - Fitness=1895.7924297391385
# Completed: Pop=75, Select=0.5, Mutate=0.3 - Fitness=2247.6616149708757
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.075 - Fitness=2027.380581292286
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.15 - Fitness=2221.57763871551
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.3 - Fitness=1832.6409562166903
# Completed: Pop=75, Select=0.75, Mutate=0.075 - Fitness=2422.697208120907
# Completed: Pop=75, Select=0.75, Mutate=0.15 - Fitness=2493.6423349795923
# Completed: Pop=75, Select=0.75, Mutate=0.3 - Fitness=2071.975378740271
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.15 - Fitness=1866.494108258338
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.3 - Fitness=1947.730848597027
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.075 - Fitness=1846.2509623404885
# Completed: Pop=150, Select=0.5, Mutate=0.075 - Fitness=1790.0910598599503
# Completed: Pop=150, Select=0.5, Mutate=0.15 - Fitness=1789.8851557498283
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.075 - Fitness=1920.3128462294328
# Completed: Pop=150, Select=0.5, Mutate=0.3 - Fitness=1742.6835388364693
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.15 - Fitness=1729.411354303817
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.3 - Fitness=1705.9368242218356
# Completed: Pop=150, Select=0.75, Mutate=0.075 - Fitness=1629.139652779323
# Completed: Pop=150, Select=0.75, Mutate=0.15 - Fitness=1786.4813216407438
# Completed: Pop=150, Select=0.75, Mutate=0.3 - Fitness=1839.3000291593987
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.15 - Fitness=1734.5251383075497
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.3 - Fitness=1662.9997462215467
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.075 - Fitness=1777.0981038763534
# Completed: Pop=300, Select=0.5, Mutate=0.075 - Fitness=1712.048507583202
# Completed: Pop=300, Select=0.5, Mutate=0.15 - Fitness=1712.687633214951
# Completed: Pop=300, Select=0.5, Mutate=0.3 - Fitness=1693.203658003439
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.075 - Fitness=1725.7902661535848
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.15 - Fitness=1698.4395762696179
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.3 - Fitness=1594.1657509796544
# Completed: Pop=300, Select=0.75, Mutate=0.075 - Fitness=1812.6249892285955
# Completed: Pop=300, Select=0.75, Mutate=0.15 - Fitness=1689.9156906728297
# Completed: Pop=300, Select=0.75, Mutate=0.3 - Fitness=1691.8002642045867

# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor, as_completed
from fractions import Fraction
from tqdm.notebook import tqdm
import pickle
import os

# 读取图和位置信息
filename1 = "cost266"  # 更改为你的文件名
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
num_edges = read_graph.num_edges()
print("nodes: ", read_graph.num_vertices(), "links ", num_edges)

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance

# 将图转换为个体编码
def graph_to_individual(graph):
    num_vertices = graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual

# 将个体解码为图并计算边权重属性
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights

# 定义适应度函数
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, read_graph.num_vertices())
    num_edges = graph.num_edges()
    if num_edges != read_graph.num_edges():  # 边数限制，确保边数为文件中边的数量
        return float('inf'),  # 如果边数不为文件中边的数量，适应度设为无穷大
    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])
    return total_distance,

# 自定义交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        num_vertices = int(np.sqrt(len(individual)))
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > num_edges:
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - num_edges)
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < num_edges:
            # 添加缺失的边
            missing_edges = random.sample(non_edges, num_edges - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2

# 自定义变异操作
def mutGraph(ind):
    size = int(np.sqrt(len(ind)))
    edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 1]
    non_edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 0]

    if edges and non_edges:
        # 移除一条边
        i, j = random.choice(edges)
        ind[i * size + j] = 0
        ind[j * size + i] = 0

        # 添加一条边
        i, j = random.choice(non_edges)
        ind[i * size + j] = 1
        ind[j * size + i] = 1

    return ind,

# 遗传算法设置
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)

# 初始化个体时确保边数为文件中的边数量
def initIndividual():
    num_vertices = read_graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], num_edges)
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)

toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)

# 保存初始种群
def save_population(population, filename):
    with open(filename, 'wb') as f:
        pickle.dump(population, f)

# 读取初始种群
def load_population(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 保存遗传算法的迭代过程数据
def save_logbook(logbook, filename):
    with open(filename, 'wb') as f:
        pickle.dump(logbook, f)

# 主遗传算法流程
def main(population_size, selection_ratio, mutpb, initial_population, pbar, logbook_filename):
    num_selected = int(population_size * selection_ratio)
    num_offspring = population_size - num_selected
    num_generations = 10  # 设定总迭代次数
    cxpb = 0.5  # 交叉概率

    # 使用固定的初始种群
    pop = initial_population[:]
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(num_generations):
        # 选择操作
        selected = toolbox.select(pop, num_selected)

        # 生成新的个体
        offspring = algorithms.varAnd(selected, toolbox, cxpb, mutpb)
        offspring = offspring[:num_offspring]

        # 组合父代和新生成的个体，形成新的种群
        pop[:] = selected + offspring

        # 评估新的种群
        fitnesses = list(map(toolbox.evaluate, pop))
        for ind, fit in zip(pop, fitnesses):
            ind.fitness.values = fit

        # 记录和输出每一代的最优适应度值
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)

        # 更新进度条
        pbar.update(1)

        # 更新Hall of Fame
        hof.update(pop)

    # 保存logbook到文件
    save_logbook(logbook, logbook_filename)

    return logbook, hof[0].fitness.values[0]

# 配置参数
population_sizes = [75, 150, 300]
selection_ratios = [1 / 3, 1 / 2, 2 / 3, 3 / 4]
mutation_probs = [0.075, 0.15, 0.3]

# 初始化进度条
progress_bars = {
    pop_size: tqdm(total=12 * 10, desc=f'Population={pop_size}', position=i, leave=True)
    for i, pop_size in enumerate(population_sizes)
}

# 逐个运行每个种群大小的12种情况，并保存过程数据
for population_size in population_sizes:
    population_filename = f"./output_36/initial_population_{filename1}_{population_size}.pkl"
    logbook_filenames = []

    # 检查是否已有保存的初始种群文件
    if os.path.exists(population_filename):
        initial_population = load_population(population_filename)
    else:
        # 生成并保存初始种群
        initial_population = toolbox.population(n=population_size)
        save_population(initial_population, population_filename)

    # 计算初始种群的适应度并存储作为初始点
    fitnesses = list(map(toolbox.evaluate, initial_population))
    initial_fitness = min(fitnesses)[0]  # 获取最小的适应度

    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_params = {
            executor.submit(main, population_size, selection_ratio, mutpb, initial_population,
                            progress_bars[population_size], 
                            f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")): (
                selection_ratio, mutpb)
            for selection_ratio in selection_ratios
            for mutpb in mutation_probs
        }

        for future in as_completed(future_to_params):
            selection_ratio, mutpb = future_to_params[future]
            logbook_filename = f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")
            logbook_filenames.append(logbook_filename)
            try:
                _, final_fitness = future.result()
                print(f'Completed: Pop={population_size}, Select={selection_ratio}, Mutate={mutpb} - Fitness={final_fitness}')
            except Exception as ex:
                print(f'Error with Pop={population_size}, Select={selection_ratio}, Mutate={mutpb}: {ex}')

# 完成后关闭所有进度条
for pbar in progress_bars.values():
    pbar.close()

# 读取并绘制图像
def load_logbook(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 确定统一的y轴范围
def determine_y_limits(logbook_filenames):
    all_min_values = []
    all_max_values = []
    for filename in logbook_filenames:
        logbook = load_logbook(filename)
        min_fitness_values = logbook.select("min")
        if np.isfinite(min(min_fitness_values)):
            all_min_values.append(min(min_fitness_values))
        if np.isfinite(max(min_fitness_values)):
            all_max_values.append(max(min_fitness_values))
    y_min = 0
    y_max = max(all_max_values) if all_max_values else 1
    return y_min, y_max

# 绘制图像
def plot_fitness_over_generations(logbook_filenames, population_size, y_min, y_max, initial_fitness):
    plt.figure(figsize=(14, 10))
    for filename in logbook_filenames:
        logbook = load_logbook(filename)
        min_fitness_values = logbook.select("min")
        generations = list(range(1, len(min_fitness_values) + 1))
        fitness_values = [initial_fitness] + min_fitness_values  # 添加初始适应度值作为第一个点
        generations = [0] + generations  # 确保x轴从0开始

        # 获取选择率和变异率的信息来作为标签
        select_info = filename.split("_sel")[1].split("_mut")[0]
        mutate_info = filename.split("_mut")[1].split(".pkl")[0]

        plt.plot(generations, fitness_values, label=f'Select={select_info}, Mutate={mutate_info}%')

    plt.title(f"Fitness Value over Generations (Population Size = {population_size})")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.legend()
    plt.grid(True)

    # 设置统一的y轴范围
    plt.ylim(y_min, y_max)

    # 保存图表
    plt.savefig(f"./output_36/fitness_over_generations_population_{population_size}.png")
    plt.show()

# 读取保存的logbook文件并生成图像
for population_size in population_sizes:
    logbook_filenames = [
        f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")
        for selection_ratio in selection_ratios
        for mutpb in mutation_probs
    ]
    y_min, y_max = determine_y_limits(logbook_filenames)

    # 计算初始种群的适应度
    initial_population = load_population(f"./output_36/initial_population_{filename1}_{population_size}.pkl")
    fitnesses = list(map(toolbox.evaluate, initial_population))
    initial_fitness = min(fitnesses)[0]

    plot_fitness_over_generations(logbook_filenames, population_size, y_min, y_max, initial_fitness)
# Out:
# nodes:  37 links  46
# Population=75:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=150:   0%|          | 0/120 [00:00<?, ?it/s]
# Population=300:   0%|          | 0/120 [00:00<?, ?it/s]
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.075 - Fitness=2090.8295769471206
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.15 - Fitness=2218.146745789303
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.3 - Fitness=2301.6806530473405
# Completed: Pop=75, Select=0.5, Mutate=0.075 - Fitness=2083.7887272468624
# Completed: Pop=75, Select=0.5, Mutate=0.15 - Fitness=2341.267298908416
# Completed: Pop=75, Select=0.5, Mutate=0.3 - Fitness=1913.1983069173232
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.075 - Fitness=2535.606981026106
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.15 - Fitness=2294.6116864951327
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.3 - Fitness=2246.8271579185384
# Completed: Pop=75, Select=0.75, Mutate=0.075 - Fitness=2256.398783924763
# Completed: Pop=75, Select=0.75, Mutate=0.15 - Fitness=1993.7711180012059
# Completed: Pop=75, Select=0.75, Mutate=0.3 - Fitness=2084.881029289405
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.075 - Fitness=1884.0914551580836
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.15 - Fitness=1845.0849675018726
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.3 - Fitness=1955.460868435678
# Completed: Pop=150, Select=0.5, Mutate=0.075 - Fitness=1856.5991746784898
# Completed: Pop=150, Select=0.5, Mutate=0.15 - Fitness=1764.939465808241
# Completed: Pop=150, Select=0.5, Mutate=0.3 - Fitness=1877.7836072209557
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.075 - Fitness=1805.9956442042337
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.15 - Fitness=1881.7566549562725
# Completed: Pop=150, Select=0.75, Mutate=0.075 - Fitness=2099.4264667042335
# Completed: Pop=150, Select=0.75, Mutate=0.15 - Fitness=1914.2315346512232
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.3 - Fitness=1941.6394065064937
# Completed: Pop=150, Select=0.75, Mutate=0.3 - Fitness=1984.4228524502832
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.15 - Fitness=2106.3736621606613
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.075 - Fitness=1749.9655451810881
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.3 - Fitness=1771.7715804005393
# Completed: Pop=300, Select=0.5, Mutate=0.075 - Fitness=1628.9900960262203
# Completed: Pop=300, Select=0.5, Mutate=0.15 - Fitness=1740.408061916547
# Completed: Pop=300, Select=0.5, Mutate=0.3 - Fitness=1894.7603604570413
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.075 - Fitness=1753.4102954413736
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.15 - Fitness=1936.6193632393488
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.3 - Fitness=1991.0889659265335
# Completed: Pop=300, Select=0.75, Mutate=0.075 - Fitness=2030.9490735852778
# Completed: Pop=300, Select=0.75, Mutate=0.15 - Fitness=1899.5655434293358
# Completed: Pop=300, Select=0.75, Mutate=0.3 - Fitness=2026.7473388117896

# %%
import numpy as np
import random
from graph_tool.all import Graph, shortest_distance
from deap import base, creator, tools, algorithms
import python_codes.files_operators as fo
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor, as_completed
from fractions import Fraction
from tqdm.notebook import tqdm
import pickle
import os

# 读取图和位置信息
filename1 = "cost266"  # 更改为你的文件名
read_graph, read_pos = fo.read_files(f"../networks_clusters/{filename1}.net")
num_edges = read_graph.num_edges()
print("nodes: ", read_graph.num_vertices(), "links ", num_edges)

# 计算并添加边的欧氏距离作为权重属性
edge_weights = read_graph.new_edge_property("double")
for edge in read_graph.edges():
    source_pos = read_pos[edge.source()]
    target_pos = read_pos[edge.target()]
    euclidean_distance = np.sqrt((source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
    edge_weights[edge] = euclidean_distance

# 将图转换为个体编码
def graph_to_individual(graph):
    num_vertices = graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    for edge in graph.edges():
        source, target = int(edge.source()), int(edge.target())
        individual[source * num_vertices + target] = 1
        individual[target * num_vertices + source] = 1
    return individual

# 将个体解码为图并计算边权重属性
def individual_to_graph(individual, num_vertices):
    graph = Graph(directed=False)
    graph.add_vertex(num_vertices)
    new_edge_weights = graph.new_edge_property("double")
    for i in range(num_vertices):
        for j in range(i + 1, num_vertices):
            if individual[i * num_vertices + j] == 1:
                edge = graph.add_edge(graph.vertex(i), graph.vertex(j))
                source_pos = read_pos[graph.vertex(i)]
                target_pos = read_pos[graph.vertex(j)]
                euclidean_distance = np.sqrt(
                    (source_pos[0] - target_pos[0]) ** 2 + (source_pos[1] - target_pos[1]) ** 2)
                new_edge_weights[edge] = euclidean_distance
    return graph, new_edge_weights

# 定义适应度函数
def evaluate(individual):
    graph, new_edge_weights = individual_to_graph(individual, read_graph.num_vertices())
    num_edges = graph.num_edges()
    if num_edges != read_graph.num_edges():  # 边数限制，确保边数为文件中边的数量
        return float('inf'),  # 如果边数不为文件中边的数量，适应度设为无穷大
    dist_matrix = shortest_distance(graph, weights=new_edge_weights).get_2d_array(range(graph.num_vertices()))
    total_distance = np.sum(dist_matrix[dist_matrix != np.inf])
    return total_distance,

# 自定义交叉操作
def cxGraph(ind1, ind2):
    size = len(ind1)
    point = random.randint(1, size - 1)
    new_ind1 = creator.Individual(np.concatenate((ind1[:point], ind2[point:])))
    new_ind2 = creator.Individual(np.concatenate((ind2[:point], ind1[point:])))

    # 修正边数
    def fix_edges(individual):
        num_vertices = int(np.sqrt(len(individual)))
        edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                 individual[i * num_vertices + j] == 1]
        non_edges = [(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices) if
                     individual[i * num_vertices + j] == 0]
        if len(edges) > num_edges:
            # 移除多余的边
            extra_edges = random.sample(edges, len(edges) - num_edges)
            for i, j in extra_edges:
                individual[i * num_vertices + j] = 0
                individual[j * num_vertices + i] = 0
        elif len(edges) < num_edges:
            # 添加缺失的边
            missing_edges = random.sample(non_edges, num_edges - len(edges))
            for i, j in missing_edges:
                individual[i * num_vertices + j] = 1
                individual[j * num_vertices + i] = 1
        return individual

    new_ind1 = fix_edges(new_ind1)
    new_ind2 = fix_edges(new_ind2)

    return new_ind1, new_ind2

# 自定义变异操作
def mutGraph(ind):
    size = int(np.sqrt(len(ind)))
    edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 1]
    non_edges = [(i, j) for i in range(size) for j in range(i + 1, size) if ind[i * size + j] == 0]

    if edges and non_edges:
        # 移除一条边
        i, j = random.choice(edges)
        ind[i * size + j] = 0
        ind[j * size + i] = 0

        # 添加一条边
        i, j = random.choice(non_edges)
        ind[i * size + j] = 1
        ind[j * size + i] = 1

    return ind,

# 遗传算法设置
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_bool", random.randint, 0, 1)

# 初始化个体时确保边数为文件中的边数量
def initIndividual():
    num_vertices = read_graph.num_vertices()
    individual = [0] * (num_vertices * num_vertices)
    edges = random.sample([(i, j) for i in range(num_vertices) for j in range(i + 1, num_vertices)], num_edges)
    for i, j in edges:
        individual[i * num_vertices + j] = 1
        individual[j * num_vertices + i] = 1
    return creator.Individual(individual)

toolbox.register("individual", initIndividual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", cxGraph)
toolbox.register("mutate", mutGraph)
toolbox.register("select", tools.selTournament, tournsize=3)

# 保存初始种群
def save_population(population, filename):
    with open(filename, 'wb') as f:
        pickle.dump(population, f)

# 读取初始种群
def load_population(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 保存遗传算法的迭代过程数据
def save_logbook(logbook, filename):
    with open(filename, 'wb') as f:
        pickle.dump(logbook, f)

# 主遗传算法流程
def main(population_size, selection_ratio, mutpb, initial_population, pbar, logbook_filename):
    num_selected = int(population_size * selection_ratio)
    num_offspring = population_size - num_selected
    num_generations = 1000  # 设定总迭代次数
    cxpb = 0.5  # 交叉概率

    # 使用固定的初始种群
    pop = initial_population[:]
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)

    logbook = tools.Logbook()
    logbook.header = ["gen", "min"]

    for gen in range(num_generations):
        # 选择操作
        selected = toolbox.select(pop, num_selected)

        # 生成新的个体
        offspring = algorithms.varAnd(selected, toolbox, cxpb, mutpb)
        offspring = offspring[:num_offspring]

        # 组合父代和新生成的个体，形成新的种群
        pop[:] = selected + offspring

        # 评估新的种群
        fitnesses = list(map(toolbox.evaluate, pop))
        for ind, fit in zip(pop, fitnesses):
            ind.fitness.values = fit

        # 记录和输出每一代的最优适应度值
        record = stats.compile(pop)
        logbook.record(gen=gen, **record)

        # 更新进度条
        pbar.update(1)

        # 更新Hall of Fame
        hof.update(pop)

    # 保存logbook到文件
    save_logbook(logbook, logbook_filename)

    return logbook, hof[0].fitness.values[0]

# 配置参数
population_sizes = [75, 150, 300]
selection_ratios = [1 / 3, 1 / 2, 2 / 3, 3 / 4]
mutation_probs = [0.075, 0.15, 0.3]

# 初始化进度条
progress_bars = {
    pop_size: tqdm(total=12 * 1000, desc=f'Population={pop_size}', position=i, leave=True)
    for i, pop_size in enumerate(population_sizes)
}

# 逐个运行每个种群大小的12种情况，并保存过程数据
for population_size in population_sizes:
    population_filename = f"./output_36/initial_population_{filename1}_{population_size}.pkl"
    logbook_filenames = []

    # 检查是否已有保存的初始种群文件
    if os.path.exists(population_filename):
        initial_population = load_population(population_filename)
    else:
        # 生成并保存初始种群
        initial_population = toolbox.population(n=population_size)
        save_population(initial_population, population_filename)

    # 计算初始种群的适应度并存储作为初始点
    fitnesses = list(map(toolbox.evaluate, initial_population))
    initial_fitness = min(fitnesses)[0]  # 获取最小的适应度

    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_params = {
            executor.submit(main, population_size, selection_ratio, mutpb, initial_population,
                            progress_bars[population_size], 
                            f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")): (
                selection_ratio, mutpb)
            for selection_ratio in selection_ratios
            for mutpb in mutation_probs
        }

        for future in as_completed(future_to_params):
            selection_ratio, mutpb = future_to_params[future]
            logbook_filename = f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")
            logbook_filenames.append(logbook_filename)
            try:
                _, final_fitness = future.result()
                print(f'Completed: Pop={population_size}, Select={selection_ratio}, Mutate={mutpb} - Fitness={final_fitness}')
            except Exception as ex:
                print(f'Error with Pop={population_size}, Select={selection_ratio}, Mutate={mutpb}: {ex}')

# 完成后关闭所有进度条
for pbar in progress_bars.values():
    pbar.close()

# 读取并绘制图像
def load_logbook(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# 统一 y 轴范围为 0 到 3000
y_min = 0
y_max = 3000

# 绘制图像
def plot_fitness_over_generations(logbook_filenames, population_size, y_min, y_max, initial_fitness):
    plt.figure(figsize=(14, 10))
    for filename in logbook_filenames:
        logbook = load_logbook(filename)
        min_fitness_values = logbook.select("min")
        generations = list(range(1, len(min_fitness_values) + 1))
        fitness_values = [initial_fitness] + min_fitness_values  # 添加初始适应度值作为第一个点
        generations = [0] + generations  # 确保x轴从0开始

        # 获取选择率和变异率的信息来作为标签
        select_info = filename.split("_sel")[1].split("_mut")[0]
        mutate_info = filename.split("_mut")[1].split(".pkl")[0]

        plt.plot(generations, fitness_values, label=f'Select={select_info}, Mutate={mutate_info}%')

    plt.title(f"Fitness Value over Generations (Population Size = {population_size})")
    plt.xlabel("Generation")
    plt.ylabel("Fitness Value (Cost)")
    plt.legend()
    plt.grid(True)

    # 设置统一的y轴范围
    plt.ylim(y_min, y_max)

    # 保存图表
    plt.savefig(f"./output_36/{filename1}_fitness_over_generations_population_{population_size}.png")
    plt.show()

# 读取保存的logbook文件并生成图像
for population_size in population_sizes:
    logbook_filenames = [
        f"./output_36/logbook_{filename1}_pop{population_size}_sel{Fraction(selection_ratio).limit_denominator()}_mut{int(mutpb * 100)}.pkl".replace("/", "_")
        for selection_ratio in selection_ratios
        for mutpb in mutation_probs
    ]

    # 计算初始种群的适应度
    initial_population = load_population(f"./output_36/initial_population_{filename1}_{population_size}.pkl")
    fitnesses = list(map(toolbox.evaluate, initial_population))
    initial_fitness = min(fitnesses)[0]

    plot_fitness_over_generations(logbook_filenames, population_size, y_min, y_max, initial_fitness)
# Out:
# nodes:  37 links  46
# Population=75:   0%|          | 0/12000 [00:00<?, ?it/s]
# Population=150:   0%|          | 0/12000 [00:00<?, ?it/s]
# Population=300:   0%|          | 0/12000 [00:00<?, ?it/s]
# /home/huanghanjun/anaconda3/envs/graph-tool/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.15 - Fitness=816.3261180281069
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.3 - Fitness=790.900780078976
# Completed: Pop=75, Select=0.3333333333333333, Mutate=0.075 - Fitness=875.8799820675185
# Completed: Pop=75, Select=0.5, Mutate=0.075 - Fitness=838.3170864434843
# Completed: Pop=75, Select=0.5, Mutate=0.15 - Fitness=802.9645997774539
# Completed: Pop=75, Select=0.5, Mutate=0.3 - Fitness=799.7915990148077
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.075 - Fitness=862.7275437233982
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.15 - Fitness=811.2131536732584
# Completed: Pop=75, Select=0.6666666666666666, Mutate=0.3 - Fitness=787.4130992915207
# Completed: Pop=75, Select=0.75, Mutate=0.075 - Fitness=1048.9593731859386
# Completed: Pop=75, Select=0.75, Mutate=0.15 - Fitness=826.7056308663832
# Completed: Pop=75, Select=0.75, Mutate=0.3 - Fitness=812.1628009574252
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.3 - Fitness=773.2784767018784
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.075 - Fitness=823.5997610814798
# Completed: Pop=150, Select=0.3333333333333333, Mutate=0.15 - Fitness=801.8196454650958
# Completed: Pop=150, Select=0.5, Mutate=0.075 - Fitness=800.8679525307111
# Completed: Pop=150, Select=0.5, Mutate=0.15 - Fitness=786.7526583022732
# Completed: Pop=150, Select=0.5, Mutate=0.3 - Fitness=773.788447989612
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.075 - Fitness=827.6546153171821
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.15 - Fitness=788.1051030179551
# Completed: Pop=150, Select=0.6666666666666666, Mutate=0.3 - Fitness=780.8931236046932
# Completed: Pop=150, Select=0.75, Mutate=0.075 - Fitness=806.2340798805161
# Completed: Pop=150, Select=0.75, Mutate=0.15 - Fitness=796.9927366869414
# Completed: Pop=150, Select=0.75, Mutate=0.3 - Fitness=785.4307566570255
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.15 - Fitness=784.4632170689398
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.3 - Fitness=768.6301633285053
# Completed: Pop=300, Select=0.3333333333333333, Mutate=0.075 - Fitness=795.6172345283337
# Completed: Pop=300, Select=0.5, Mutate=0.075 - Fitness=789.4380104611209
# Completed: Pop=300, Select=0.5, Mutate=0.15 - Fitness=769.0356617394782
# Completed: Pop=300, Select=0.5, Mutate=0.3 - Fitness=772.744227118009
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.075 - Fitness=792.2071372435666
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.15 - Fitness=776.8921284894857
# Completed: Pop=300, Select=0.6666666666666666, Mutate=0.3 - Fitness=755.8420075303774
# Completed: Pop=300, Select=0.75, Mutate=0.075 - Fitness=810.3695886095311
# Completed: Pop=300, Select=0.75, Mutate=0.15 - Fitness=786.20821793423
# Completed: Pop=300, Select=0.75, Mutate=0.3 - Fitness=754.239291705351
