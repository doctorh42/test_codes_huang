# %%
import random
from graph_tool import Graph, draw
from graph_tool.topology import min_spanning_tree, shortest_distance
import python_codes.files_operators

filename1 = "Germany50"

# 读取网络数据
read_graph, read_pos = python_codes.files_operators.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 参数设置
POP_SIZE = 50
NUM_GENERATIONS = 100
MUTATION_RATE = 0.1
TOURNAMENT_SIZE = 3

# 初始化种群
def initialize_population(graph, pop_size):
    population = []
    for _ in range(pop_size):
        mst = min_spanning_tree(graph)
        mst_graph = Graph(directed=False)
        mst_graph.add_vertex(graph.num_vertices())
        for edge, in_mst in zip(graph.edges(), mst):
            if in_mst:
                mst_graph.add_edge(edge.source(), edge.target())
        # 复制顶点和边属性
        for prop_name, prop_map in graph.vertex_properties.items():
            mst_graph.vertex_properties[prop_name] = mst_graph.new_vertex_property(prop_map.value_type())
            for v in mst_graph.vertices():
                mst_graph.vertex_properties[prop_name][v] = graph.vertex_properties[prop_name][v]
        for prop_name, prop_map in graph.edge_properties.items():
            mst_graph.edge_properties[prop_name] = mst_graph.new_edge_property(prop_map.value_type())
            for e in mst_graph.edges():
                mst_graph.edge_properties[prop_name][e] = graph.edge_properties[prop_name][graph.edge(e.source(), e.target())]
        population.append(mst_graph)
    return population

# 适应度函数：计算总路径长度
def fitness(graph):
    total_length = 0
    for v in graph.vertices():
        dist_map = shortest_distance(graph, source=v)
        total_length += sum(dist_map.a)
    return total_length

# 选择父代
def tournament_selection(population, k):
    selected = random.sample(population, k)
    selected.sort(key=fitness)
    return selected[0]

# 交叉操作
def crossover(parent1, parent2):
    size = parent1.num_edges()
    edges1 = list(parent1.edges())
    edges2 = list(parent2.edges())
    child = Graph(directed=False)
    child.add_vertex(parent1.num_vertices())
    for i in range(size // 2):
        edge = edges1[i]
        child.add_edge(edge.source(), edge.target())
    for i in range(size // 2, size):
        edge = edges2[i]
        child.add_edge(edge.source(), edge.target())
    # 复制顶点和边属性
    for prop_name, prop_map in parent1.vertex_properties.items():
        child.vertex_properties[prop_name] = child.new_vertex_property(prop_map.value_type())
        for v in child.vertices():
            child.vertex_properties[prop_name][v] = parent1.vertex_properties[prop_name][v]
    for prop_name, prop_map in parent1.edge_properties.items():
        child.edge_properties[prop_name] = child.new_edge_property(prop_map.value_type())
        for e in child.edges():
            child.edge_properties[prop_name][e] = parent1.edge_properties[prop_name][parent1.edge(e.source(), e.target())]
    return child

# 变异操作
def mutate(graph, mutation_rate):
    if random.random() < mutation_rate:
        edges = list(graph.edges())
        graph.remove_edge(random.choice(edges))
        available_edges = list(read_graph.edges())
        new_edge = random.choice(available_edges)
        graph.add_edge(new_edge.source(), new_edge.target())

# 主遗传算法
def genetic_algorithm(graph, pop_size, num_generations, mutation_rate, tournament_size):
    population = initialize_population(graph, pop_size)
    best_individual = None
    best_fitness = float('inf')

    for generation in range(num_generations):
        new_population = []
        for _ in range(pop_size // 2):
            parent1 = tournament_selection(population, tournament_size)
            parent2 = tournament_selection(population, tournament_size)
            child1 = crossover(parent1, parent2)
            child2 = crossover(parent2, parent1)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            new_population.extend([child1, child2])

        population = new_population

        # 评估新种群
        for individual in population:
            ind_fitness = fitness(individual)
            if ind_fitness < best_fitness:
                best_fitness = ind_fitness
                best_individual = individual

        print(f"Generation {generation}: Best fitness = {best_fitness}")

    return best_individual

# 执行遗传算法
best_mst = genetic_algorithm(read_graph, POP_SIZE, NUM_GENERATIONS, MUTATION_RATE, TOURNAMENT_SIZE)

# 打印最优解的节点和边数量
print("Best MST nodes: ", best_mst.num_vertices(), "Best MST links: ", best_mst.num_edges())

# 绘制最优解
draw.graph_draw(best_mst, read_pos, vertex_text=best_mst.vertex_properties["number"], edge_color='blue', output_size=(1000, 1000), output=f'./output_GA/{filename1}_{NUM_GENERATIONS}_best_mst.pdf')
# Out:
# nodes:  50 links  69
# Generation 0: Best fitness = 20368
# Generation 1: Best fitness = 20368
# Generation 2: Best fitness = 20008
# Generation 3: Best fitness = 20008
# Generation 4: Best fitness = 19824
# Generation 5: Best fitness = 19824
# Generation 6: Best fitness = 19824
# Generation 7: Best fitness = 19824
# Generation 8: Best fitness = 19824
# Generation 9: Best fitness = 19824
# Generation 10: Best fitness = 19824
# Generation 11: Best fitness = 19824
# Generation 12: Best fitness = 19824
# Generation 13: Best fitness = 19824
# Generation 14: Best fitness = 19824
# Generation 15: Best fitness = 19824
# Generation 16: Best fitness = 19824
# Generation 17: Best fitness = 19824
# Generation 18: Best fitness = 19824
# Generation 19: Best fitness = 19824
# Generation 20: Best fitness = 19824
# Generation 21: Best fitness = 19824
# Generation 22: Best fitness = 19570
# Generation 23: Best fitness = 19570
# Generation 24: Best fitness = 19570
# Generation 25: Best fitness = 19570
# Generation 26: Best fitness = 19570
# Generation 27: Best fitness = 19570
# Generation 28: Best fitness = 19570
# Generation 29: Best fitness = 19570
# Generation 30: Best fitness = 19570
# Generation 31: Best fitness = 19570
# Generation 32: Best fitness = 19570
# Generation 33: Best fitness = 19570
# Generation 34: Best fitness = 19122
# Generation 35: Best fitness = 19122
# Generation 36: Best fitness = 19122
# Generation 37: Best fitness = 19122
# Generation 38: Best fitness = 19122
# Generation 39: Best fitness = 19122
# Generation 40: Best fitness = 19122
# Generation 41: Best fitness = 19122
# Generation 42: Best fitness = 19122
# Generation 43: Best fitness = 19122
# Generation 44: Best fitness = 19122
# Generation 45: Best fitness = 19122
# Generation 46: Best fitness = 19122
# Generation 47: Best fitness = 19122
# Generation 48: Best fitness = 19122
# Generation 49: Best fitness = 19122
# Generation 50: Best fitness = 19122
# Generation 51: Best fitness = 19122
# Generation 52: Best fitness = 19122
# Generation 53: Best fitness = 19058
# Generation 54: Best fitness = 19058
# Generation 55: Best fitness = 19058
# Generation 56: Best fitness = 19058
# Generation 57: Best fitness = 19058
# Generation 58: Best fitness = 19058
# Generation 59: Best fitness = 19058
# Generation 60: Best fitness = 19058
# Generation 61: Best fitness = 19058
# Generation 62: Best fitness = 19058
# Generation 63: Best fitness = 19058
# Generation 64: Best fitness = 19058
# Generation 65: Best fitness = 19058
# Generation 66: Best fitness = 19058
# Generation 67: Best fitness = 19058
# Generation 68: Best fitness = 19058
# Generation 69: Best fitness = 19058
# Generation 70: Best fitness = 19058
# Generation 71: Best fitness = 19058
# Generation 72: Best fitness = 19058
# Generation 73: Best fitness = 19058
# Generation 74: Best fitness = 19058
# Generation 75: Best fitness = 18930
# Generation 76: Best fitness = 18930
# Generation 77: Best fitness = 18930
# Generation 78: Best fitness = 18930
# Generation 79: Best fitness = 18930
# Generation 80: Best fitness = 18930
# Generation 81: Best fitness = 18930
# Generation 82: Best fitness = 18930
# Generation 83: Best fitness = 18930
# Generation 84: Best fitness = 18930
# Generation 85: Best fitness = 18930
# Generation 86: Best fitness = 18930
# Generation 87: Best fitness = 18930
# Generation 88: Best fitness = 18930
# Generation 89: Best fitness = 18930
# Generation 90: Best fitness = 18930
# Generation 91: Best fitness = 18930
# Generation 92: Best fitness = 18930
# Generation 93: Best fitness = 18930
# Generation 94: Best fitness = 18930
# Generation 95: Best fitness = 18930
# Generation 96: Best fitness = 18866
# Generation 97: Best fitness = 18866
# Generation 98: Best fitness = 18866
# Generation 99: Best fitness = 18866
# Best MST nodes:  50 Best MST links:  49
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7c217652e690, at 0x7c2204fc7140>

# %%
import random
from graph_tool import Graph, draw
from graph_tool.topology import min_spanning_tree, shortest_distance
import python_codes.files_operators

filename1 = "Germany50"

# 读取网络数据
read_graph, read_pos = python_codes.files_operators.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 参数设置
POP_SIZE = 50
NUM_GENERATIONS = 200
MUTATION_RATE = 0.1
TOURNAMENT_SIZE = 3

# 初始化种群
def initialize_population(graph, pop_size):
    population = []
    for _ in range(pop_size):
        mst = min_spanning_tree(graph)
        mst_graph = Graph(directed=False)
        mst_graph.add_vertex(graph.num_vertices())
        for edge, in_mst in zip(graph.edges(), mst):
            if in_mst:
                mst_graph.add_edge(edge.source(), edge.target())
        # 复制顶点和边属性
        for prop_name, prop_map in graph.vertex_properties.items():
            mst_graph.vertex_properties[prop_name] = mst_graph.new_vertex_property(prop_map.value_type())
            for v in mst_graph.vertices():
                mst_graph.vertex_properties[prop_name][v] = graph.vertex_properties[prop_name][v]
        for prop_name, prop_map in graph.edge_properties.items():
            mst_graph.edge_properties[prop_name] = mst_graph.new_edge_property(prop_map.value_type())
            for e in mst_graph.edges():
                mst_graph.edge_properties[prop_name][e] = graph.edge_properties[prop_name][graph.edge(e.source(), e.target())]
        population.append(mst_graph)
    return population

# 适应度函数：计算总路径长度
def fitness(graph):
    total_length = 0
    for v in graph.vertices():
        dist_map = shortest_distance(graph, source=v)
        total_length += sum(dist_map.a)
    return total_length

# 选择父代
def tournament_selection(population, k):
    selected = random.sample(population, k)
    selected.sort(key=fitness)
    return selected[0]

# 交叉操作
def crossover(parent1, parent2):
    size = parent1.num_edges()
    edges1 = list(parent1.edges())
    edges2 = list(parent2.edges())
    child = Graph(directed=False)
    child.add_vertex(parent1.num_vertices())
    for i in range(size // 2):
        edge = edges1[i]
        child.add_edge(edge.source(), edge.target())
    for i in range(size // 2, size):
        edge = edges2[i]
        child.add_edge(edge.source(), edge.target())
    # 复制顶点和边属性
    for prop_name, prop_map in parent1.vertex_properties.items():
        child.vertex_properties[prop_name] = child.new_vertex_property(prop_map.value_type())
        for v in child.vertices():
            child.vertex_properties[prop_name][v] = parent1.vertex_properties[prop_name][v]
    for prop_name, prop_map in parent1.edge_properties.items():
        child.edge_properties[prop_name] = child.new_edge_property(prop_map.value_type())
        for e in child.edges():
            child.edge_properties[prop_name][e] = parent1.edge_properties[prop_name][parent1.edge(e.source(), e.target())]
    return child

# 变异操作
def mutate(graph, mutation_rate):
    if random.random() < mutation_rate:
        edges = list(graph.edges())
        graph.remove_edge(random.choice(edges))
        available_edges = list(read_graph.edges())
        new_edge = random.choice(available_edges)
        graph.add_edge(new_edge.source(), new_edge.target())

# 主遗传算法
def genetic_algorithm(graph, pop_size, num_generations, mutation_rate, tournament_size):
    population = initialize_population(graph, pop_size)
    best_individual = None
    best_fitness = float('inf')

    for generation in range(num_generations):
        new_population = []
        for _ in range(pop_size // 2):
            parent1 = tournament_selection(population, tournament_size)
            parent2 = tournament_selection(population, tournament_size)
            child1 = crossover(parent1, parent2)
            child2 = crossover(parent2, parent1)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            new_population.extend([child1, child2])

        population = new_population

        # 评估新种群
        for individual in population:
            ind_fitness = fitness(individual)
            if ind_fitness < best_fitness:
                best_fitness = ind_fitness
                best_individual = individual

        print(f"Generation {generation}: Best fitness = {best_fitness}")

    return best_individual

# 执行遗传算法
best_mst = genetic_algorithm(read_graph, POP_SIZE, NUM_GENERATIONS, MUTATION_RATE, TOURNAMENT_SIZE)

# 打印最优解的节点和边数量
print("Best MST nodes: ", best_mst.num_vertices(), "Best MST links: ", best_mst.num_edges())

# 绘制最优解
draw.graph_draw(best_mst, read_pos, vertex_text=best_mst.vertex_properties["number"], edge_color='blue', output_size=(1000, 1000), output=f'./output_GA/{filename1}_{NUM_GENERATIONS}_best_mst.pdf')
# Out:
# nodes:  50 links  69
# Generation 0: Best fitness = 20368
# Generation 1: Best fitness = 20368
# Generation 2: Best fitness = 20368
# Generation 3: Best fitness = 20368
# Generation 4: Best fitness = 20368
# Generation 5: Best fitness = 20368
# Generation 6: Best fitness = 20368
# Generation 7: Best fitness = 20368
# Generation 8: Best fitness = 20368
# Generation 9: Best fitness = 20368
# Generation 10: Best fitness = 20368
# Generation 11: Best fitness = 20368
# Generation 12: Best fitness = 20360
# Generation 13: Best fitness = 17678
# Generation 14: Best fitness = 17678
# Generation 15: Best fitness = 17678
# Generation 16: Best fitness = 17678
# Generation 17: Best fitness = 17678
# Generation 18: Best fitness = 17678
# Generation 19: Best fitness = 17678
# Generation 20: Best fitness = 17678
# Generation 21: Best fitness = 17678
# Generation 22: Best fitness = 17678
# Generation 23: Best fitness = 17678
# Generation 24: Best fitness = 17678
# Generation 25: Best fitness = 17678
# Generation 26: Best fitness = 17678
# Generation 27: Best fitness = 17168
# Generation 28: Best fitness = 17168
# Generation 29: Best fitness = 17168
# Generation 30: Best fitness = 17168
# Generation 31: Best fitness = 17168
# Generation 32: Best fitness = 17168
# Generation 33: Best fitness = 17168
# Generation 34: Best fitness = 17168
# Generation 35: Best fitness = 17168
# Generation 36: Best fitness = 17168
# Generation 37: Best fitness = 17168
# Generation 38: Best fitness = 17168
# Generation 39: Best fitness = 17168
# Generation 40: Best fitness = 17168
# Generation 41: Best fitness = 17168
# Generation 42: Best fitness = 17168
# Generation 43: Best fitness = 17168
# Generation 44: Best fitness = 17168
# Generation 45: Best fitness = 17168
# Generation 46: Best fitness = 17168
# Generation 47: Best fitness = 17168
# Generation 48: Best fitness = 17168
# Generation 49: Best fitness = 17168
# Generation 50: Best fitness = 17168
# Generation 51: Best fitness = 17168
# Generation 52: Best fitness = 17168
# Generation 53: Best fitness = 17168
# Generation 54: Best fitness = 17168
# Generation 55: Best fitness = 17168
# Generation 56: Best fitness = 17168
# Generation 57: Best fitness = 17168
# Generation 58: Best fitness = 17168
# Generation 59: Best fitness = 17168
# Generation 60: Best fitness = 17168
# Generation 61: Best fitness = 17168
# Generation 62: Best fitness = 17168
# Generation 63: Best fitness = 17168
# Generation 64: Best fitness = 17168
# Generation 65: Best fitness = 17168
# Generation 66: Best fitness = 17168
# Generation 67: Best fitness = 17168
# Generation 68: Best fitness = 17168
# Generation 69: Best fitness = 17168
# Generation 70: Best fitness = 17168
# Generation 71: Best fitness = 17168
# Generation 72: Best fitness = 17168
# Generation 73: Best fitness = 17168
# Generation 74: Best fitness = 17168
# Generation 75: Best fitness = 17168
# Generation 76: Best fitness = 17168
# Generation 77: Best fitness = 17168
# Generation 78: Best fitness = 17168
# Generation 79: Best fitness = 17168
# Generation 80: Best fitness = 17168
# Generation 81: Best fitness = 17168
# Generation 82: Best fitness = 17168
# Generation 83: Best fitness = 17168
# Generation 84: Best fitness = 17168
# Generation 85: Best fitness = 17168
# Generation 86: Best fitness = 17168
# Generation 87: Best fitness = 17168
# Generation 88: Best fitness = 17168
# Generation 89: Best fitness = 17168
# Generation 90: Best fitness = 17168
# Generation 91: Best fitness = 17168
# Generation 92: Best fitness = 17168
# Generation 93: Best fitness = 17168
# Generation 94: Best fitness = 17168
# Generation 95: Best fitness = 17168
# Generation 96: Best fitness = 17168
# Generation 97: Best fitness = 17168
# Generation 98: Best fitness = 17168
# Generation 99: Best fitness = 17168
# Generation 100: Best fitness = 17168
# Generation 101: Best fitness = 17168
# Generation 102: Best fitness = 17168
# Generation 103: Best fitness = 17168
# Generation 104: Best fitness = 17168
# Generation 105: Best fitness = 17168
# Generation 106: Best fitness = 17168
# Generation 107: Best fitness = 17168
# Generation 108: Best fitness = 17168
# Generation 109: Best fitness = 17168
# Generation 110: Best fitness = 17168
# Generation 111: Best fitness = 17168
# Generation 112: Best fitness = 17168
# Generation 113: Best fitness = 17168
# Generation 114: Best fitness = 17168
# Generation 115: Best fitness = 17168
# Generation 116: Best fitness = 17168
# Generation 117: Best fitness = 17168
# Generation 118: Best fitness = 17168
# Generation 119: Best fitness = 17168
# Generation 120: Best fitness = 17168
# Generation 121: Best fitness = 17168
# Generation 122: Best fitness = 17168
# Generation 123: Best fitness = 17168
# Generation 124: Best fitness = 17168
# Generation 125: Best fitness = 17168
# Generation 126: Best fitness = 17168
# Generation 127: Best fitness = 17168
# Generation 128: Best fitness = 17168
# Generation 129: Best fitness = 17168
# Generation 130: Best fitness = 17168
# Generation 131: Best fitness = 17168
# Generation 132: Best fitness = 17168
# Generation 133: Best fitness = 17168
# Generation 134: Best fitness = 17168
# Generation 135: Best fitness = 17168
# Generation 136: Best fitness = 17168
# Generation 137: Best fitness = 17168
# Generation 138: Best fitness = 17168
# Generation 139: Best fitness = 17168
# Generation 140: Best fitness = 17168
# Generation 141: Best fitness = 17168
# Generation 142: Best fitness = 17168
# Generation 143: Best fitness = 17168
# Generation 144: Best fitness = 17168
# Generation 145: Best fitness = 17168
# Generation 146: Best fitness = 17168
# Generation 147: Best fitness = 17168
# Generation 148: Best fitness = 17168
# Generation 149: Best fitness = 17168
# Generation 150: Best fitness = 17168
# Generation 151: Best fitness = 17168
# Generation 152: Best fitness = 17168
# Generation 153: Best fitness = 17168
# Generation 154: Best fitness = 17168
# Generation 155: Best fitness = 17168
# Generation 156: Best fitness = 17168
# Generation 157: Best fitness = 17168
# Generation 158: Best fitness = 17168
# Generation 159: Best fitness = 17168
# Generation 160: Best fitness = 17168
# Generation 161: Best fitness = 17168
# Generation 162: Best fitness = 17168
# Generation 163: Best fitness = 17168
# Generation 164: Best fitness = 17168
# Generation 165: Best fitness = 17168
# Generation 166: Best fitness = 17168
# Generation 167: Best fitness = 17168
# Generation 168: Best fitness = 17168
# Generation 169: Best fitness = 17168
# Generation 170: Best fitness = 17168
# Generation 171: Best fitness = 17168
# Generation 172: Best fitness = 17168
# Generation 173: Best fitness = 17168
# Generation 174: Best fitness = 17168
# Generation 175: Best fitness = 17168
# Generation 176: Best fitness = 17168
# Generation 177: Best fitness = 17168
# Generation 178: Best fitness = 17168
# Generation 179: Best fitness = 17168
# Generation 180: Best fitness = 17168
# Generation 181: Best fitness = 17168
# Generation 182: Best fitness = 17168
# Generation 183: Best fitness = 17168
# Generation 184: Best fitness = 17168
# Generation 185: Best fitness = 17168
# Generation 186: Best fitness = 17168
# Generation 187: Best fitness = 17168
# Generation 188: Best fitness = 17168
# Generation 189: Best fitness = 17168
# Generation 190: Best fitness = 17168
# Generation 191: Best fitness = 17168
# Generation 192: Best fitness = 17168
# Generation 193: Best fitness = 17168
# Generation 194: Best fitness = 17168
# Generation 195: Best fitness = 17168
# Generation 196: Best fitness = 17168
# Generation 197: Best fitness = 17168
# Generation 198: Best fitness = 17168
# Generation 199: Best fitness = 17168
# Best MST nodes:  50 Best MST links:  49
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7c21867e8ef0, at 0x7c2204f3bfe0>

# %%
import random
from graph_tool import Graph, draw
from graph_tool.topology import min_spanning_tree, shortest_distance
import python_codes.files_operators

filename1 = "Germany50"

# 读取网络数据
read_graph, read_pos = python_codes.files_operators.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 参数设置
POP_SIZE = 50
NUM_GENERATIONS = 300
MUTATION_RATE = 0.1
TOURNAMENT_SIZE = 3

# 初始化种群
def initialize_population(graph, pop_size):
    population = []
    for _ in range(pop_size):
        mst = min_spanning_tree(graph)
        mst_graph = Graph(directed=False)
        mst_graph.add_vertex(graph.num_vertices())
        for edge, in_mst in zip(graph.edges(), mst):
            if in_mst:
                mst_graph.add_edge(edge.source(), edge.target())
        # 复制顶点和边属性
        for prop_name, prop_map in graph.vertex_properties.items():
            mst_graph.vertex_properties[prop_name] = mst_graph.new_vertex_property(prop_map.value_type())
            for v in mst_graph.vertices():
                mst_graph.vertex_properties[prop_name][v] = graph.vertex_properties[prop_name][v]
        for prop_name, prop_map in graph.edge_properties.items():
            mst_graph.edge_properties[prop_name] = mst_graph.new_edge_property(prop_map.value_type())
            for e in mst_graph.edges():
                mst_graph.edge_properties[prop_name][e] = graph.edge_properties[prop_name][graph.edge(e.source(), e.target())]
        population.append(mst_graph)
    return population

# 适应度函数：计算总路径长度
def fitness(graph):
    total_length = 0
    for v in graph.vertices():
        dist_map = shortest_distance(graph, source=v)
        total_length += sum(dist_map.a)
    return total_length

# 选择父代
def tournament_selection(population, k):
    selected = random.sample(population, k)
    selected.sort(key=fitness)
    return selected[0]

# 交叉操作
def crossover(parent1, parent2):
    size = parent1.num_edges()
    edges1 = list(parent1.edges())
    edges2 = list(parent2.edges())
    child = Graph(directed=False)
    child.add_vertex(parent1.num_vertices())
    for i in range(size // 2):
        edge = edges1[i]
        child.add_edge(edge.source(), edge.target())
    for i in range(size // 2, size):
        edge = edges2[i]
        child.add_edge(edge.source(), edge.target())
    # 复制顶点和边属性
    for prop_name, prop_map in parent1.vertex_properties.items():
        child.vertex_properties[prop_name] = child.new_vertex_property(prop_map.value_type())
        for v in child.vertices():
            child.vertex_properties[prop_name][v] = parent1.vertex_properties[prop_name][v]
    for prop_name, prop_map in parent1.edge_properties.items():
        child.edge_properties[prop_name] = child.new_edge_property(prop_map.value_type())
        for e in child.edges():
            child.edge_properties[prop_name][e] = parent1.edge_properties[prop_name][parent1.edge(e.source(), e.target())]
    return child

# 变异操作
def mutate(graph, mutation_rate):
    if random.random() < mutation_rate:
        edges = list(graph.edges())
        graph.remove_edge(random.choice(edges))
        available_edges = list(read_graph.edges())
        new_edge = random.choice(available_edges)
        graph.add_edge(new_edge.source(), new_edge.target())

# 主遗传算法
def genetic_algorithm(graph, pop_size, num_generations, mutation_rate, tournament_size):
    population = initialize_population(graph, pop_size)
    best_individual = None
    best_fitness = float('inf')

    for generation in range(num_generations):
        new_population = []
        for _ in range(pop_size // 2):
            parent1 = tournament_selection(population, tournament_size)
            parent2 = tournament_selection(population, tournament_size)
            child1 = crossover(parent1, parent2)
            child2 = crossover(parent2, parent1)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            new_population.extend([child1, child2])

        population = new_population

        # 评估新种群
        for individual in population:
            ind_fitness = fitness(individual)
            if ind_fitness < best_fitness:
                best_fitness = ind_fitness
                best_individual = individual

        print(f"Generation {generation}: Best fitness = {best_fitness}")

    return best_individual

# 执行遗传算法
best_mst = genetic_algorithm(read_graph, POP_SIZE, NUM_GENERATIONS, MUTATION_RATE, TOURNAMENT_SIZE)

# 打印最优解的节点和边数量
print("Best MST nodes: ", best_mst.num_vertices(), "Best MST links: ", best_mst.num_edges())

# 绘制最优解
draw.graph_draw(best_mst, read_pos, vertex_text=best_mst.vertex_properties["number"], edge_color='blue', output_size=(1000, 1000), output=f'./output_GA/{filename1}_{NUM_GENERATIONS}_best_mst.pdf')
# Out:
# nodes:  50 links  69
# Generation 0: Best fitness = 20368
# Generation 1: Best fitness = 20368
# Generation 2: Best fitness = 20368
# Generation 3: Best fitness = 20368
# Generation 4: Best fitness = 20368
# Generation 5: Best fitness = 20368
# Generation 6: Best fitness = 20368
# Generation 7: Best fitness = 20368
# Generation 8: Best fitness = 20368
# Generation 9: Best fitness = 20368
# Generation 10: Best fitness = 20368
# Generation 11: Best fitness = 20368
# Generation 12: Best fitness = 20368
# Generation 13: Best fitness = 20368
# Generation 14: Best fitness = 20368
# Generation 15: Best fitness = 20368
# Generation 16: Best fitness = 19440
# Generation 17: Best fitness = 19440
# Generation 18: Best fitness = 19440
# Generation 19: Best fitness = 19440
# Generation 20: Best fitness = 19440
# Generation 21: Best fitness = 19440
# Generation 22: Best fitness = 19440
# Generation 23: Best fitness = 19440
# Generation 24: Best fitness = 19440
# Generation 25: Best fitness = 19440
# Generation 26: Best fitness = 19440
# Generation 27: Best fitness = 19440
# Generation 28: Best fitness = 19440
# Generation 29: Best fitness = 19440
# Generation 30: Best fitness = 19440
# Generation 31: Best fitness = 19440
# Generation 32: Best fitness = 18912
# Generation 33: Best fitness = 18912
# Generation 34: Best fitness = 18912
# Generation 35: Best fitness = 18912
# Generation 36: Best fitness = 18912
# Generation 37: Best fitness = 18912
# Generation 38: Best fitness = 18912
# Generation 39: Best fitness = 18912
# Generation 40: Best fitness = 18912
# Generation 41: Best fitness = 18912
# Generation 42: Best fitness = 18912
# Generation 43: Best fitness = 18912
# Generation 44: Best fitness = 18912
# Generation 45: Best fitness = 18912
# Generation 46: Best fitness = 18912
# Generation 47: Best fitness = 18912
# Generation 48: Best fitness = 18912
# Generation 49: Best fitness = 18912
# Generation 50: Best fitness = 18912
# Generation 51: Best fitness = 18912
# Generation 52: Best fitness = 18912
# Generation 53: Best fitness = 18912
# Generation 54: Best fitness = 18912
# Generation 55: Best fitness = 18912
# Generation 56: Best fitness = 18912
# Generation 57: Best fitness = 18912
# Generation 58: Best fitness = 18912
# Generation 59: Best fitness = 18912
# Generation 60: Best fitness = 18912
# Generation 61: Best fitness = 18912
# Generation 62: Best fitness = 18912
# Generation 63: Best fitness = 18912
# Generation 64: Best fitness = 18912
# Generation 65: Best fitness = 18912
# Generation 66: Best fitness = 18912
# Generation 67: Best fitness = 18912
# Generation 68: Best fitness = 18912
# Generation 69: Best fitness = 18912
# Generation 70: Best fitness = 18912
# Generation 71: Best fitness = 18912
# Generation 72: Best fitness = 18912
# Generation 73: Best fitness = 18912
# Generation 74: Best fitness = 18912
# Generation 75: Best fitness = 18912
# Generation 76: Best fitness = 18912
# Generation 77: Best fitness = 18912
# Generation 78: Best fitness = 18912
# Generation 79: Best fitness = 18912
# Generation 80: Best fitness = 18912
# Generation 81: Best fitness = 18912
# Generation 82: Best fitness = 18912
# Generation 83: Best fitness = 18912
# Generation 84: Best fitness = 18912
# Generation 85: Best fitness = 18912
# Generation 86: Best fitness = 18912
# Generation 87: Best fitness = 18912
# Generation 88: Best fitness = 18912
# Generation 89: Best fitness = 18912
# Generation 90: Best fitness = 18912
# Generation 91: Best fitness = 18912
# Generation 92: Best fitness = 18912
# Generation 93: Best fitness = 18912
# Generation 94: Best fitness = 18912
# Generation 95: Best fitness = 18912
# Generation 96: Best fitness = 18912
# Generation 97: Best fitness = 18912
# Generation 98: Best fitness = 18912
# Generation 99: Best fitness = 18912
# Generation 100: Best fitness = 18912
# Generation 101: Best fitness = 18912
# Generation 102: Best fitness = 18912
# Generation 103: Best fitness = 18912
# Generation 104: Best fitness = 18912
# Generation 105: Best fitness = 18912
# Generation 106: Best fitness = 18912
# Generation 107: Best fitness = 18912
# Generation 108: Best fitness = 18912
# Generation 109: Best fitness = 18912
# Generation 110: Best fitness = 18912
# Generation 111: Best fitness = 18912
# Generation 112: Best fitness = 18912
# Generation 113: Best fitness = 18912
# Generation 114: Best fitness = 18912
# Generation 115: Best fitness = 18912
# Generation 116: Best fitness = 18912
# Generation 117: Best fitness = 18912
# Generation 118: Best fitness = 18912
# Generation 119: Best fitness = 18912
# Generation 120: Best fitness = 18912
# Generation 121: Best fitness = 18912
# Generation 122: Best fitness = 18912
# Generation 123: Best fitness = 18912
# Generation 124: Best fitness = 18912
# Generation 125: Best fitness = 18912
# Generation 126: Best fitness = 18912
# Generation 127: Best fitness = 18912
# Generation 128: Best fitness = 18912
# Generation 129: Best fitness = 18912
# Generation 130: Best fitness = 18912
# Generation 131: Best fitness = 18912
# Generation 132: Best fitness = 18912
# Generation 133: Best fitness = 18912
# Generation 134: Best fitness = 18912
# Generation 135: Best fitness = 18912
# Generation 136: Best fitness = 18912
# Generation 137: Best fitness = 18912
# Generation 138: Best fitness = 18912
# Generation 139: Best fitness = 18912
# Generation 140: Best fitness = 18912
# Generation 141: Best fitness = 18912
# Generation 142: Best fitness = 18912
# Generation 143: Best fitness = 18912
# Generation 144: Best fitness = 18912
# Generation 145: Best fitness = 18912
# Generation 146: Best fitness = 18912
# Generation 147: Best fitness = 18912
# Generation 148: Best fitness = 18912
# Generation 149: Best fitness = 18912
# Generation 150: Best fitness = 18912
# Generation 151: Best fitness = 18912
# Generation 152: Best fitness = 18912
# Generation 153: Best fitness = 18912
# Generation 154: Best fitness = 18912
# Generation 155: Best fitness = 18912
# Generation 156: Best fitness = 18912
# Generation 157: Best fitness = 18912
# Generation 158: Best fitness = 18912
# Generation 159: Best fitness = 18912
# Generation 160: Best fitness = 18912
# Generation 161: Best fitness = 18912
# Generation 162: Best fitness = 18912
# Generation 163: Best fitness = 18912
# Generation 164: Best fitness = 18912
# Generation 165: Best fitness = 18912
# Generation 166: Best fitness = 18912
# Generation 167: Best fitness = 18912
# Generation 168: Best fitness = 18912
# Generation 169: Best fitness = 18912
# Generation 170: Best fitness = 18912
# Generation 171: Best fitness = 18912
# Generation 172: Best fitness = 18912
# Generation 173: Best fitness = 18912
# Generation 174: Best fitness = 18912
# Generation 175: Best fitness = 18912
# Generation 176: Best fitness = 18912
# Generation 177: Best fitness = 18912
# Generation 178: Best fitness = 18912
# Generation 179: Best fitness = 18912
# Generation 180: Best fitness = 18912
# Generation 181: Best fitness = 18912
# Generation 182: Best fitness = 18912
# Generation 183: Best fitness = 18912
# Generation 184: Best fitness = 18912
# Generation 185: Best fitness = 18912
# Generation 186: Best fitness = 18912
# Generation 187: Best fitness = 18912
# Generation 188: Best fitness = 18912
# Generation 189: Best fitness = 18912
# Generation 190: Best fitness = 17064
# Generation 191: Best fitness = 17064
# Generation 192: Best fitness = 17064
# Generation 193: Best fitness = 17064
# Generation 194: Best fitness = 17064
# Generation 195: Best fitness = 17064
# Generation 196: Best fitness = 17064
# Generation 197: Best fitness = 17064
# Generation 198: Best fitness = 17064
# Generation 199: Best fitness = 17064
# Generation 200: Best fitness = 17064
# Generation 201: Best fitness = 17064
# Generation 202: Best fitness = 17064
# Generation 203: Best fitness = 17064
# Generation 204: Best fitness = 17064
# Generation 205: Best fitness = 17064
# Generation 206: Best fitness = 17064
# Generation 207: Best fitness = 17064
# Generation 208: Best fitness = 17064
# Generation 209: Best fitness = 17064
# Generation 210: Best fitness = 17064
# Generation 211: Best fitness = 17064
# Generation 212: Best fitness = 17064
# Generation 213: Best fitness = 17064
# Generation 214: Best fitness = 17064
# Generation 215: Best fitness = 17064
# Generation 216: Best fitness = 17064
# Generation 217: Best fitness = 17064
# Generation 218: Best fitness = 17064
# Generation 219: Best fitness = 17064
# Generation 220: Best fitness = 17064
# Generation 221: Best fitness = 17064
# Generation 222: Best fitness = 17064
# Generation 223: Best fitness = 17064
# Generation 224: Best fitness = 17064
# Generation 225: Best fitness = 17064
# Generation 226: Best fitness = 17064
# Generation 227: Best fitness = 17064
# Generation 228: Best fitness = 17064
# Generation 229: Best fitness = 17064
# Generation 230: Best fitness = 17064
# Generation 231: Best fitness = 17064
# Generation 232: Best fitness = 17064
# Generation 233: Best fitness = 17064
# Generation 234: Best fitness = 17064
# Generation 235: Best fitness = 17064
# Generation 236: Best fitness = 17064
# Generation 237: Best fitness = 17064
# Generation 238: Best fitness = 17064
# Generation 239: Best fitness = 17064
# Generation 240: Best fitness = 17064
# Generation 241: Best fitness = 17064
# Generation 242: Best fitness = 17064
# Generation 243: Best fitness = 17064
# Generation 244: Best fitness = 17064
# Generation 245: Best fitness = 17064
# Generation 246: Best fitness = 17064
# Generation 247: Best fitness = 17064
# Generation 248: Best fitness = 17064
# Generation 249: Best fitness = 17064
# Generation 250: Best fitness = 17064
# Generation 251: Best fitness = 17064
# Generation 252: Best fitness = 17064
# Generation 253: Best fitness = 16976
# Generation 254: Best fitness = 16976
# Generation 255: Best fitness = 16976
# Generation 256: Best fitness = 16976
# Generation 257: Best fitness = 16976
# Generation 258: Best fitness = 16976
# Generation 259: Best fitness = 16976
# Generation 260: Best fitness = 16976
# Generation 261: Best fitness = 16976
# Generation 262: Best fitness = 16976
# Generation 263: Best fitness = 16976
# Generation 264: Best fitness = 16976
# Generation 265: Best fitness = 16976
# Generation 266: Best fitness = 16976
# Generation 267: Best fitness = 16976
# Generation 268: Best fitness = 16976
# Generation 269: Best fitness = 16976
# Generation 270: Best fitness = 16976
# Generation 271: Best fitness = 16976
# Generation 272: Best fitness = 16976
# Generation 273: Best fitness = 16976
# Generation 274: Best fitness = 16976
# Generation 275: Best fitness = 16976
# Generation 276: Best fitness = 16976
# Generation 277: Best fitness = 16976
# Generation 278: Best fitness = 16976
# Generation 279: Best fitness = 16976
# Generation 280: Best fitness = 16976
# Generation 281: Best fitness = 16976
# Generation 282: Best fitness = 16976
# Generation 283: Best fitness = 16976
# Generation 284: Best fitness = 16976
# Generation 285: Best fitness = 16976
# Generation 286: Best fitness = 16976
# Generation 287: Best fitness = 16976
# Generation 288: Best fitness = 16976
# Generation 289: Best fitness = 16976
# Generation 290: Best fitness = 16976
# Generation 291: Best fitness = 16976
# Generation 292: Best fitness = 16976
# Generation 293: Best fitness = 16928
# Generation 294: Best fitness = 16928
# Generation 295: Best fitness = 16928
# Generation 296: Best fitness = 16928
# Generation 297: Best fitness = 16928
# Generation 298: Best fitness = 16928
# Generation 299: Best fitness = 16928
# Best MST nodes:  50 Best MST links:  49
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7c21841e18e0, at 0x7c2187ab6270>

# %%
import random
from graph_tool import Graph, draw
from graph_tool.topology import min_spanning_tree, shortest_distance
import python_codes.files_operators

filename1 = "Germany50"

# 读取网络数据
read_graph, read_pos = python_codes.files_operators.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 参数设置
POP_SIZE = 50
NUM_GENERATIONS = 500
MUTATION_RATE = 0.1
TOURNAMENT_SIZE = 3

# 初始化种群
def initialize_population(graph, pop_size):
    population = []
    for _ in range(pop_size):
        mst = min_spanning_tree(graph)
        mst_graph = Graph(directed=False)
        mst_graph.add_vertex(graph.num_vertices())
        for edge, in_mst in zip(graph.edges(), mst):
            if in_mst:
                mst_graph.add_edge(edge.source(), edge.target())
        # 复制顶点和边属性
        for prop_name, prop_map in graph.vertex_properties.items():
            mst_graph.vertex_properties[prop_name] = mst_graph.new_vertex_property(prop_map.value_type())
            for v in mst_graph.vertices():
                mst_graph.vertex_properties[prop_name][v] = graph.vertex_properties[prop_name][v]
        for prop_name, prop_map in graph.edge_properties.items():
            mst_graph.edge_properties[prop_name] = mst_graph.new_edge_property(prop_map.value_type())
            for e in mst_graph.edges():
                mst_graph.edge_properties[prop_name][e] = graph.edge_properties[prop_name][graph.edge(e.source(), e.target())]
        population.append(mst_graph)
    return population

# 适应度函数：计算总路径长度
def fitness(graph):
    total_length = 0
    for v in graph.vertices():
        dist_map = shortest_distance(graph, source=v)
        total_length += sum(dist_map.a)
    return total_length

# 选择父代
def tournament_selection(population, k):
    selected = random.sample(population, k)
    selected.sort(key=fitness)
    return selected[0]

# 交叉操作
def crossover(parent1, parent2):
    size = parent1.num_edges()
    edges1 = list(parent1.edges())
    edges2 = list(parent2.edges())
    child = Graph(directed=False)
    child.add_vertex(parent1.num_vertices())
    for i in range(size // 2):
        edge = edges1[i]
        child.add_edge(edge.source(), edge.target())
    for i in range(size // 2, size):
        edge = edges2[i]
        child.add_edge(edge.source(), edge.target())
    # 复制顶点和边属性
    for prop_name, prop_map in parent1.vertex_properties.items():
        child.vertex_properties[prop_name] = child.new_vertex_property(prop_map.value_type())
        for v in child.vertices():
            child.vertex_properties[prop_name][v] = parent1.vertex_properties[prop_name][v]
    for prop_name, prop_map in parent1.edge_properties.items():
        child.edge_properties[prop_name] = child.new_edge_property(prop_map.value_type())
        for e in child.edges():
            child.edge_properties[prop_name][e] = parent1.edge_properties[prop_name][parent1.edge(e.source(), e.target())]
    return child

# 变异操作
def mutate(graph, mutation_rate):
    if random.random() < mutation_rate:
        edges = list(graph.edges())
        graph.remove_edge(random.choice(edges))
        available_edges = list(read_graph.edges())
        new_edge = random.choice(available_edges)
        graph.add_edge(new_edge.source(), new_edge.target())

# 主遗传算法
def genetic_algorithm(graph, pop_size, num_generations, mutation_rate, tournament_size):
    population = initialize_population(graph, pop_size)
    best_individual = None
    best_fitness = float('inf')

    for generation in range(num_generations):
        new_population = []
        for _ in range(pop_size // 2):
            parent1 = tournament_selection(population, tournament_size)
            parent2 = tournament_selection(population, tournament_size)
            child1 = crossover(parent1, parent2)
            child2 = crossover(parent2, parent1)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            new_population.extend([child1, child2])

        population = new_population

        # 评估新种群
        for individual in population:
            ind_fitness = fitness(individual)
            if ind_fitness < best_fitness:
                best_fitness = ind_fitness
                best_individual = individual

        print(f"Generation {generation}: Best fitness = {best_fitness}")

    return best_individual

# 执行遗传算法
best_mst = genetic_algorithm(read_graph, POP_SIZE, NUM_GENERATIONS, MUTATION_RATE, TOURNAMENT_SIZE)

# 打印最优解的节点和边数量
print("Best MST nodes: ", best_mst.num_vertices(), "Best MST links: ", best_mst.num_edges())

# 绘制最优解
draw.graph_draw(best_mst, read_pos, vertex_text=best_mst.vertex_properties["number"], edge_color='blue', output_size=(1000, 1000), output=f'./output_GA/{filename1}_{NUM_GENERATIONS}_best_mst.pdf')
# Out:
# nodes:  50 links  69
# Generation 0: Best fitness = 20368
# Generation 1: Best fitness = 20368
# Generation 2: Best fitness = 20368
# Generation 3: Best fitness = 20368
# Generation 4: Best fitness = 20368
# Generation 5: Best fitness = 20368
# Generation 6: Best fitness = 20368
# Generation 7: Best fitness = 20368
# Generation 8: Best fitness = 20368
# Generation 9: Best fitness = 20368
# Generation 10: Best fitness = 20368
# Generation 11: Best fitness = 20368
# Generation 12: Best fitness = 20368
# Generation 13: Best fitness = 18128
# Generation 14: Best fitness = 18128
# Generation 15: Best fitness = 18128
# Generation 16: Best fitness = 18128
# Generation 17: Best fitness = 18128
# Generation 18: Best fitness = 18128
# Generation 19: Best fitness = 18128
# Generation 20: Best fitness = 18128
# Generation 21: Best fitness = 18128
# Generation 22: Best fitness = 18128
# Generation 23: Best fitness = 18128
# Generation 24: Best fitness = 18128
# Generation 25: Best fitness = 18128
# Generation 26: Best fitness = 18128
# Generation 27: Best fitness = 18128
# Generation 28: Best fitness = 18128
# Generation 29: Best fitness = 18128
# Generation 30: Best fitness = 18128
# Generation 31: Best fitness = 18128
# Generation 32: Best fitness = 18128
# Generation 33: Best fitness = 18128
# Generation 34: Best fitness = 18128
# Generation 35: Best fitness = 18128
# Generation 36: Best fitness = 18128
# Generation 37: Best fitness = 18128
# Generation 38: Best fitness = 18128
# Generation 39: Best fitness = 18128
# Generation 40: Best fitness = 18128
# Generation 41: Best fitness = 18128
# Generation 42: Best fitness = 18128
# Generation 43: Best fitness = 18128
# Generation 44: Best fitness = 18128
# Generation 45: Best fitness = 18128
# Generation 46: Best fitness = 18128
# Generation 47: Best fitness = 18128
# Generation 48: Best fitness = 18128
# Generation 49: Best fitness = 18128
# Generation 50: Best fitness = 18128
# Generation 51: Best fitness = 18128
# Generation 52: Best fitness = 18128
# Generation 53: Best fitness = 18128
# Generation 54: Best fitness = 18128
# Generation 55: Best fitness = 18128
# Generation 56: Best fitness = 18128
# Generation 57: Best fitness = 18018
# Generation 58: Best fitness = 18018
# Generation 59: Best fitness = 18018
# Generation 60: Best fitness = 18018
# Generation 61: Best fitness = 18018
# Generation 62: Best fitness = 17594
# Generation 63: Best fitness = 17594
# Generation 64: Best fitness = 17594
# Generation 65: Best fitness = 17594
# Generation 66: Best fitness = 17594
# Generation 67: Best fitness = 17594
# Generation 68: Best fitness = 17594
# Generation 69: Best fitness = 17594
# Generation 70: Best fitness = 17594
# Generation 71: Best fitness = 17594
# Generation 72: Best fitness = 17362
# Generation 73: Best fitness = 17362
# Generation 74: Best fitness = 17362
# Generation 75: Best fitness = 17362
# Generation 76: Best fitness = 17362
# Generation 77: Best fitness = 17362
# Generation 78: Best fitness = 17362
# Generation 79: Best fitness = 17362
# Generation 80: Best fitness = 17362
# Generation 81: Best fitness = 17362
# Generation 82: Best fitness = 17362
# Generation 83: Best fitness = 17362
# Generation 84: Best fitness = 17362
# Generation 85: Best fitness = 17362
# Generation 86: Best fitness = 17362
# Generation 87: Best fitness = 17362
# Generation 88: Best fitness = 17362
# Generation 89: Best fitness = 17362
# Generation 90: Best fitness = 17362
# Generation 91: Best fitness = 17362
# Generation 92: Best fitness = 17362
# Generation 93: Best fitness = 17362
# Generation 94: Best fitness = 17362
# Generation 95: Best fitness = 17362
# Generation 96: Best fitness = 17362
# Generation 97: Best fitness = 17362
# Generation 98: Best fitness = 17362
# Generation 99: Best fitness = 17362
# Generation 100: Best fitness = 17362
# Generation 101: Best fitness = 17362
# Generation 102: Best fitness = 17362
# Generation 103: Best fitness = 17362
# Generation 104: Best fitness = 17362
# Generation 105: Best fitness = 17362
# Generation 106: Best fitness = 17362
# Generation 107: Best fitness = 17362
# Generation 108: Best fitness = 17362
# Generation 109: Best fitness = 17362
# Generation 110: Best fitness = 17362
# Generation 111: Best fitness = 17362
# Generation 112: Best fitness = 17362
# Generation 113: Best fitness = 17362
# Generation 114: Best fitness = 17362
# Generation 115: Best fitness = 17362
# Generation 116: Best fitness = 17362
# Generation 117: Best fitness = 17362
# Generation 118: Best fitness = 17362
# Generation 119: Best fitness = 17362
# Generation 120: Best fitness = 17362
# Generation 121: Best fitness = 17362
# Generation 122: Best fitness = 17362
# Generation 123: Best fitness = 17362
# Generation 124: Best fitness = 17362
# Generation 125: Best fitness = 17362
# Generation 126: Best fitness = 17362
# Generation 127: Best fitness = 17362
# Generation 128: Best fitness = 17362
# Generation 129: Best fitness = 17362
# Generation 130: Best fitness = 17362
# Generation 131: Best fitness = 17362
# Generation 132: Best fitness = 17362
# Generation 133: Best fitness = 17362
# Generation 134: Best fitness = 17362
# Generation 135: Best fitness = 17362
# Generation 136: Best fitness = 17362
# Generation 137: Best fitness = 17362
# Generation 138: Best fitness = 17362
# Generation 139: Best fitness = 17362
# Generation 140: Best fitness = 17362
# Generation 141: Best fitness = 17362
# Generation 142: Best fitness = 17362
# Generation 143: Best fitness = 17362
# Generation 144: Best fitness = 17362
# Generation 145: Best fitness = 17362
# Generation 146: Best fitness = 17362
# Generation 147: Best fitness = 17362
# Generation 148: Best fitness = 17362
# Generation 149: Best fitness = 17362
# Generation 150: Best fitness = 17362
# Generation 151: Best fitness = 17362
# Generation 152: Best fitness = 17362
# Generation 153: Best fitness = 17362
# Generation 154: Best fitness = 17362
# Generation 155: Best fitness = 17362
# Generation 156: Best fitness = 17362
# Generation 157: Best fitness = 17362
# Generation 158: Best fitness = 17362
# Generation 159: Best fitness = 17362
# Generation 160: Best fitness = 17362
# Generation 161: Best fitness = 17362
# Generation 162: Best fitness = 17362
# Generation 163: Best fitness = 17362
# Generation 164: Best fitness = 17362
# Generation 165: Best fitness = 17362
# Generation 166: Best fitness = 17362
# Generation 167: Best fitness = 17362
# Generation 168: Best fitness = 17362
# Generation 169: Best fitness = 17362
# Generation 170: Best fitness = 17362
# Generation 171: Best fitness = 17362
# Generation 172: Best fitness = 17362
# Generation 173: Best fitness = 17362
# Generation 174: Best fitness = 17362
# Generation 175: Best fitness = 17362
# Generation 176: Best fitness = 17362
# Generation 177: Best fitness = 17272
# Generation 178: Best fitness = 17272
# Generation 179: Best fitness = 17272
# Generation 180: Best fitness = 17272
# Generation 181: Best fitness = 17074
# Generation 182: Best fitness = 17074
# Generation 183: Best fitness = 17074
# Generation 184: Best fitness = 17074
# Generation 185: Best fitness = 17074
# Generation 186: Best fitness = 17074
# Generation 187: Best fitness = 17074
# Generation 188: Best fitness = 17074
# Generation 189: Best fitness = 17074
# Generation 190: Best fitness = 17074
# Generation 191: Best fitness = 17074
# Generation 192: Best fitness = 17074
# Generation 193: Best fitness = 17074
# Generation 194: Best fitness = 17074
# Generation 195: Best fitness = 17074
# Generation 196: Best fitness = 17074
# Generation 197: Best fitness = 17074
# Generation 198: Best fitness = 17074
# Generation 199: Best fitness = 17074
# Generation 200: Best fitness = 17074
# Generation 201: Best fitness = 17074
# Generation 202: Best fitness = 17074
# Generation 203: Best fitness = 17074
# Generation 204: Best fitness = 17074
# Generation 205: Best fitness = 17074
# Generation 206: Best fitness = 17074
# Generation 207: Best fitness = 17074
# Generation 208: Best fitness = 17074
# Generation 209: Best fitness = 17074
# Generation 210: Best fitness = 17074
# Generation 211: Best fitness = 17074
# Generation 212: Best fitness = 17074
# Generation 213: Best fitness = 17074
# Generation 214: Best fitness = 17074
# Generation 215: Best fitness = 17074
# Generation 216: Best fitness = 17074
# Generation 217: Best fitness = 17074
# Generation 218: Best fitness = 17074
# Generation 219: Best fitness = 17074
# Generation 220: Best fitness = 17074
# Generation 221: Best fitness = 17074
# Generation 222: Best fitness = 17074
# Generation 223: Best fitness = 17074
# Generation 224: Best fitness = 17074
# Generation 225: Best fitness = 17074
# Generation 226: Best fitness = 17074
# Generation 227: Best fitness = 17074
# Generation 228: Best fitness = 17074
# Generation 229: Best fitness = 17074
# Generation 230: Best fitness = 17074
# Generation 231: Best fitness = 17074
# Generation 232: Best fitness = 17074
# Generation 233: Best fitness = 17074
# Generation 234: Best fitness = 17074
# Generation 235: Best fitness = 17074
# Generation 236: Best fitness = 17074
# Generation 237: Best fitness = 17074
# Generation 238: Best fitness = 17074
# Generation 239: Best fitness = 17074
# Generation 240: Best fitness = 17074
# Generation 241: Best fitness = 17074
# Generation 242: Best fitness = 17074
# Generation 243: Best fitness = 17074
# Generation 244: Best fitness = 17074
# Generation 245: Best fitness = 17074
# Generation 246: Best fitness = 17074
# Generation 247: Best fitness = 17074
# Generation 248: Best fitness = 17074
# Generation 249: Best fitness = 17074
# Generation 250: Best fitness = 17074
# Generation 251: Best fitness = 17074
# Generation 252: Best fitness = 17074
# Generation 253: Best fitness = 17074
# Generation 254: Best fitness = 17074
# Generation 255: Best fitness = 17074
# Generation 256: Best fitness = 17074
# Generation 257: Best fitness = 17074
# Generation 258: Best fitness = 17074
# Generation 259: Best fitness = 17074
# Generation 260: Best fitness = 17074
# Generation 261: Best fitness = 17074
# Generation 262: Best fitness = 17074
# Generation 263: Best fitness = 17074
# Generation 264: Best fitness = 17074
# Generation 265: Best fitness = 17074
# Generation 266: Best fitness = 16956
# Generation 267: Best fitness = 16956
# Generation 268: Best fitness = 16956
# Generation 269: Best fitness = 16956
# Generation 270: Best fitness = 16956
# Generation 271: Best fitness = 16956
# Generation 272: Best fitness = 16956
# Generation 273: Best fitness = 16956
# Generation 274: Best fitness = 16956
# Generation 275: Best fitness = 16956
# Generation 276: Best fitness = 16956
# Generation 277: Best fitness = 16956
# Generation 278: Best fitness = 16956
# Generation 279: Best fitness = 16956
# Generation 280: Best fitness = 16956
# Generation 281: Best fitness = 16956
# Generation 282: Best fitness = 16956
# Generation 283: Best fitness = 16956
# Generation 284: Best fitness = 16956
# Generation 285: Best fitness = 16666
# Generation 286: Best fitness = 16666
# Generation 287: Best fitness = 16666
# Generation 288: Best fitness = 16666
# Generation 289: Best fitness = 16666
# Generation 290: Best fitness = 16666
# Generation 291: Best fitness = 16666
# Generation 292: Best fitness = 16666
# Generation 293: Best fitness = 16666
# Generation 294: Best fitness = 16666
# Generation 295: Best fitness = 16666
# Generation 296: Best fitness = 16666
# Generation 297: Best fitness = 16666
# Generation 298: Best fitness = 16666
# Generation 299: Best fitness = 16666
# Generation 300: Best fitness = 16666
# Generation 301: Best fitness = 16666
# Generation 302: Best fitness = 16666
# Generation 303: Best fitness = 16666
# Generation 304: Best fitness = 16666
# Generation 305: Best fitness = 16666
# Generation 306: Best fitness = 16666
# Generation 307: Best fitness = 16666
# Generation 308: Best fitness = 16666
# Generation 309: Best fitness = 16666
# Generation 310: Best fitness = 16666
# Generation 311: Best fitness = 16666
# Generation 312: Best fitness = 16666
# Generation 313: Best fitness = 16666
# Generation 314: Best fitness = 16666
# Generation 315: Best fitness = 16666
# Generation 316: Best fitness = 16666
# Generation 317: Best fitness = 16666
# Generation 318: Best fitness = 16666
# Generation 319: Best fitness = 16666
# Generation 320: Best fitness = 16666
# Generation 321: Best fitness = 16666
# Generation 322: Best fitness = 16666
# Generation 323: Best fitness = 16666
# Generation 324: Best fitness = 16666
# Generation 325: Best fitness = 16666
# Generation 326: Best fitness = 16666
# Generation 327: Best fitness = 16666
# Generation 328: Best fitness = 16666
# Generation 329: Best fitness = 16666
# Generation 330: Best fitness = 16666
# Generation 331: Best fitness = 16666
# Generation 332: Best fitness = 16666
# Generation 333: Best fitness = 16666
# Generation 334: Best fitness = 16666
# Generation 335: Best fitness = 16666
# Generation 336: Best fitness = 16666
# Generation 337: Best fitness = 16666
# Generation 338: Best fitness = 16666
# Generation 339: Best fitness = 16666
# Generation 340: Best fitness = 16666
# Generation 341: Best fitness = 16666
# Generation 342: Best fitness = 16666
# Generation 343: Best fitness = 16666
# Generation 344: Best fitness = 16666
# Generation 345: Best fitness = 16666
# Generation 346: Best fitness = 16666
# Generation 347: Best fitness = 16666
# Generation 348: Best fitness = 16666
# Generation 349: Best fitness = 16666
# Generation 350: Best fitness = 16666
# Generation 351: Best fitness = 16666
# Generation 352: Best fitness = 16666
# Generation 353: Best fitness = 16666
# Generation 354: Best fitness = 16666
# Generation 355: Best fitness = 16666
# Generation 356: Best fitness = 16666
# Generation 357: Best fitness = 16666
# Generation 358: Best fitness = 16666
# Generation 359: Best fitness = 16666
# Generation 360: Best fitness = 16666
# Generation 361: Best fitness = 16666
# Generation 362: Best fitness = 16666
# Generation 363: Best fitness = 16666
# Generation 364: Best fitness = 16666
# Generation 365: Best fitness = 16666
# Generation 366: Best fitness = 16666
# Generation 367: Best fitness = 16666
# Generation 368: Best fitness = 16666
# Generation 369: Best fitness = 16666
# Generation 370: Best fitness = 16666
# Generation 371: Best fitness = 16666
# Generation 372: Best fitness = 16666
# Generation 373: Best fitness = 16666
# Generation 374: Best fitness = 16666
# Generation 375: Best fitness = 16666
# Generation 376: Best fitness = 16666
# Generation 377: Best fitness = 16666
# Generation 378: Best fitness = 16666
# Generation 379: Best fitness = 16666
# Generation 380: Best fitness = 16666
# Generation 381: Best fitness = 16666
# Generation 382: Best fitness = 16666
# Generation 383: Best fitness = 16666
# Generation 384: Best fitness = 16666
# Generation 385: Best fitness = 16666
# Generation 386: Best fitness = 16666
# Generation 387: Best fitness = 16666
# Generation 388: Best fitness = 16666
# Generation 389: Best fitness = 16666
# Generation 390: Best fitness = 16666
# Generation 391: Best fitness = 16666
# Generation 392: Best fitness = 16666
# Generation 393: Best fitness = 16666
# Generation 394: Best fitness = 16666
# Generation 395: Best fitness = 16666
# Generation 396: Best fitness = 16666
# Generation 397: Best fitness = 16666
# Generation 398: Best fitness = 16666
# Generation 399: Best fitness = 16666
# Generation 400: Best fitness = 16666
# Generation 401: Best fitness = 16666
# Generation 402: Best fitness = 16666
# Generation 403: Best fitness = 16666
# Generation 404: Best fitness = 16666
# Generation 405: Best fitness = 16666
# Generation 406: Best fitness = 16666
# Generation 407: Best fitness = 16666
# Generation 408: Best fitness = 16666
# Generation 409: Best fitness = 16666
# Generation 410: Best fitness = 16666
# Generation 411: Best fitness = 16666
# Generation 412: Best fitness = 16666
# Generation 413: Best fitness = 16512
# Generation 414: Best fitness = 16512
# Generation 415: Best fitness = 16512
# Generation 416: Best fitness = 16512
# Generation 417: Best fitness = 16512
# Generation 418: Best fitness = 16512
# Generation 419: Best fitness = 16512
# Generation 420: Best fitness = 16512
# Generation 421: Best fitness = 16512
# Generation 422: Best fitness = 16512
# Generation 423: Best fitness = 16512
# Generation 424: Best fitness = 16512
# Generation 425: Best fitness = 16512
# Generation 426: Best fitness = 16512
# Generation 427: Best fitness = 16512
# Generation 428: Best fitness = 16512
# Generation 429: Best fitness = 16512
# Generation 430: Best fitness = 16512
# Generation 431: Best fitness = 16512
# Generation 432: Best fitness = 16512
# Generation 433: Best fitness = 16512
# Generation 434: Best fitness = 16512
# Generation 435: Best fitness = 16512
# Generation 436: Best fitness = 16512
# Generation 437: Best fitness = 16512
# Generation 438: Best fitness = 16512
# Generation 439: Best fitness = 16512
# Generation 440: Best fitness = 16512
# Generation 441: Best fitness = 16512
# Generation 442: Best fitness = 16512
# Generation 443: Best fitness = 16512
# Generation 444: Best fitness = 16512
# Generation 445: Best fitness = 16512
# Generation 446: Best fitness = 16512
# Generation 447: Best fitness = 16512
# Generation 448: Best fitness = 16512
# Generation 449: Best fitness = 16512
# Generation 450: Best fitness = 16512
# Generation 451: Best fitness = 16512
# Generation 452: Best fitness = 16512
# Generation 453: Best fitness = 16512
# Generation 454: Best fitness = 16512
# Generation 455: Best fitness = 16512
# Generation 456: Best fitness = 16512
# Generation 457: Best fitness = 16512
# Generation 458: Best fitness = 16512
# Generation 459: Best fitness = 16512
# Generation 460: Best fitness = 16512
# Generation 461: Best fitness = 16512
# Generation 462: Best fitness = 16512
# Generation 463: Best fitness = 16512
# Generation 464: Best fitness = 16512
# Generation 465: Best fitness = 16512
# Generation 466: Best fitness = 16512
# Generation 467: Best fitness = 16512
# Generation 468: Best fitness = 16512
# Generation 469: Best fitness = 16512
# Generation 470: Best fitness = 16512
# Generation 471: Best fitness = 16512
# Generation 472: Best fitness = 16512
# Generation 473: Best fitness = 16512
# Generation 474: Best fitness = 16512
# Generation 475: Best fitness = 16512
# Generation 476: Best fitness = 16512
# Generation 477: Best fitness = 16512
# Generation 478: Best fitness = 16512
# Generation 479: Best fitness = 16512
# Generation 480: Best fitness = 16512
# Generation 481: Best fitness = 16512
# Generation 482: Best fitness = 16512
# Generation 483: Best fitness = 16512
# Generation 484: Best fitness = 16512
# Generation 485: Best fitness = 16512
# Generation 486: Best fitness = 16512
# Generation 487: Best fitness = 16512
# Generation 488: Best fitness = 16512
# Generation 489: Best fitness = 16512
# Generation 490: Best fitness = 16512
# Generation 491: Best fitness = 16512
# Generation 492: Best fitness = 16512
# Generation 493: Best fitness = 16512
# Generation 494: Best fitness = 16512
# Generation 495: Best fitness = 16512
# Generation 496: Best fitness = 16512
# Generation 497: Best fitness = 16512
# Generation 498: Best fitness = 16512
# Generation 499: Best fitness = 16512
# Best MST nodes:  50 Best MST links:  49
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7c21867de9f0, at 0x7c218676d580>
