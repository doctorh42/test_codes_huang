# %%
import random
from graph_tool import Graph, draw
from graph_tool.topology import min_spanning_tree, shortest_distance
import python_codes.files_operators

filename1 = "Germany50"

# 读取网络数据
read_graph, read_pos = python_codes.files_operators.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 参数设置
POP_SIZE = 50
NUM_GENERATIONS = 100
MUTATION_RATE = 0.1
TOURNAMENT_SIZE = 3

# 初始化种群
def initialize_population(graph, pop_size):
    population = []
    for _ in range(pop_size):
        mst = min_spanning_tree(graph)
        mst_graph = Graph(directed=False)
        mst_graph.add_vertex(graph.num_vertices())
        for edge, in_mst in zip(graph.edges(), mst):
            if in_mst:
                mst_graph.add_edge(edge.source(), edge.target())
        population.append(mst_graph)
    return population

# 适应度函数：计算总路径长度
def fitness(graph):
    total_length = 0
    for v in graph.vertices():
        dist_map = shortest_distance(graph, source=v)
        total_length += sum(dist_map.a)
    return total_length

# 选择父代
def tournament_selection(population, k):
    selected = random.sample(population, k)
    selected.sort(key=fitness)
    return selected[0]

# 交叉操作
def crossover(parent1, parent2):
    size = parent1.num_edges()
    edges1 = list(parent1.edges())
    edges2 = list(parent2.edges())
    child = Graph(directed=False)
    child.add_vertex(parent1.num_vertices())
    for i in range(size // 2):
        edge = edges1[i]
        child.add_edge(edge.source(), edge.target())
    for i in range(size // 2, size):
        edge = edges2[i]
        child.add_edge(edge.source(), edge.target())
    return child

# 变异操作
def mutate(graph, mutation_rate):
    if random.random() < mutation_rate:
        edges = list(graph.edges())
        graph.remove_edge(random.choice(edges))
        available_edges = list(read_graph.edges())
        new_edge = random.choice(available_edges)
        graph.add_edge(new_edge.source(), new_edge.target())

# 主遗传算法
def genetic_algorithm(graph, pop_size, num_generations, mutation_rate, tournament_size):
    population = initialize_population(graph, pop_size)
    best_individual = None
    best_fitness = float('inf')

    for generation in range(num_generations):
        new_population = []
        for _ in range(pop_size // 2):
            parent1 = tournament_selection(population, tournament_size)
            parent2 = tournament_selection(population, tournament_size)
            child1 = crossover(parent1, parent2)
            child2 = crossover(parent2, parent1)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            new_population.extend([child1, child2])

        population = new_population

        # 评估新种群
        for individual in population:
            ind_fitness = fitness(individual)
            if ind_fitness < best_fitness:
                best_fitness = ind_fitness
                best_individual = individual

        print(f"Generation {generation}: Best fitness = {best_fitness}")

    return best_individual

# 执行遗传算法
best_mst = genetic_algorithm(read_graph, POP_SIZE, NUM_GENERATIONS, MUTATION_RATE, TOURNAMENT_SIZE)

# 打印最优解的节点和边数量
print("Best MST nodes: ", best_mst.num_vertices(), "Best MST links: ", best_mst.num_edges())

# 绘制最优解
draw.graph_draw(best_mst, read_pos, vertex_text=best_mst.vertex_properties["number"], edge_color='blue', output_size=(1000, 1000), output=f'./output_GA/{filename1}_best_mst.pdf')
# Out:
# nodes:  50 links  69
# Generation 0: Best fitness = 20368
# Generation 1: Best fitness = 20368
# Generation 2: Best fitness = 20368
# Generation 3: Best fitness = 20368
# Generation 4: Best fitness = 20368
# Generation 5: Best fitness = 20368
# Generation 6: Best fitness = 20368
# Generation 7: Best fitness = 20368
# Generation 8: Best fitness = 20368
# Generation 9: Best fitness = 20368
# Generation 10: Best fitness = 20368
# Generation 11: Best fitness = 20368
# Generation 12: Best fitness = 20368
# Generation 13: Best fitness = 20368
# Generation 14: Best fitness = 20368
# Generation 15: Best fitness = 20368
# Generation 16: Best fitness = 20368
# Generation 17: Best fitness = 20368
# Generation 18: Best fitness = 18458
# Generation 19: Best fitness = 18458
# Generation 20: Best fitness = 18458
# Generation 21: Best fitness = 18458
# Generation 22: Best fitness = 18458
# Generation 23: Best fitness = 18458
# Generation 24: Best fitness = 18458
# Generation 25: Best fitness = 18458
# Generation 26: Best fitness = 18458
# Generation 27: Best fitness = 18458
# Generation 28: Best fitness = 18458
# Generation 29: Best fitness = 18458
# Generation 30: Best fitness = 18458
# Generation 31: Best fitness = 18458
# Generation 32: Best fitness = 18458
# Generation 33: Best fitness = 18458
# Generation 34: Best fitness = 18458
# Generation 35: Best fitness = 18458
# Generation 36: Best fitness = 18458
# Generation 37: Best fitness = 18458
# Generation 38: Best fitness = 18458
# Generation 39: Best fitness = 18458
# Generation 40: Best fitness = 18458
# Generation 41: Best fitness = 18458
# Generation 42: Best fitness = 18458
# Generation 43: Best fitness = 18458
# Generation 44: Best fitness = 18458
# Generation 45: Best fitness = 18458
# Generation 46: Best fitness = 18458
# Generation 47: Best fitness = 18458
# Generation 48: Best fitness = 18458
# Generation 49: Best fitness = 18458
# Generation 50: Best fitness = 18458
# Generation 51: Best fitness = 18458
# Generation 52: Best fitness = 17438
# Generation 53: Best fitness = 17438
# Generation 54: Best fitness = 17438
# Generation 55: Best fitness = 17438
# Generation 56: Best fitness = 17438
# Generation 57: Best fitness = 17438
# Generation 58: Best fitness = 17438
# Generation 59: Best fitness = 17438
# Generation 60: Best fitness = 17438
# Generation 61: Best fitness = 17438
# Generation 62: Best fitness = 17438
# Generation 63: Best fitness = 17438
# Generation 64: Best fitness = 17438
# Generation 65: Best fitness = 17438
# Generation 66: Best fitness = 17438
# Generation 67: Best fitness = 17438
# Generation 68: Best fitness = 17438
# Generation 69: Best fitness = 17438
# Generation 70: Best fitness = 17438
# Generation 71: Best fitness = 17438
# Generation 72: Best fitness = 17438
# Generation 73: Best fitness = 17438
# Generation 74: Best fitness = 17438
# Generation 75: Best fitness = 17438
# Generation 76: Best fitness = 17438
# Generation 77: Best fitness = 17438
# Generation 78: Best fitness = 17438
# Generation 79: Best fitness = 17438
# Generation 80: Best fitness = 17438
# Generation 81: Best fitness = 17438
# Generation 82: Best fitness = 17438
# Generation 83: Best fitness = 17438
# Generation 84: Best fitness = 17438
# Generation 85: Best fitness = 17438
# Generation 86: Best fitness = 17438
# Generation 87: Best fitness = 17438
# Generation 88: Best fitness = 17438
# Generation 89: Best fitness = 17438
# Generation 90: Best fitness = 17438
# Generation 91: Best fitness = 17438
# Generation 92: Best fitness = 17438
# Generation 93: Best fitness = 17438
# Generation 94: Best fitness = 17438
# Generation 95: Best fitness = 17438
# Generation 96: Best fitness = 17438
# Generation 97: Best fitness = 17438
# Generation 98: Best fitness = 17438
# Generation 99: Best fitness = 17438
# Best MST nodes:  50 Best MST links:  49
# /home/huanghanjun/anaconda3/envs/graph-tool/lib/python3.12/site-packages/graph_tool/__init__.py:2004: SyntaxWarning: invalid escape sequence '\m'
#   """Return the edge from vertex ``s`` to ``t``, if it exists. If
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 106
#     103 print("Best MST nodes: ", best_mst.num_vertices(), "Best MST links: ", best_mst.num_edges())
#     105 # 绘制最优解
# --> 106 draw.graph_draw(best_mst, read_pos, vertex_text=best_mst.vertex_properties["number"], edge_color='blue', output_size=(1000, 1000), output=f'./output_GA/{filename1}_best_mst.pdf')
#
# File ~/anaconda3/envs/graph-tool/lib/python3.12/site-packages/graph_tool/__init__.py:1483, in PropertyDict.__getitem__(self, key)
#    1481     p = self.__properties[(self.__t, key)]
#    1482     return p[p.get_graph()]
# -> 1483 return self.__properties[(self.__t, key)]
#
# KeyError: ('v', 'number')

# %%
import random
from graph_tool import Graph, draw
from graph_tool.topology import min_spanning_tree, shortest_distance
import python_codes.files_operators

filename1 = "Germany50"

# 读取网络数据
read_graph, read_pos = python_codes.files_operators.read_files(f"../networks_clusters/{filename1}.net")
print("nodes: ", read_graph.num_vertices(), "links ", read_graph.num_edges())

# 参数设置
POP_SIZE = 50
NUM_GENERATIONS = 100
MUTATION_RATE = 0.1
TOURNAMENT_SIZE = 3

# 初始化种群
def initialize_population(graph, pop_size):
    population = []
    for _ in range(pop_size):
        mst = min_spanning_tree(graph)
        mst_graph = Graph(directed=False)
        mst_graph.add_vertex(graph.num_vertices())
        for edge, in_mst in zip(graph.edges(), mst):
            if in_mst:
                mst_graph.add_edge(edge.source(), edge.target())
        # 复制顶点和边属性
        for prop_name, prop_map in graph.vertex_properties.items():
            mst_graph.vertex_properties[prop_name] = mst_graph.new_vertex_property(prop_map.value_type())
            for v in mst_graph.vertices():
                mst_graph.vertex_properties[prop_name][v] = graph.vertex_properties[prop_name][v]
        for prop_name, prop_map in graph.edge_properties.items():
            mst_graph.edge_properties[prop_name] = mst_graph.new_edge_property(prop_map.value_type())
            for e in mst_graph.edges():
                mst_graph.edge_properties[prop_name][e] = graph.edge_properties[prop_name][graph.edge(e.source(), e.target())]
        population.append(mst_graph)
    return population

# 适应度函数：计算总路径长度
def fitness(graph):
    total_length = 0
    for v in graph.vertices():
        dist_map = shortest_distance(graph, source=v)
        total_length += sum(dist_map.a)
    return total_length

# 选择父代
def tournament_selection(population, k):
    selected = random.sample(population, k)
    selected.sort(key=fitness)
    return selected[0]

# 交叉操作
def crossover(parent1, parent2):
    size = parent1.num_edges()
    edges1 = list(parent1.edges())
    edges2 = list(parent2.edges())
    child = Graph(directed=False)
    child.add_vertex(parent1.num_vertices())
    for i in range(size // 2):
        edge = edges1[i]
        child.add_edge(edge.source(), edge.target())
    for i in range(size // 2, size):
        edge = edges2[i]
        child.add_edge(edge.source(), edge.target())
    # 复制顶点和边属性
    for prop_name, prop_map in parent1.vertex_properties.items():
        child.vertex_properties[prop_name] = child.new_vertex_property(prop_map.value_type())
        for v in child.vertices():
            child.vertex_properties[prop_name][v] = parent1.vertex_properties[prop_name][v]
    for prop_name, prop_map in parent1.edge_properties.items():
        child.edge_properties[prop_name] = child.new_edge_property(prop_map.value_type())
        for e in child.edges():
            child.edge_properties[prop_name][e] = parent1.edge_properties[prop_name][parent1.edge(e.source(), e.target())]
    return child

# 变异操作
def mutate(graph, mutation_rate):
    if random.random() < mutation_rate:
        edges = list(graph.edges())
        graph.remove_edge(random.choice(edges))
        available_edges = list(read_graph.edges())
        new_edge = random.choice(available_edges)
        graph.add_edge(new_edge.source(), new_edge.target())

# 主遗传算法
def genetic_algorithm(graph, pop_size, num_generations, mutation_rate, tournament_size):
    population = initialize_population(graph, pop_size)
    best_individual = None
    best_fitness = float('inf')

    for generation in range(num_generations):
        new_population = []
        for _ in range(pop_size // 2):
            parent1 = tournament_selection(population, tournament_size)
            parent2 = tournament_selection(population, tournament_size)
            child1 = crossover(parent1, parent2)
            child2 = crossover(parent2, parent1)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            new_population.extend([child1, child2])

        population = new_population

        # 评估新种群
        for individual in population:
            ind_fitness = fitness(individual)
            if ind_fitness < best_fitness:
                best_fitness = ind_fitness
                best_individual = individual

        print(f"Generation {generation}: Best fitness = {best_fitness}")

    return best_individual

# 执行遗传算法
best_mst = genetic_algorithm(read_graph, POP_SIZE, NUM_GENERATIONS, MUTATION_RATE, TOURNAMENT_SIZE)

# 打印最优解的节点和边数量
print("Best MST nodes: ", best_mst.num_vertices(), "Best MST links: ", best_mst.num_edges())

# 绘制最优解
draw.graph_draw(best_mst, read_pos, vertex_text=best_mst.vertex_properties["number"], edge_color='blue', output_size=(1000, 1000), output=f'./output_GA/{filename1}_best_mst.pdf')
# Out:
# nodes:  50 links  69
# Generation 0: Best fitness = 20368
# Generation 1: Best fitness = 20368
# Generation 2: Best fitness = 20368
# Generation 3: Best fitness = 20368
# Generation 4: Best fitness = 20368
# Generation 5: Best fitness = 20368
# Generation 6: Best fitness = 20320
# Generation 7: Best fitness = 20320
# Generation 8: Best fitness = 20320
# Generation 9: Best fitness = 18458
# Generation 10: Best fitness = 18458
# Generation 11: Best fitness = 18458
# Generation 12: Best fitness = 18458
# Generation 13: Best fitness = 18458
# Generation 14: Best fitness = 18458
# Generation 15: Best fitness = 18458
# Generation 16: Best fitness = 18458
# Generation 17: Best fitness = 18458
# Generation 18: Best fitness = 18458
# Generation 19: Best fitness = 18306
# Generation 20: Best fitness = 18306
# Generation 21: Best fitness = 18306
# Generation 22: Best fitness = 18306
# Generation 23: Best fitness = 18306
# Generation 24: Best fitness = 18306
# Generation 25: Best fitness = 18306
# Generation 26: Best fitness = 18306
# Generation 27: Best fitness = 18306
# Generation 28: Best fitness = 18306
# Generation 29: Best fitness = 18306
# Generation 30: Best fitness = 18306
# Generation 31: Best fitness = 18306
# Generation 32: Best fitness = 18306
# Generation 33: Best fitness = 18306
# Generation 34: Best fitness = 18306
# Generation 35: Best fitness = 18306
# Generation 36: Best fitness = 18306
# Generation 37: Best fitness = 18306
# Generation 38: Best fitness = 18306
# Generation 39: Best fitness = 18306
# Generation 40: Best fitness = 18306
# Generation 41: Best fitness = 18108
# Generation 42: Best fitness = 18108
# Generation 43: Best fitness = 18108
# Generation 44: Best fitness = 18108
# Generation 45: Best fitness = 18108
# Generation 46: Best fitness = 18108
# Generation 47: Best fitness = 18108
# Generation 48: Best fitness = 18108
# Generation 49: Best fitness = 18108
# Generation 50: Best fitness = 18108
# Generation 51: Best fitness = 18108
# Generation 52: Best fitness = 18108
# Generation 53: Best fitness = 18108
# Generation 54: Best fitness = 18108
# Generation 55: Best fitness = 18108
# Generation 56: Best fitness = 18108
# Generation 57: Best fitness = 18108
# Generation 58: Best fitness = 18108
# Generation 59: Best fitness = 18108
# Generation 60: Best fitness = 18108
# Generation 61: Best fitness = 18108
# Generation 62: Best fitness = 18108
# Generation 63: Best fitness = 18108
# Generation 64: Best fitness = 18108
# Generation 65: Best fitness = 18108
# Generation 66: Best fitness = 18108
# Generation 67: Best fitness = 18108
# Generation 68: Best fitness = 18108
# Generation 69: Best fitness = 18108
# Generation 70: Best fitness = 18108
# Generation 71: Best fitness = 18108
# Generation 72: Best fitness = 18108
# Generation 73: Best fitness = 18108
# Generation 74: Best fitness = 18108
# Generation 75: Best fitness = 18108
# Generation 76: Best fitness = 18108
# Generation 77: Best fitness = 17960
# Generation 78: Best fitness = 17960
# Generation 79: Best fitness = 17960
# Generation 80: Best fitness = 17960
# Generation 81: Best fitness = 17960
# Generation 82: Best fitness = 17960
# Generation 83: Best fitness = 17960
# Generation 84: Best fitness = 17704
# Generation 85: Best fitness = 17704
# Generation 86: Best fitness = 17704
# Generation 87: Best fitness = 17704
# Generation 88: Best fitness = 17704
# Generation 89: Best fitness = 17704
# Generation 90: Best fitness = 17704
# Generation 91: Best fitness = 17704
# Generation 92: Best fitness = 17704
# Generation 93: Best fitness = 17704
# Generation 94: Best fitness = 17704
# Generation 95: Best fitness = 17704
# Generation 96: Best fitness = 17704
# Generation 97: Best fitness = 17704
# Generation 98: Best fitness = 17704
# Generation 99: Best fitness = 17704
# Best MST nodes:  50 Best MST links:  49
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7623276e2420, at 0x76232a80ac90>
